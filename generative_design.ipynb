# %%
# !pip freeze > requirements.txt

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !pip install accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.43.1 trl==0.4.7 wandb datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 32.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 17.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 13.7 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade transformers trl vllm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 979.0 kB/s eta 0:00:00
# ...
#   Using cached tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 36.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.1/280.1 kB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.6/134.6 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 MB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.8/20.8 MB 53.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.9/362.9 kB 25.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 9.2 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade trl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.1/280.1 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 9.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: trl
#     Found existing installation: trl 0.4.7
#     Uninstalling trl-0.4.7:
#       Successfully uninstalled trl-0.4.7
# ...

# %%
# !pip install accelerate peft bitsandbytes transformers trl wandb datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.5/322.5 kB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.4/318.4 kB 15.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 60.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 25.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.4/311.4 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.9/105.9 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.6 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade transformers vllm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 79.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.3/228.3 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 92.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.8/20.8 MB 81.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 66.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 59.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 39.3 MB/s eta 0:00:00
# ...

# %%
from trl import SFTTrainer
import os
import torch
from datasets import load_dataset, Dataset
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainingArguments, pipeline, logging, GenerationConfig
from peft import LoraConfig, prepare_model_for_kbit_training, PeftModel
import torch
import gc
import wandb
from tqdm.notebook import tqdm
import re
import random
from huggingface_hub import login
from transformers.integrations import WandbCallback
from torch.utils.data import DataLoader
import shutil

# %%
dataset_name = "evgmaslov/cars"
text2text_model_name = "VityaVitalich/Llama3.1-8b-instruct"
text2code_model_name = "ajibawa-2023/Code-Llama-3-8B"
text2code_tuned_model_name = "evgmaslov/Code-Llama-3-8B-cars"

llama3_format_prompt_inference = "{prompt}<|eot_id|><|start_header_id|>{input}<|end_header_id|>"
llama3_format_noprompt_inference = "<|eot_id|><|start_header_id|>{input}<|end_header_id|>"
llama3_format_prompt_train = "{prompt}<|eot_id|><|start_header_id|>{input}<|end_header_id|>{output}<|eot_id|>"
llama3_format_noprompt_train = "<|eot_id|><|start_header_id|>{input}<|end_header_id|>{output}<|eot_id|>"

# %% [markdown]
# #Common operations

# %% [markdown]
# ##Clean memory

# %%
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ##Init entities

# %%
from transformers import GenerationConfig
from transformers.integrations import WandbCallback
import random
class LLMSampleCB(WandbCallback):
    def __init__(self, trainer, test_dataset, num_samples=2, max_new_tokens=2048, log_model="checkpoint"):
        super().__init__()
        self._log_model = log_model
        self.sample_dataset = test_dataset.select(random.choices(range(len(test_dataset)), k=num_samples))
        self.model, self.tokenizer = trainer.model, trainer.tokenizer
        self.inference_model = None
        self.gen_config = GenerationConfig.from_pretrained(trainer.model.name_or_path,
                                                           max_new_tokens=max_new_tokens)
        self.gen_config.temperature = 0.9
    def generate(self, prompt):
        tokenized_prompt = self.tokenizer(prompt, return_tensors='pt')['input_ids'].cuda()
        with torch.inference_mode():
            output = self.inference_model.generate(**{"input_ids":tokenized_prompt,
                                                      "generation_config":self.gen_config})
        return self.tokenizer.decode(output[0][len(tokenized_prompt[0]):], skip_special_tokens=True)

    def samples_table(self, examples):
        records_table = wandb.Table(columns=["prompt", "generation"] + list(self.gen_config.to_dict().keys()))
        for example in tqdm(examples, leave=False):
            prompt = get_inference_text(example['input'])
            generation = self.generate(prompt=prompt)
            records_table.add_data(prompt, generation, *list(self.gen_config.to_dict().values()))
        return records_table

    def on_evaluate(self, args, state, control,  **kwargs):
        super().on_evaluate(args, state, control, **kwargs)
        self.inference_model = self.model
        records_table = self.samples_table(self.sample_dataset)
        self._wandb.log({"sample_predictions":records_table})

# %%
def generate(model, tokenizer, generation_config, inp):
  tokenized_prompt = tokenizer(inp, return_tensors='pt', padding=True, truncation=True)
  tokenized_prompt_ids = tokenized_prompt["input_ids"].cuda()
  tokenized_prompt_mask = tokenized_prompt["attention_mask"].cuda()
  with torch.inference_mode():
      output = model.generate(**{"input_ids":tokenized_prompt_ids, "attention_mask":tokenized_prompt_mask, "generation_config":generation_config}).detach().cpu()
  decoded = []
  for i in range(output.shape[0]):
    ans = tokenizer.decode(output[i][len(tokenized_prompt[0]):], skip_special_tokens=True)
    decoded.append(ans)
  return decoded

# %%
def format_prompt(prompt_format, args):
  prompt = prompt_format.format(**args)
  return prompt

# %%
def transform_to_nl(dataloader, text2text_model, tokenizer, gen_config, prompt, path):
  natural_inputs = []
  for batch in tqdm(dataloader):
    formated_inputs = ["characteristics:{text}\n".format(text=inp.replace("Generate a car with the following characteristics: ", "")) for inp in batch["input"]]
    prompts = [format_prompt(llama3_format_prompt_inference, {"prompt":prompt, "input":inp}) for inp in batch["input"]]
    generations = generate(text2text_model, tokenizer, gen_config, prompts)
    natural_inputs.extend(generations)

    existed = ""
    if os.path.exists(path):
      with open(path, "r") as f:
        existed = f.read()
    with open(path, "w+") as f:
      f.write(existed + "###SAMPLE###" + "###SAMPLE###".join(generations))
  return natural_inputs

# %% [markdown]
# ##Login to huggingface

# %%
token = "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"

# %%
login()

# %% [markdown]
# ##Delete folder

# %%
shutil.rmtree("/content/evgmaslov")

# %% [markdown]
# #Dataset creation

# %% [markdown]
# ##Load to the hub

# %%
# !unzip /content/drive/MyDrive/generative_design/CarsDataset.zip
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: CarsDataset/OutputCode/Code_95499.cs
#   inflating: CarsDataset/OutputCode/Code_955.cs
#   inflating: CarsDataset/OutputCode/Code_9550.cs
#   inflating: CarsDataset/OutputCode/Code_95500.cs
#   inflating: CarsDataset/OutputCode/Code_95501.cs
#   inflating: CarsDataset/OutputCode/Code_95502.cs
#   inflating: CarsDataset/OutputCode/Code_95503.cs
#   inflating: CarsDataset/OutputCode/Code_95504.cs
#   inflating: CarsDataset/OutputCode/Code_95505.cs
#   inflating: CarsDataset/OutputCode/Code_95506.cs
#   inflating: CarsDataset/OutputCode/Code_95507.cs
#   inflating: CarsDataset/OutputCode/Code_95508.cs
#   inflating: CarsDataset/OutputCode/Code_95509.cs
#   inflating: CarsDataset/OutputCode/Code_9551.cs
#   inflating: CarsDataset/OutputCode/Code_95510.cs
#   inflating: CarsDataset/OutputCode/Code_95511.cs
#   inflating: CarsDataset/OutputCode/Code_95512.cs
# ...

# %%
login()

# %%
path = "CarsDataset"
code_path = os.path.join(path, "OutputCode")
text_path = os.path.join(path, "InputTextsEn.txt")

dataset_dict = {
    "input":[],
    "output":[],
    "text":[],
}
for i in tqdm(range(len(os.listdir(code_path))), desc="Reading code"):
  local_path = os.path.join(code_path, f"Code_{i}.cs")
  with open(local_path, "r") as f:
    code = f.read()
    dataset_dict["output"].append(code)
with open(text_path, "r") as f:
  texts = f.readlines()
  _ = [dataset_dict["input"].append(text) for text in texts]
for i in range(len(dataset_dict["input"])):
  inp = dataset_dict["input"][i]
  out = dataset_dict["output"][i]
  text = f"<s>[INST] {inp} [/INST] {out} </s>"
  dataset_dict["text"].append(text)
# Out:
# Reading code:   0%|          | 0/257688 [00:00<?, ?it/s]

# %%
import shutil
shutil.rmtree("/content/drive")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = Dataset.from_dict(dataset_dict)

# %%
dataset = dataset.train_test_split(test_size=0.1)

# %%
dataset.push_to_hub(dataset_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Creating parquet from Arrow format:   0%|          | 0/26 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/evgmaslov/gen_cars/commit/24f0bcd1a405813c432dcd56eb8f51945dfcaa89', commit_message='Upload dataset', commit_description='', oid='24f0bcd1a405813c432dcd56eb8f51945dfcaa89', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ##Generate natural language descriptions

# %%
dataset = load_dataset(dataset_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/3.10M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/7.44M [00:00<?, ?B/s]
# ...
# Generating test split:   0%|          | 0/25769 [00:00<?, ? examples/s]

# %%
quant_config = BitsAndBytesConfig(load_in_4bit=True,
                                  bnb_4bit_compute_dtype=torch.float16,
                                  bnb_4bit_quant_type="nf4",
                                  bnb_4bit_use_double_quant=True)

# %%
tokenizer = AutoTokenizer.from_pretrained(text2text_model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
peft_params = LoraConfig(
    lora_alpha=16, lora_dropout=0.1, r=64, bias="none", task_type="CAUSAL_LM")
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.9k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]

# %%
text2text_model = AutoModelForCausalLM.from_pretrained(text2text_model_name,
                                             quantization_config=quant_config,
                                             device_map='auto',
                                  low_cpu_mem_usage=True, offload_state_dict=True)
# Out:
# config.json:   0%|          | 0.00/915 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]

# %%
with open("train_nl.txt", "r") as f:
  train_nl_buffer = f.read()
train_nl_buffer = train_nl_buffer.split("###SAMPLE###")

# %%
len(train_nl_buffer)

# %%
dataset["train"] = dataset["train"].select(range(0:len(dataset["train"])))

# %%
train_dataloader = DataLoader(dataset["train"], batch_size=2, shuffle=False)
test_dataloader = DataLoader(dataset["test"], batch_size=2, shuffle=False)

# %%
gen_config = GenerationConfig.from_pretrained(text2text_model_name)
gen_config.max_length = 2048
"You receive a description of the characteristics of a car as input. Write a request to generate a car with such characteristics on human language. Don't write anything other than the request like."
prompt = """You receive a request to generate a car in the format "Generate a car with the following characteristics: name1:value1; name2:value2;...". Rewrite it into human language. You shouldn't write anything like "Here is the rewritten request in human language". Here are some examples:
Example 1
request: Generate a car with the following characteristics: length: 290 cm; width: 150 cm; height: 135 cm; wheel width: 27 cm; wheel radius: 36.6 cm; clearance height: 12 cm; bonnet size : small; bonnet shape : rounded; windscreen shape: rounded; boot shape: rounded;
rewritten request: Make me a car with a rounded hood and windshield, wheels with a radius of 36.6 cm and a width of 27 cm. The clearance should be 12 cm, the length 290 cm, the width 150 cm, the height 135 cm. Also let the hood be small.
Example 2
request: Generate a car with the following characteristics: length: 350 cm; width: 150 cm; height: 135 cm; wheel width: 15 cm; wheel radius: 35.15 cm; clearance height: 14 cm; bonnet size : large; bonnet shape : rounded; windscreen shape: rounded; boot shape: flat;
rewritten request: Generate a car with a length of 350 cm, a width of 150 cm and a height of 135 cm. Make a large rounded hood, a flat trunk and a rounded windshield. The wheels should have a radius of 35.15 cm and a width of 15 cm.
Example 3
request: Generate a car with the following characteristics: 2 wheelsets;normal size boot; length: 250 cm; height: 135 cm; wheel radius: 25 cm;
rewritten request: Create a passenger car with a standard-sized trunk. It will be 2.5 meters long and 1 meter 35 centimeters high. The wheels should have a radius of 25 centimeters.
Example 4
request: Generate a car with the following characteristics: body type: truck;
rewritten request: I want a random truck.
Example 5
request: Generate a car with the following characteristics: normal size bonnet; length: 250 cm; width is small; height is small; wheel radius: 25 cm;
rewritten request: I want you to create a car with a wheel radius of 25 cm. Make it compact, but make it 2.5 meters long. Leave the hood of standard size.
"""
"""Example 6
request: Generate a car with the following characteristics: body type: sedan; width is small;
rewritten request: I need some small sedan.
Example  7
request: Generate a car with the following characteristics: 2 wheelsets;normal size bonnet;small boot; width is small; height is small;
rewritten request: Can you please make me a small passenger vehicle for city driving? The trunk can be made small, but the hood should be normal.
"""
# Out:
# 'Example 6\nrequest: Generate a car with the following characteristics: body type: sedan; width is small;\nrewritten request: I need some small sedan.\nExample  7\nrequest: Generate a car with the following characteristics: 2 wheelsets;normal size bonnet;small boot; width is small; height is small;\nrewritten request: Can you please make me a small passenger vehicle for city driving? The trunk can be made small, but the hood should be normal.\n'

# %%
train_nl = transform_to_nl(train_dataloader, text2text_model, tokenizer, gen_config, prompt, "train_nl.txt")
# Out:
#   0%|          | 0/26640 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Generate a car with the following characteristics: normal size boot; length is small; width: 167 cm; height is small; wheel radius is small
# Generate a car with the following characteristics: normal size boot; length is small; height: 135 cm; wheel radius: 25 cm
# assistant
#
# Make a car with a compact trunk. It should be relatively short and narrow, with a wheel radius that is smaller than usual.
# assistant
#
# Make me a car with a normal-sized trunk. It should be relatively short in length, 1.35 meters high, and have wheels with a radius of 25 centimeters.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Generate a car with the following characteristics: normal size bonnet;normal size boot; length: 250 cm; height is small; wheel radius is small
# ...

# %%
test_nl = transform_to_nl(test_dataloader, text2text_model, tokenizer, gen_config, prompt)

# %%
dataset["train"].add_column("natural_input", train_nl)
dataset["test"].add_column("natural_input", test_nl)

# %%
dataset.push_to_hub(dataset_name)

# %% [markdown]
# #Training

# %% [markdown]
# ##Prepare dataset

# %%
dataset = load_dataset(dataset_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
eos_token = "<|eot_id|>"
b_inst_token = "<|start_header_id|>"
e_inst_token = "<|end_header_id|>"
prompt = ""

# %%
def get_inference_text(text):
  input_format_without_prompt = "{b_inst}{text}{e_inst}"
  input_format_with_prompt = "{prompt}{eos}" + input_format_without_prompt
  input_text = ""
  if len(prompt) == 0:
    input_text = input_format_without_prompt.format(b_inst=b_inst_token, text=text, e_inst=e_inst_token)
  else:
    input_text = input_format_with_prompt.format(prompt=prompt, eos=eos_token, b_inst=b_inst_token, text=text, e_inst=e_inst_token)
  return input_text
def get_train_text(input_text, output_text):
  output_format = "{output}{eos}"
  inp = get_inference_text(input_text)
  out = inp + output_format.format(output=output_text, eos=eos_token)
  return out

# %%
def generate_train_text(row):
  row["text"] = get_train_text(row["input"], row["output"])
  return row

# %%
dataset = dataset.map(generate_train_text)

# %% [markdown]
# ##Init model

# %%
quant_config = BitsAndBytesConfig(load_in_4bit=True,
                                  bnb_4bit_compute_dtype=torch.float16,
                                  bnb_4bit_quant_type="nf4",
                                  bnb_4bit_use_double_quant=True)

# %%
tokenizer = AutoTokenizer.from_pretrained(text2code_model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
peft_params = LoraConfig(
    lora_alpha=16, lora_dropout=0.1, r=64, bias="none", task_type="CAUSAL_LM")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
model = AutoModelForCausalLM.from_pretrained(text2code_model_name,
                                             quantization_config=quant_config,
                                             device_map='auto',
                                  low_cpu_mem_usage=True, offload_state_dict=True)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ##Init pretrain model

# %%
model = PeftModel.from_pretrained(model, text2code_tuned_model_name)
model = prepare_model_for_kbit_training(model)
# Out:
# adapter_config.json:   0%|          | 0.00/450 [00:00<?, ?B/s]
# adapter_model.bin:   0%|          | 0.00/109M [00:00<?, ?B/s]
# ...

# %% [markdown]
# ##Train

# %%
resume_from_checkpoint=True
training_params = TrainingArguments(
    output_dir=text2code_tuned_model_name,
    num_train_epochs=1,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    gradient_accumulation_steps=1,
    optim="paged_adamw_32bit",
    save_steps=25, logging_steps=25,
    learning_rate=3e-5, weight_decay=0.001,
    fp16=False, bf16=False,
    max_grad_norm=0.3,
    max_steps=-1, warmup_ratio=0.001,
    group_by_length=True, lr_scheduler_type='cosine',
    report_to="wandb",
    save_total_limit=2,
    evaluation_strategy="steps",
    eval_steps=25,
    push_to_hub=True,
    hub_strategy="checkpoint",
    resume_from_checkpoint=resume_from_checkpoint)
trainer = SFTTrainer(
    model=model,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"].select(range(100)),
    peft_config=peft_params,
    dataset_text_field="text",
    max_seq_length=None,
    tokenizer=tokenizer,
    args=training_params, packing=False)
wandb_callback = LLMSampleCB(trainer, dataset["test"], num_samples=2, max_new_tokens=2048)
trainer.add_callback(wandb_callback)
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:159: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# ...

# %%
wandb.init("generative_design")
if resume_from_checkpoint:
  trainer.train(resume_from_checkpoint=text2code_tuned_model_name + "/last-checkpoint")
else:
  trainer.train()
# Out:
# wandb: Currently logged in as: evg_maslov. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.8
# Run data is saved locally in <code>/content/wandb/run-20240829_144209-o5y2k33j</code>
# Syncing run <strong><a href='https://wandb.ai/evg_maslov/uncategorized/runs/o5y2k33j' target="_blank">whole-sponge-45</a></strong> to <a href='https://wandb.ai/evg_maslov/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/evg_maslov/uncategorized' target="_blank">https://wandb.ai/evg_maslov/uncategorized</a>
#  View run at <a href='https://wandb.ai/evg_maslov/uncategorized/runs/o5y2k33j' target="_blank">https://wandb.ai/evg_maslov/uncategorized/runs/o5y2k33j</a>
# ...

# %%
# Test the model
logging.set_verbosity(logging.CRITICAL)
prompt = "Who is Leonardo Da Vinci?"
pipe = pipeline(task="text-generation", model=model, tokenizer=tokenizer, max_length=200)
result = pipe(f"<s>[INST] {prompt} [/INST]")
print(result[0]['generated_text'])

# %% [markdown]
# #Evaluation

# %%
request = "Generate a car with a large bonnet."
prompt = get_inference_text(request)
tokenized_prompt = tokenizer(prompt, return_tensors='pt')['input_ids'].cuda()
gen_config = GenerationConfig.from_pretrained(model.name_or_path)
with torch.inference_mode():
    output = model.generate(**{"input_ids":tokenized_prompt, "generation_config":gen_config})
output = tokenizer.decode(output[0][len(tokenized_prompt[0]):], skip_special_tokens=True)
print(output)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [SHAPE]Give the car a flat front with a raised lip at the edges. The bonnet should be large and rounded at the edges. The sides should be straight and flat. The rear should be flat with a small vertical lip at the top. The bottom should be rounded and raised high off the ground. The wheels should be large and rounded at the edges with thin spokes. [/SHAPE]
#
# ...

# %%
num_eval_samples = 100
inds = random.choices(range(len(dataset["test"])), k=num_eval_samples)
eval_samples = dataset["test"].select(inds)

# %%
test_true = ""
test_pred = ""

# %%
file_accuracy = 0
pos_count = 0
pbar = tqdm(enumerate(eval_samples), total=num_eval_samples, desc="Evaluation ")
for i, sample in pbar:
  system = """You are an expert in writing code to generate car geometry. You receive a description of a car containing its geometric characteristics. Write code in the format of a C# class definition that describes the car geometry. Fill in the class properties according to the user's request."""
  prompt = f"<s><<SYS>>{system}<</SYS>>[INST]{sample['input']}[/INST]"
  tokenized_prompt = tokenizer(prompt, return_tensors='pt')['input_ids'].cuda()
  gen_config = GenerationConfig.from_pretrained(model.name_or_path)
  with torch.inference_mode():
      output = model.generate(**{"input_ids":tokenized_prompt, "generation_config":gen_config})
  output = tokenizer.decode(output[0][len(tokenized_prompt[0]):], skip_special_tokens=True)
  test_pred = output
  test_true = sample["output"]
  output = re.search("using (?:.|\n)*}", output)[0]
  if evaluate(sample["input"], output):
    pos_count += 1
  file_accuracy = pos_count/(i+1)
  pbar.set_description("File accuracy: %s" % file_accuracy)
# Out:
# Evaluation :   0%|          | 0/100 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ...

# %%
def evaluate(input_text, output_text):
  try:
    length = re.search("(Length = )([^;]+)(;\s+)", output_text).group(2).split("f")[0]
    width = re.search("(Width = )([^;]+)(;\s+)", output_text).group(2).split("f")[0]
    height = re.search("(Height = )([^;]+)(;\s+)", output_text).group(2).split("f")[0]
    wheel_width = re.search("(WheelWidth = )([^;]+)(;\s+)", output_text).group(2).split("f")[0]
    wheel_radius = re.search("(WheelRadius = )([^;]+)(;\s+)", output_text).group(2).split("f")[0]
    clearance = re.search("WheelBaseSegmentsBottomSurfaces = new List<Line>\(\) { new Constant\(height: (.*)f\) };", output_text).group(1)
    body_segment_spans = re.search("BodySegmentsSpans = (.*);", output_text).group(1)
    body_segment_top_surfaces = re.search("BodySegmentsTopSurfaces = (.*);", output_text).group(1)

    real_text = "Generate a car with the following characteristics:"
    real_text = real_text + f" length: {length} cm;"
    real_text = real_text + f" width: {width} cm;"
    real_text = real_text + f" height: {height} cm;"
    real_text = real_text + f" wheel width: {wheel_width} cm;"
    real_text = real_text + f" wheel radius: {wheel_radius} cm;"
    real_text = real_text + f" clearance height: {clearance} cm;"

    bonnet_size = float(re.search("{ new List<float>\(\){ 0f, (.*)f }, new", body_segment_spans).group(1))
    if bonnet_size <= 0.2:
      real_text = real_text + f" bonnet size : small;"
    elif bonnet_size >= 0.3:
      real_text = real_text + f" bonnet size : large;"
    surfaces = body_segment_top_surfaces.split("new")[2:]
    if "CornerRounded" in surfaces[0] and "leftCornerRounded: true" in surfaces[0] or "TotalRounded" in surfaces[0]:
      real_text = real_text + f" bonnet shape : rounded;"
    elif "Constant" in surfaces[0]:
      real_text = real_text + f" bonnet shape : flat;"

    if (len(surfaces) == 2 and "CornerRounded" in surfaces[1] and "leftCornerRounded: true" in surfaces[1]) or (len(surfaces) == 3 and ("TotalRounded" in surfaces[1] or "CornerRounded" in surfaces[1] and "leftCornerRounded: true" in surfaces[1])):
      real_text = real_text + f" windscreen shape: rounded;";
    elif "Constant" in surfaces[1] or "CornerRounded" in surfaces[1] and "leftCornerRounded: false" in surfaces[1]:
      real_text = real_text + f" windscreen shape: flat;"

    if len(surfaces) == 3:
      boot_size = float(re.search("{ new List<float>\(\){ (.*)f, (.*)f }", surfaces[2]).group(2))
      if boot_size >= 0.9:
        real_text = real_text + " boot size: small;"
      elif boot_size <= 0.8:
        real_text = real_text + " boot size: medium;"
    if (len(surfaces) == 2 and "CornerRounded" in surfaces[1] and "rightCornerRounded: true" in surfaces[1]) or (len(surfaces) == 3 and ("TotalRounded" in surfaces[2] or "CornerRounded" in surfaces[2] and "rightCornerRounded: true" in surfaces[1])):
      real_text = real_text + " boot shape: rounded;"
    elif (len(surfaces) == 2 and ("CornerRounded" in surfaces[1] and "rightCornerRounded: false" in surfaces[1]) or "Constant" in surfaces[1]) or (len(surfaces) == 3 and ("Constant" in surfaces[2] or "CornerRounded" in surfaces[1] and "rightCornerRounded: false" in surfaces[1])):
      real_text = real_text + " boot shape: flat;"
    real_text = real_text + "\n"
    if real_text == input_text:
      return True
    else:
      return False
  except:
    return False
