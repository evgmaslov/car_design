# %%
from trl import SFTTrainer
import os
import torch
from datasets import load_dataset, Dataset
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainingArguments, pipeline, logging, GenerationConfig, get_cosine_with_hard_restarts_schedule_with_warmup
from peft import LoraConfig, prepare_model_for_kbit_training, PeftModel
import torch
import gc
import wandb
from tqdm.notebook import tqdm
import re
import random
from huggingface_hub import login
from transformers.integrations import WandbCallback
from torch.utils.data import DataLoader
import shutil
import json

# %%
dataset_name = "evgmaslov/cars"
text2text_model_name = "mistralai/Mistral-Nemo-Instruct-2407"
text2code_model_name = "mistralai/Mistral-Nemo-Instruct-2407"
text2code_tuned_model_name = "evgmaslov/Mistral-Nemo-Instruct-2407-cars"

llama3_format_prompt_inference = "{prompt}<|eot_id|><|start_header_id|>{input}<|end_header_id|>"
llama3_format_noprompt_inference = "<|eot_id|><|start_header_id|>{input}<|end_header_id|>"
llama3_format_prompt_train = "{prompt}<|eot_id|><|start_header_id|>{input}<|end_header_id|>{output}<|eot_id|>"
llama3_format_noprompt_train = "<|eot_id|><|start_header_id|>{input}<|end_header_id|>{output}<|eot_id|>"

# %% [markdown]
# # Common operations

# %% [markdown]
# ## Clean memory

# %%
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ## Init entities

# %%
from transformers import GenerationConfig
from transformers.integrations import WandbCallback
import random
class LLMSampleCB(WandbCallback):
    def __init__(self, trainer, test_dataset, num_samples=2, max_new_tokens=2048, log_model="checkpoint"):
        super().__init__()
        self.sample_dataset = test_dataset.select(random.choices(range(len(test_dataset)), k=num_samples))
        self.model, self.tokenizer = trainer.model, trainer.tokenizer
        self.inference_model = None
        self.gen_config = GenerationConfig.from_pretrained(trainer.model.name_or_path,
                                                           max_new_tokens=max_new_tokens)
        self.gen_config.temperature = 0.9
    def generate(self, prompt):
        tokenized_prompt = self.tokenizer(prompt, return_tensors='pt')['input_ids'].cuda()
        with torch.inference_mode():
            output = self.inference_model.generate(**{"input_ids":tokenized_prompt,
                                                      "generation_config":self.gen_config})
        return self.tokenizer.decode(output[0][len(tokenized_prompt[0]):], skip_special_tokens=True)

    def samples_table(self, examples):
        records_table = wandb.Table(columns=["prompt", "generation"] + list(self.gen_config.to_dict().keys()))
        for example in tqdm(examples, leave=False):
            prompt = get_inference_text(example['natural_input'], tokenizer)
            generation = self.generate(prompt=prompt)
            records_table.add_data(prompt, generation, *list(self.gen_config.to_dict().values()))
        return records_table

    def on_evaluate(self, args, state, control,  **kwargs):
        super().on_evaluate(args, state, control, **kwargs)
        self.inference_model = self.model
        records_table = self.samples_table(self.sample_dataset)
        self._wandb.log({"sample_predictions":records_table})

# %%
def generate(model, tokenizer, generation_config, inp):
  tokenized_prompt = tokenizer(inp, return_tensors='pt', padding=True, truncation=True)
  tokenized_prompt_ids = tokenized_prompt["input_ids"].cuda()
  tokenized_prompt_mask = tokenized_prompt["attention_mask"].cuda()
  with torch.inference_mode():
      output = model.generate(**{"input_ids":tokenized_prompt_ids, "attention_mask":tokenized_prompt_mask, "generation_config":generation_config}).detach().cpu()
  decoded = []
  for i in range(output.shape[0]):
    ans = tokenizer.decode(output[i][len(tokenized_prompt[0]):], skip_special_tokens=True)
    decoded.append(ans)
  return decoded

# %%
def transform_to_nl(dataset, batch_size, text2text_model, tokenizer, gen_config, prompt, path):
  natural_inputs = {}
  if os.path.exists(path):
      with open(path, "r") as f:
        current = json.load(f)
        for key in current.keys():
            natural_inputs[key] = current[key]
  n_batches = int(len(dataset)/batch_size)
  if n_batches * batch_size < len(dataset):
      n_batches += 1
  for i in range(n_batches):
      rest_inds = [ind for ind in range(len(dataset)) if str(ind) not in natural_inputs]
      if len(rest_inds) == 0:
          continue
      if len(rest_inds) < batch_size:
          inds = rest_inds
      else:
          inds = random.sample(rest_inds, batch_size)
      batch = dataset.select(inds)
      prompts = [get_inference_text(prompt, inp, tokenizer) for inp in batch["input"]]
      generations = generate(text2text_model, tokenizer, gen_config, prompts)
      
      for ind, pos in enumerate(inds):
          natural_inputs[pos] = generations[ind]
      with open(path, "w+") as f:
        json.dump(natural_inputs, f)
      print(f"Batch {i} is processed")
  return natural_inputs

# %% [markdown]
# ### Filtering dataset to delete poor samples

# %%
def clean_dataset(row):
    result = True
    row = {"input": row["input"].lower(), "natural_input": row["natural_input"].lower()}
    if "can't" in row["natural_input"] or "can not" in row["natural_input"]:
        result = False
    ints = ["length", "width", "heignt"]
    for param in ints:
        if param in row["input"]:
            value = re.findall("(?<=" + param + ": )\d+?(?= cm)", row["input"])
            if len(value) == 0:
                continue
            else:
                value = value[0]
            equals = [" "+value+" ", value[:-2] + " \w+? " + value[-2:], " "+str(float(value)/100)+" "]
            found = False
            for e in equals:
                if len(re.findall(e, row["natural_input"])) > 0:
                    found = True
                    break
            if not found:
                result = False
                break
    doubles = ["wheel radius", "wheel width"]
    for param in doubles:
        if param in row["input"]:
            value = re.findall("(?<=" + param + ": )\d+?(?= cm)", row["input"])
            if len(value) == 0:
                continue
            else:
                value = value[0]
            if len(re.findall(" "+value+" ", row["natural_input"])) == 0:
                result = False
                break
    body_types = ["sedan", "hatchback", "station wagon", "coupe", "limousine", "SUV", "pickup", "minivan", "van", "truck"]
    if "body type" in row["input"]:
        found = []
        for body in body_types:
            if body in row["natural_input"]:
                found.append(body)
        if len(found) > 1:
            result = False
        if len(found) == 1:
            right_body = re.findall("(?<=body type: )\w+?", row["input"])[0]
            if right_body != found[0]:
                result = False
    return result

# %% [markdown]
# ### Text formatting with custom template (codellama)

# %%
eos_token = "<|end_of_text|>"
b_inst_token = "<|start_header_id|>"
e_inst_token = "<|end_header_id|>"
def get_inference_text(prompt, text, tokenizer):
  input_format_without_prompt = """{b_inst}user{e_inst}
  {text}{eos}{b_inst}assistant{e_inst}
  """
  input_format_with_prompt = """{b_inst}system{e_inst}
  {prompt}{eos}""" + input_format_without_prompt
  input_text = ""
  if len(prompt) == 0:
    input_text = input_format_without_prompt.format(b_inst=b_inst_token, text=text, e_inst=e_inst_token, eos=eos_token)
  else:
    input_text = input_format_with_prompt.format(prompt=prompt, b_inst=b_inst_token, text=text, e_inst=e_inst_token, eos=eos_token)
  return input_text
def get_train_text(prompt, input_text, output_text, tokenizer):
  output_format = """{output}{eos}
  """
  inp = get_inference_text(prompt, input_text, tokenizer)
  out = inp + output_format.format(output=output_text, eos=eos_token)
  return out
def generate_train_text(prompt, row, tokenizer):
  row["text"] = get_train_text(prompt, row["natural_input"], row["output"])
  return row

# %% [markdown]
# ### Text formatting with huggingface chat template (qwen, mistral)

# %%
def get_inference_text(prompt, text, tokenizer):
  messages = [
      {"role": "system", "content": prompt},
      {"role": "user", "content": text}
  ]
  input_text = tokenizer.apply_chat_template(
      messages,
      tokenize=False,
      add_generation_prompt=True
  )
  return input_text
def get_train_text(prompt, input_text, output_text, tokenizer):
  messages = [
      {"role": "system", "content": prompt},
      {"role": "user", "content": input_text},
      {"role": "assistant", "content": output_text},
  ]
  out = tokenizer.apply_chat_template(
      messages,
      tokenize=False,
  )
  return out

def generate_train_text(prompt, row, tokenizer):
  row["text"] = get_train_text(prompt, row["natural_input"], row["output"], tokenizer)
  return row

# %% [markdown]
# ## Huggingface login

# %%
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# # Dataset creation

# %% [markdown]
# ## Generate natural language descriptions

# %%
dataset = load_dataset(dataset_name)

# %%
quant_config = BitsAndBytesConfig(load_in_4bit=True,
                                  bnb_4bit_compute_dtype=torch.float16,
                                  bnb_4bit_quant_type="nf4",
                                  bnb_4bit_use_double_quant=True)

# %%
tokenizer = AutoTokenizer.from_pretrained(text2text_model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
peft_params = LoraConfig(
    lora_alpha=16, lora_dropout=0.1, r=64, bias="none", task_type="CAUSAL_LM")

# %%
text2text_model = AutoModelForCausalLM.from_pretrained(text2text_model_name,
                                             quantization_config=quant_config,
                                             device_map='auto',
                                  low_cpu_mem_usage=True, offload_state_dict=True)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
train_dataloader = DataLoader(dataset["train"], batch_size=256, shuffle=False)
test_dataloader = DataLoader(dataset["test"], batch_size=256, shuffle=False)

# %%
gen_config = GenerationConfig.from_pretrained(text2text_model_name)
gen_config.max_length = 2048
prompt = """You receive a request to generate a car in the format "Generate a car with the following characteristics: name1:value1; name2:value2;...". This request contains a set of car characteristics. Rewrite this request into human language without losing information about the characteristics of the car. You must return a response in the following json format: {"rewritten request": here you must paste the rewritten request in human language, "explanation": here you should explain where in the human language query the information about a specific parameter is mentioned. Write it in the following json format: {parameter name: mention explanation} } Here are some examples:
Example 1
request: Generate a car with the following characteristics: length: 290 cm; width: 150 cm; height: 135 cm; wheel width: 27 cm; wheel radius: 36.6 cm; clearance height: 12 cm; bonnet size : small; bonnet shape : rounded; windscreen shape: rounded; boot shape: rounded;
answer: {"rewritten request":"Make me a car with a rounded hood and windshield, wheels with a radius of 36.6 cm and a width of 27 cm. The clearance should be 12 cm, the length 290 cm, the width 150 cm, the height 135 cm. Also let the hood be small and boot be rounded.",
"explanation":{"length": "I mentioned, that 'the length 290 cm'", "width":"I mentioned, that 'the width 150 cm'", "height": "I mentioned, that 'the height 135 cm'", "wheel width":"I mentioned it here: 'wheels with a radius of 36.6 cm and a width of 27 cm'", "wheel radius": "I mentioned it here: 'wheels with a radius of 36.6 cm and a width of 27 cm'", "clearance height": "I mentioned, that 'The clearance should be 12 cm'", "bonnet size": "I mentioned it here: 'let the hood be small'", "bonnet shape":"I mentioned it here: 'a car with a rounded hood', "windscreen shape": "I mentioned it here: 'a car with a rounded hood and windshield'", "boot shape": "I mentioned it here: 'let the hood be small and boot be rounded'"}}
Example 2
request: Generate a car with the following characteristics: length: 350 cm; width: 150 cm; height: 135 cm; wheel width: 15 cm; wheel radius: 35.15 cm; clearance height: 14 cm; bonnet size : large; bonnet shape : rounded; windscreen shape: rounded; boot shape: flat;
answer: {"rewritten request":"Generate a car with a length of 350 cm, a width of 150 cm and a height of 135 cm. Make a large rounded hood, a flat trunk and a rounded windshield. The wheels should have a radius of 35.15 cm and a width of 15 cm. The clearance should be 14 cm.",
"explanation":{"length": "I mentioned it here 'a car with a length of 350 cm'", "width":"I mentioned, that 'a width of 150 cm'", "height": "I mentioned, that 'a height of 135 cm'", "wheel width":"I mentioned it here: 'The wheels should have a radius of 35.15 cm and a width of 15 cm'", "wheel radius": "I mentioned it here: 'The wheels should have a radius of 35.15 cm and a width of 15 cm'", "clearance height": "I mentioned, that 'The clearance should be 14 cm'", "bonnet size": "I mentioned it here: 'Make a large rounded hood'", "bonnet shape":"I mentioned it here: 'Make a large rounded hood', "windscreen shape": "I mentioned it here: 'a rounded windshield'", "boot shape": "I mentioned it here: 'a flat trunk'"}}
Example 3
request: Generate a car with the following characteristics: 2 wheelsets;normal size boot; length: 250 cm; height: 135 cm; wheel radius: 25 cm;
answer: {"rewritten request":"Create a passenger car with a standard-sized trunk. It will be 2.5 meters long and 1 meter 35 centimeters high. The wheels should have a radius of 25 centimeters.",
"explanation":{"wheelsets count":"I mentioned it here: 'Create a passenger car'", "boot size":"I mentioned it here: 'standard-sized trunk'", "length":"I mentioned it here: 'It will be 2.5 meters long'", "height": "I mentioned it here: '1 meter 35 centimeters high'", "wheel radius": "I mentioned it here: 'The wheels should have a radius of 25 centimeters.'"}}
rewritten request: Create a passenger car with a standard-sized trunk. It will be 2.5 meters long and 1 meter 35 centimeters high. The wheels should have a radius of 25 centimeters.
Example 4
request: Generate a car with the following characteristics: body type: truck;
answer: {"rewritten request": "I want a random truck",
"explanation": {"body type":"I mentioned it here: 'a random truck'}}
Example 5
request: Generate a car with the following characteristics: normal size bonnet; length: 250 cm; width is small; height is small; wheel radius: 25 cm;
answer: {"rewritten request":"I want you to create a car with a wheel radius of 25 cm. Make it compact, but make it 2.5 meters long. Leave the hood of standard size.",
"explanation":{"bonnet size":"I mentioned it here: 'Leave the hood of standard size', "length": "I mentioned it here: 'make it 2.5 meters long'", "width":"I mentioned it here: 'Make it compact'", "height":"I mentioned it here: 'Make it compact'", "wheel radius": "I mentioned it here: 'a wheel radius of 25 cm'"}}
"""

# %%
gen_config = GenerationConfig.from_pretrained(text2text_model_name)
gen_config.max_length = 2048
prompt = """You receive a request to generate a car in the format "Generate a car with the following characteristics: name1:value1; name2:value2;...". This request contains a set of car characteristics. Rewrite this request into human language without losing information about the characteristics of the car. You must return a response in the following json format: {"rewritten request": here you must paste the rewritten request in human language, "explanation": here you should explain where in the human language query the information about a specific parameter is mentioned } Here are some examples:
Example 1
request: Generate a car with the following characteristics: length: 290 cm; width: 150 cm; height: 135 cm; wheel width: 27 cm; wheel radius: 36.6 cm; clearance height: 12 cm; bonnet size : small; bonnet shape : rounded; windscreen shape: rounded; boot shape: rounded;
answer: {"rewritten request":"Make me a car with a rounded hood and windshield, wheels with a radius of 36.6 cm and a width of 27 cm. The clearance should be 12 cm, the length 290 cm, the width 150 cm, the height 135 cm. Also let the hood be small and boot be rounded.",
"explanation":"I mentioned the clearance height, length, width and height here: 'clearance should be 12 cm, the length 290 cm, the width 150 cm, the height 135 cm'. I wrote about the wheel parameters here: 'wheels with a radius of 36.6 cm and a width of 27 cm'. Here I wrote about the hood: 'let the hood be small', 'a car with a rounded hood', about the windscreen: 'a rounded hood and windshield', and about the boot: 'boot be rounded'."}
Example 2
request: Generate a car with the following characteristics: length: 350 cm; width: 150 cm; height: 135 cm; wheel width: 15 cm; wheel radius: 35.15 cm; clearance height: 14 cm; bonnet size : large; bonnet shape : rounded; windscreen shape: rounded; boot shape: flat;
answer: {"rewritten request":"Generate a car with a length of 350 cm, a width of 150 cm and a height of 135 cm. Make a large rounded hood, a flat trunk and a rounded windshield. The wheels should have a radius of 35.15 cm and a width of 15 cm. The clearance should be 14 cm.",
"explanation":"I mentioned the length, width and height here: 'a length of 350 cm, a width of 150 cm and a height of 135 cm'. Wheel parameters have been mentioned here: 'The wheels should have a radius of 35.15 cm and a width of 15 cm'. Here I wrote about the clearance height: 'The clearance should be 14 cm', and here I wrote about the body shapes: 'Make a large rounded hood, a flat trunk and a rounded windshield'."}
Example 3
request: Generate a car with the following characteristics: 2 wheelsets;normal size boot; length: 250 cm; height: 135 cm; wheel radius: 25 cm;
answer: {"rewritten request":"Create a passenger car with a standard-sized trunk. It will be 2.5 meters long and 1 meter 35 centimeters high. The wheels should have a radius of 25 centimeters.",
"explanation":"I wrote 'Create a passenger car', because every passenger car has 2 wheelsets. 'standard-sized trunk' means normal size boot. Length and height are mentioned here: 'It will be 2.5 meters long and 1 meter 35 centimeters high'. And here I wrote about wheel radius: 'The wheels should have a radius of 25 centimeters'."}
Example 4
request: Generate a car with the following characteristics: body type: truck;
answer: {"rewritten request": "I want a random truck",
"explanation": "The request only mentions the body type, thats why I wrote 'random truck'."}
Example 5
request: Generate a car with the following characteristics: normal size bonnet; length: 250 cm; width is small; height is small; wheel radius: 25 cm;
answer: {"rewritten request":"I want you to create a car with a wheel radius of 25 cm. Make it compact, but make it 2.5 meters long. Leave the hood of standard size.",
"explanation":"I wrote 'Make it compact', because both width and height are small. I wrote about length here: 'make it 2.5 meters long'. Here I mentioned the wheel radius: 'wheel radius of 25 cm'. And here I wrote about the bonnet size: 'Leave the hood of standard size'."}
"""

# %%
train_nl = transform_to_nl(train_dataloader, 0, text2text_model, tokenizer, gen_config, prompt, "train_nl.json")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.

# %%
dataset["train"] = dataset["train"].add_column("natural_input_mistral", train_nl)

# %%
def fix_nl(row):
    return row

# %%
dataset["train"] = dataset["train"].map(fix_nl)

# %%
test_nl = transform_to_nl(test_dataloader, 0, text2text_model, tokenizer, gen_config, prompt, "test_nl.txt")
# Out:
#   0%|          | 0/101 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.

# %%
dataset["test"] = dataset["test"].add_column("natural_input_mistral", test_nl)

# %%
dataset["test"] = dataset["test"].map(fix_nl)
# Out:
# Map:   0%|          | 0/25769 [00:00<?, ? examples/s]

# %%
dataset.push_to_hub(dataset_name)
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/54 [00:00<?, ?ba/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/26 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/evgmaslov/cars/commit/69597e7885381c5415d966515efdecaa5e6dcff5', commit_message='Upload dataset', commit_description='', oid='69597e7885381c5415d966515efdecaa5e6dcff5', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/evgmaslov/cars', endpoint='https://huggingface.co', repo_type='dataset', repo_id='evgmaslov/cars'), pr_revision=None, pr_num=None)

# %% [markdown]
# ## Validate dataset

# %%
dataset = load_dataset(dataset_name)

# %%
poor_samples = []

# %%
print(dataset["train"][0]["natural_input"])
print(dataset["train"][0]["input"])
# Out:
# Make me a car that is compact and has a small trunk. The clearance should be low, the length should be short, the width 167 cm and the height should be low.
# Generate a car with the following characteristics: normal size boot; length is small; width: 167 cm; height is small; wheel radius is small

# %% [markdown]
# # Training

# %% [markdown]
# ## Prepare dataset

# %%
prompt = """You are an experienced engineer who designs cars. You know everything about the shape and size of cars. You know many different types of car bodies and understand their geometric characteristics. You help people get the car they need. You receive a request to create a car, which describes its shape, size, and other characteristics. To create a car, you use a C# class of the following structure:
public Car()
{
    Length = ...;
    Width = ...;
    Height = ...;

    WheelWidth = ...;
    WheelRadius = ...;

    WheelRelativeBiasAlongWidth = ...;
    WheelRelativeBiasesAlongLength = ...;

    WheelBaseSegmentsSpans = ...;
    WheelBaseSegmentsBottomSurfaces = ...;
    WheelBaseTopSurface = ...;
    GapBetweenWheelAndBase = ...;

    BodySegmentsSpans = ...;
    BodySegmentsTopSurfaces = ...;
}.
Here is a description of its parameters. "Length" is the length of the car in centimeters, this is a float type parameter. "Width" is the width of the car in centimeters, this is a float type parameter. "Height" is the width of the car in centimeters, this is a float type parameter. "WheelWidth" is the width of each wheel in centimeters, this is a float type parameter. "WheelRadius" is the radius of each wheel in centimeters, this is a float type parameter. "WheelRelativeBiasAlongWidth" is a parameter that determines how deep the wheel is shifted into the car body. For example, if WheelRelativeBiasAlongWidth = 0.1, then the wheel is shifted into the car by a distance equal to 10% of its width. This parameter is of float type. "WheelRelativeBiasesAlongLength" is a parameter that contains a list of numbers in floating point format. The number of values in the list is equal to the number of wheel pairs the car has. Each value is equal to the relative offset of a wheel pair relative to the front of the car. For example, if WheelRelativeBiasesAlongLength = new List<float>() { 0.2f, 0.8f }, then the car has two wheel pairs, one offset by 20% of the length, and the other by 80%. The "WheelBaseSegmentsSpans" parameter describes the arrangement of the parts of the car's floor. The floor of a car is the frame on which its wheels are mounted. Usually a car has one frame, but a truck can have 2 or more frames. This parameter contains a list where each element is a range of lengths in which the floor of the car is located. The range is described by a list where the first element is the start of the range and the second element is the end of the range. The WheelBaseSegmentsBottomSurfaces parameter describes the shape of the bottom of the car. If the bottom of the car consists of several planes, this parameter will contain several planes. This parameter contains as many planes as there are ranges specified in the "WheelBaseSegmentsSpans" parameter, because each plane has its own range. This parameter can be used to adjust the ground clearance of the car. The "BodySegmentsSpans" parameter contains a list of length ranges in which the vehicle body components are located. The "BodySegmentsTopSurfaces" parameter contains a list of the components of the car body. The number of components of the car is equal to the number of ranges in the "BodySegmentsSpans" parameter, because each component has its own range. Each component of the car is described by the shape of its surface. The shape can be specified by one of three classes: Constant (plain shape), CornerRounded (plain shape with rounded corners) and TotalRounded (rounded shape).
The user will ask you to generate a car and will provide you with a description of its shape and dimensions. You need to extract from his request the information needed to fill in the C# class parameters described above. Write C# class to generate a car, fill in its parameters according to the user's request. If the user has not specified specific dimensions or has provided insufficient information, use all your knowledge of car shapes and sizes to fill in the missing values and generate the correct car class. Here are some examples of what you need to do:
Example 1
user request: Design a car with a standard-sized hood and trunk. It should be 1.67 meters wide and have wheels with a radius of 40 cm.
car: using System.Collections.Generic;
using System;
using System.Collections;
namespace GenerativeDesign.Cars
{
    public class Car : CarBase
    {
        public Car()
        {
            Length = 250f;
            Width = 167f;
            Height = 150f;

            WheelWidth = 20f;
            WheelRadius = 40f;
            WheelRelativeBiasAlongWidth = 0.1f;
            WheelRelativeBiasesAlongLength = new List<float>() { 0.2f, 0.8f };

            WheelBaseSegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 1f } };
            WheelBaseSegmentsBottomSurfaces = new List<Line>() { new Constant(height: 13f) };
            WheelBaseTopSurface = new Constant(height: 90f);
            GapBetweenWheelAndBase = 3f;

            BodySegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 0.3f }, new List<float>(){ 0.3f, 0.8f }, new List<float>(){ 0.8f, 1f } };
            BodySegmentsTopSurfaces = new List<Line>() { new Constant(height: 105f), new Constant(height: 150f), new CornerRounded(minHeight: 90f, maxHeight: 105f, cornerRelativeLength: 0.2f, surfaceAbsoluteLength: 49.999996f, leftCornerRounded: false, rightCornerRounded: true) };
        }
    }

}
Example 2:
user request: Design a car with two wheelsets and a standard-sized hood. It should be 1.67 meters wide.
car: using System.Collections.Generic;
using System;
using System.Collections;
namespace GenerativeDesign.Cars
{
    public class Car : CarBase
    {
        public Car()
        {
            Length = 250f;
            Width = 167f;
            Height = 150f;

            WheelWidth = 20f;
            WheelRadius = 25f;
            WheelRelativeBiasAlongWidth = 0.1f;
            WheelRelativeBiasesAlongLength = new List<float>() { 0.2f, 0.8f };

            WheelBaseSegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 1f } };
            WheelBaseSegmentsBottomSurfaces = new List<Line>() { new Constant(height: 18f) };
            WheelBaseTopSurface = new Constant(height: 75f);
            GapBetweenWheelAndBase = 3f;

            BodySegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 0.3f }, new List<float>(){ 0.3f, 0.9f }, new List<float>(){ 0.9f, 1f } };
            BodySegmentsTopSurfaces = new List<Line>() { new TotalRounded(minHeight: 75f, maxHeight: 90f, leftRounded: true), new Constant(height: 150f), new CornerRounded(minHeight: 75f, maxHeight: 90f, cornerRelativeLength: 0.2f, surfaceAbsoluteLength: 25.000006f, leftCornerRounded: false, rightCornerRounded: true) };
        }
    }

}
Example 3: 
user request: Design a compact sedan. It should be short and narrow, with a small height.
car: using System.Collections.Generic;
using System;
using System.Collections;
namespace GenerativeDesign.Cars
{
    public class Car : CarBase
    {
        public Car()
        {
            Length = 250f;
            Width = 167f;
            Height = 135f;

            WheelWidth = 20f;
            WheelRadius = 25f;
            WheelRelativeBiasAlongWidth = 0.1f;
            WheelRelativeBiasesAlongLength = new List<float>() { 0.2f, 0.8f };

            WheelBaseSegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 1f } };
            WheelBaseSegmentsBottomSurfaces = new List<Line>() { new Constant(height: 13f) };
            WheelBaseTopSurface = new Constant(height: 67.5f);
            GapBetweenWheelAndBase = 3f;

            BodySegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 0.2f }, new List<float>(){ 0.2f, 0.8f }, new List<float>(){ 0.8f, 1f } };
            BodySegmentsTopSurfaces = new List<Line>() { new CornerRounded(minHeight: 67.5f, maxHeight: 94.5f, cornerRelativeLength: 0.2f, surfaceAbsoluteLength: 50f, leftCornerRounded: true, rightCornerRounded: false), new CornerRounded(minHeight: 94.5f, maxHeight: 135f, cornerRelativeLength: 0.2f, surfaceAbsoluteLength: 150f, leftCornerRounded: true, rightCornerRounded: true), new CornerRounded(minHeight: 67.5f, maxHeight: 94.5f, cornerRelativeLength: 0.2f, surfaceAbsoluteLength: 49.999996f, leftCornerRounded: false, rightCornerRounded: true) };
        }
    }

}
Example 4:
user request: Design a car with two wheelsets, a standard-sized hood, and a height of 1.35 meters. Ensure the wheel radius is large.
car: using System.Collections.Generic;
using System;
using System.Collections;
namespace GenerativeDesign.Cars
{
    public class Car : CarBase
    {
        public Car()
        {
            Length = 250f;
            Width = 167f;
            Height = 135f;

            WheelWidth = 20f;
            WheelRadius = 40f;
            WheelRelativeBiasAlongWidth = 0.1f;
            WheelRelativeBiasesAlongLength = new List<float>() { 0.2f, 0.8f };

            WheelBaseSegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 1f } };
            WheelBaseSegmentsBottomSurfaces = new List<Line>() { new Constant(height: 18f) };
            WheelBaseTopSurface = new Constant(height: 94.5f);
            GapBetweenWheelAndBase = 3f;

            BodySegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 0.2f }, new List<float>(){ 0.2f, 0.8f }, new List<float>(){ 0.8f, 1f } };
            BodySegmentsTopSurfaces = new List<Line>() { new TotalRounded(minHeight: 94.5f, maxHeight: 108f, leftRounded: true), new CornerRounded(minHeight: 108f, maxHeight: 135f, cornerRelativeLength: 0.2f, surfaceAbsoluteLength: 150f, leftCornerRounded: true, rightCornerRounded: true), new TotalRounded(minHeight: 94.5f, maxHeight: 108f, leftRounded: false) };
        }
    }

}"""

# %%
tokenizer = AutoTokenizer.from_pretrained(text2code_model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# %% [markdown]
# For mistral-nemo fix bug in chat template

# %%
tokenizer.chat_template = """{%- if messages[0][\"role\"] == \"system\" %}\n    {%- set system_message = messages[0][\"content\"] %}\n    {%- set loop_messages = messages[1:] %}\n{%- else %}\n    {%- set loop_messages = messages %}\n{%- endif %}\n{%- if not tools is defined %}\n    {%- set tools = none %}\n{%- endif %}\n{%- set user_messages = loop_messages | selectattr(\"role\", \"equalto\", \"user\") | list %}\n\n{#- This block checks for alternating user/assistant messages, skipping tool calling messages #}\n{%- set ns = namespace() %}\n{%- set ns.index = 0 %}\n{%- for message in loop_messages %}\n    {%- if not (message.role == \"tool\" or message.role == \"tool_results\" or (message.tool_calls is defined and message.tool_calls is not none)) %}\n        {%- if (message[\"role\"] == \"user\") != (ns.index % 2 == 0) %}\n            {{- raise_exception(\"After the optional system message, conversation roles must alternate user/assistant/user/assistant/...\") }}\n        {%- endif %}\n        {%- set ns.index = ns.index + 1 %}\n    {%- endif %}\n{%- endfor %}\n\n{{- bos_token }}\n{%- for message in loop_messages %}\n    {%- if message[\"role\"] == \"user\" %}\n        {%- if tools is not none and (message == user_messages[-1]) %}\n            {{- \"[AVAILABLE_TOOLS][\" }}\n            {%- for tool in tools %}\n                {%- set tool = tool.function %}\n                {{- '{\"type\": \"function\", \"function\": {' }}\n                {%- for key, val in tool.items() if key != \"return\" %}\n                    {%- if val is string %}\n                        {{- '\"' + key + '\": \"' + val + '\"' }}\n                    {%- else %}\n                        {{- '\"' + key + '\": ' + val|tojson }}\n                    {%- endif %}\n                    {%- if not loop.last %}\n                        {{- \", \" }}\n                    {%- endif %}\n                {%- endfor %}\n                {{- \"}}\" }}\n                {%- if not loop.last %}\n                    {{- \", \" }}\n                {%- else %}\n                    {{- \"]\" }}\n                {%- endif %}\n            {%- endfor %}\n            {{- \"[/AVAILABLE_TOOLS]\" }}\n            {%- endif %}\n        {%- if system_message is defined %}\n            {{- \"[INST]\" + system_message + \"\\n\\n\" + message[\"content\"] + \"[/INST]\" }}\n        {%- else %}\n            {{- \"[INST]\" + message[\"content\"] + \"[/INST]\" }}\n        {%- endif %}\n    {%- elif (message.tool_calls is defined and message.tool_calls is not none) %}\n        {{- \"[TOOL_CALLS][\" }}\n        {%- for tool_call in message.tool_calls %}\n            {%- set out = tool_call.function|tojson %}\n            {{- out[:-1] }}\n            {%- if not tool_call.id is defined or tool_call.id|length != 9 %}\n                {{- raise_exception(\"Tool call IDs should be alphanumeric strings with length 9!\") }}\n            {%- endif %}\n            {{- ', \"id\": \"' + tool_call.id + '\"}' }}\n            {%- if not loop.last %}\n                {{- \", \" }}\n            {%- else %}\n                {{- \"]\" + eos_token }}\n            {%- endif %}\n        {%- endfor %}\n    {%- elif message[\"role\"] == \"assistant\" %}\n        {{- message[\"content\"] + eos_token}}\n    {%- elif message[\"role\"] == \"tool_results\" or message[\"role\"] == \"tool\" %}\n        {%- if message.content is defined and message.content.content is defined %}\n            {%- set content = message.content.content %}\n        {%- else %}\n            {%- set content = message.content %}\n        {%- endif %}\n        {{- '[TOOL_RESULTS]{\"content\": ' + content|string + \", \" }}\n        {%- if not message.tool_call_id is defined or message.tool_call_id|length != 9 %}\n            {{- raise_exception(\"Tool call IDs should be alphanumeric strings with length 9!\") }}\n        {%- endif %}\n        {{- '\"call_id\": \"' + message.tool_call_id + '\"}[/TOOL_RESULTS]' }}\n    {%- else %}\n        {{- raise_exception(\"Only user and assistant roles are supported, with the exception of an initial optional system message!\") }}\n    {%- endif %}\n{%- endfor %}\n"""

# %%
dataset = dataset.filter(clean_dataset)

# %%
dataset = dataset.map(lambda row: generate_train_text(row, tokenizer))
# Out:
# Map:   0%|          | 0/33866 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 dataset = dataset.map(lambda row: generate_train_text(row, tokenizer))
#
# File ~/.mlspace/envs/leap71/lib/python3.10/site-packages/datasets/dataset_dict.py:866, in DatasetDict.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_names, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, desc)
#     863 if cache_file_names is None:
#     864     cache_file_names = {k: None for k in self}
#     865 return DatasetDict(
# --> 866     {
#     867         k: dataset.map(
#     868             function=function,
#     869             with_indices=with_indices,
#     870             with_rank=with_rank,
#     871             input_columns=input_columns,
#     872             batched=batched,
#     873             batch_size=batch_size,
#     874             drop_last_batch=drop_last_batch,
#     875             remove_columns=remove_columns,
#     876             keep_in_memory=keep_in_memory,
#     877             load_from_cache_file=load_from_cache_file,
#     878             cache_file_name=cache_file_names[k],
#     879             writer_batch_size=writer_batch_size,
#     880             features=features,
#     881             disable_nullable=disable_nullable,
#     882             fn_kwargs=fn_kwargs,
#     883             num_proc=num_proc,
#     884             desc=desc,
#     885         )
#     886         for k, dataset in self.items()
#     887     }
#     888 )
#
# File ~/.mlspace/envs/leap71/lib/python3.10/site-packages/datasets/dataset_dict.py:867, in <dictcomp>(.0)
#     863 if cache_file_names is None:
#     864     cache_file_names = {k: None for k in self}
#     865 return DatasetDict(
#     866     {
# --> 867         k: dataset.map(
#     868             function=function,
#     869             with_indices=with_indices,
#     870             with_rank=with_rank,
#     871             input_columns=input_columns,
#     872             batched=batched,
#     873             batch_size=batch_size,
#     874             drop_last_batch=drop_last_batch,
#     875             remove_columns=remove_columns,
#     876             keep_in_memory=keep_in_memory,
#     877             load_from_cache_file=load_from_cache_file,
#     878             cache_file_name=cache_file_names[k],
#     879             writer_batch_size=writer_batch_size,
#     880             features=features,
#     881             disable_nullable=disable_nullable,
#     882             fn_kwargs=fn_kwargs,
#     883             num_proc=num_proc,
#     884             desc=desc,
#     885         )
#     886         for k, dataset in self.items()
#     887     }
#     888 )
#
# File ~/.mlspace/envs/leap71/lib/python3.10/site-packages/datasets/arrow_dataset.py:560, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     553 self_format = {
#     554     "type": self._format_type,
#     555     "format_kwargs": self._format_kwargs,
#     556     "columns": self._format_columns,
#     557     "output_all_columns": self._output_all_columns,
#     558 }
#     559 # apply actual function
# --> 560 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     561 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     562 # re-apply format to the output
#
# File ~/.mlspace/envs/leap71/lib/python3.10/site-packages/datasets/arrow_dataset.py:3035, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    3029 if transformed_dataset is None:
#    3030     with hf_tqdm(
#    3031         unit=" examples",
#    3032         total=pbar_total,
#    3033         desc=desc or "Map",
#    3034     ) as pbar:
# -> 3035         for rank, done, content in Dataset._map_single(**dataset_kwargs):
#    3036             if done:
#    3037                 shards_done += 1
#
# File ~/.mlspace/envs/leap71/lib/python3.10/site-packages/datasets/arrow_dataset.py:3408, in Dataset._map_single(shard, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset)
#    3406 _time = time.time()
#    3407 for i, example in shard_iterable:
# -> 3408     example = apply_function_on_filtered_inputs(example, i, offset=offset)
#    3409     if update_data:
#    3410         if i == 0:
#
# File ~/.mlspace/envs/leap71/lib/python3.10/site-packages/datasets/arrow_dataset.py:3300, in Dataset._map_single.<locals>.apply_function_on_filtered_inputs(pa_inputs, indices, check_same_num_examples, offset)
#    3298 if with_rank:
#    3299     additional_args += (rank,)
# -> 3300 processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)
#    3301 if isinstance(processed_inputs, LazyDict):
#    3302     processed_inputs = {
#    3303         k: v for k, v in processed_inputs.data.items() if k not in processed_inputs.keys_to_format
#    3304     }
#
# Cell In[19], line 1, in <lambda>(row)
# ----> 1 dataset = dataset.map(lambda row: generate_train_text(row, tokenizer))
#
# NameError: name 'tokenizer' is not defined

# %% [markdown]
# ## Init model

# %%
quant_config = BitsAndBytesConfig(load_in_4bit=True,
                                  bnb_4bit_compute_dtype=torch.float16,
                                  bnb_4bit_quant_type="nf4",
                                  bnb_4bit_use_double_quant=True)
peft_params = LoraConfig(
    lora_alpha=16, lora_dropout=0.1, r=64, bias="none", task_type="CAUSAL_LM")

# %%
model = AutoModelForCausalLM.from_pretrained(text2code_model_name,
                                             quantization_config=quant_config,
                                             device_map='auto',
                                  low_cpu_mem_usage=True, offload_state_dict=True)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# ## Train

# %%
os.environ["WANDB_PROJECT"]="leap71"
os.environ["WANDB_LOG_MODEL"] = "checkpoint"

# %%
resume_from_checkpoint=False
training_params = TrainingArguments(
    output_dir=text2code_tuned_model_name,
    num_train_epochs=1,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    gradient_accumulation_steps=1,
    optim="paged_adamw_32bit",
    save_steps=100, 
    learning_rate=3e-5, weight_decay=0.001,
    fp16=False, bf16=False,
    max_grad_norm=0.3,
    max_steps=-1, warmup_ratio=0.01,
    group_by_length=True, lr_scheduler_type='cosine_with_restarts',
    lr_scheduler_kwargs={"num_cycles":5},
    report_to="wandb",
    save_total_limit=2,
    eval_strategy="steps",
    eval_steps=100,
    push_to_hub=True,
    hub_strategy="checkpoint",
    resume_from_checkpoint=resume_from_checkpoint,
    run_name="natural_language_to_code_1")
trainer = SFTTrainer(
    model=model,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"].select(range(32)),
    peft_config=peft_params,
    dataset_text_field="text",
    max_seq_length=None,
    tokenizer=tokenizer,
    args=training_params, packing=False)
wandb_callback = LLMSampleCB(trainer, dataset["test"], num_samples=2, max_new_tokens=2048)
trainer.add_callback(wandb_callback)
# Out:
# /home/jovyan/.mlspace/envs/leap71/lib/python3.10/site-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in '__init__': dataset_text_field. Will not be supported from version '1.0.0'.
#
# Deprecated positional argument(s) used in SFTTrainer, please use the SFTConfig to set these arguments instead.
#   warnings.warn(message, FutureWarning)
# /home/jovyan/.mlspace/envs/leap71/lib/python3.10/site-packages/trl/trainer/sft_trainer.py:292: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# /home/jovyan/.mlspace/envs/leap71/lib/python3.10/site-packages/trl/trainer/sft_trainer.py:321: UserWarning: You passed a `dataset_text_field` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# Map:   0%|          | 0/53280 [00:00<?, ? examples/s]
# Map:   0%|          | 0/32 [00:00<?, ? examples/s]
# Detected kernel version 5.4.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.

# %%
# !wandb login
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# wandb: Currently logged in as: free001style. Use `wandb login --relogin` to force relogin

# %%
wandb.init("leap71")
if resume_from_checkpoint:
  #trainer.train(resume_from_checkpoint=text2code_tuned_model_name + "/last-checkpoint")
  trainer.train(resume_from_checkpoint=text2code_tuned_model_name + "/checkpoint-10000")
else:
  trainer.train()
# Out:
# Finishing last run (ID:dfjd8r1t) before initializing another...
# VBox(children=(Label(value='0.005 MB of 0.005 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">fragrant-feather-19</strong> at: <a href='https://wandb.ai/evg_maslov/leap71/runs/dfjd8r1t' target="_blank">https://wandb.ai/evg_maslov/leap71/runs/dfjd8r1t</a><br/> View project at: <a href='https://wandb.ai/evg_maslov/leap71' target="_blank">https://wandb.ai/evg_maslov/leap71</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241003_123924-dfjd8r1t/logs</code>
# Successfully finished last run (ID:dfjd8r1t). Initializing new run:<br/>
# Tracking run with wandb version 0.18.2
# Run data is saved locally in <code>/home/jovyan/maslov/wandb/run-20241003_124015-uv8r6axt</code>
# Syncing run <strong><a href='https://wandb.ai/evg_maslov/leap71/runs/uv8r6axt' target="_blank">wobbly-breeze-20</a></strong> to <a href='https://wandb.ai/evg_maslov/leap71' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/evg_maslov/leap71' target="_blank">https://wandb.ai/evg_maslov/leap71</a>
#  View run at <a href='https://wandb.ai/evg_maslov/leap71/runs/uv8r6axt' target="_blank">https://wandb.ai/evg_maslov/leap71/runs/uv8r6axt</a>
# /home/jovyan/.mlspace/envs/leap71/lib/python3.10/site-packages/transformers/trainer.py:3262: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(os.path.join(checkpoint, OPTIMIZER_NAME), map_location=map_location)
# /home/jovyan/.mlspace/envs/leap71/lib/python3.10/site-packages/transformers/trainer.py:2944: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint_rng_state = torch.load(rng_file)
#     <div>
#
#       <progress value='15182' max='39960' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [15182/39960 9:03:30 < 43:19:48, 0.16 it/s, Epoch 1.14/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10500</td>
#       <td>0.049800</td>
#       <td>0.316373</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.050100</td>
#       <td>0.298745</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.049700</td>
#       <td>0.314826</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.048800</td>
#       <td>0.310907</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.048600</td>
#       <td>0.290600</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.047500</td>
#       <td>0.296261</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.047800</td>
#       <td>0.295860</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.047300</td>
#       <td>0.291479</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.047600</td>
#       <td>0.285518</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.046500</td>
#       <td>0.292918</td>
#     </tr>
#   </tbody>
# </table><p>
#   0%|          | 0/2 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# wandb: Adding directory to artifact (./evgmaslov/Code-Llama-3-8B-cars/checkpoint-10500)... Done. 1.4s
# wandb: Adding directory to artifact (./evgmaslov/Code-Llama-3-8B-cars/checkpoint-10500)... Done. 1.4s
#   0%|          | 0/2 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# wandb: Adding directory to artifact (./evgmaslov/Code-Llama-3-8B-cars/checkpoint-11000)... Done. 1.7s
# wandb: Adding directory to artifact (./evgmaslov/Code-Llama-3-8B-cars/checkpoint-11000)... Done. 1.3s
#   0%|          | 0/2 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# wandb: Adding directory to artifact (./evgmaslov/Code-Llama-3-8B-cars/checkpoint-12000)... Done. 1.6s
# wandb: Adding directory to artifact (./evgmaslov/Code-Llama-3-8B-cars/checkpoint-12000)... Done. 1.4s
#   0%|          | 0/2 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# wandb: Adding directory to artifact (./evgmaslov/Code-Llama-3-8B-cars/checkpoint-12500)... Done. 1.6s
# wandb: Adding directory to artifact (./evgmaslov/Code-Llama-3-8B-cars/checkpoint-12500)... Done. 1.4s
#   0%|          | 0/2 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# wandb: Adding directory to artifact (./evgmaslov/Code-Llama-3-8B-cars/checkpoint-13000)... Done. 2.5s
# wandb: Adding directory to artifact (./evgmaslov/Code-Llama-3-8B-cars/checkpoint-13000)... Done. 1.7s
#   0%|          | 0/2 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# wandb: Adding directory to artifact (./evgmaslov/Code-Llama-3-8B-cars/checkpoint-13500)... Done. 1.7s
# wandb: Adding directory to artifact (./evgmaslov/Code-Llama-3-8B-cars/checkpoint-13500)... Done. 1.3s
#   0%|          | 0/2 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# wandb: Adding directory to artifact (./evgmaslov/Code-Llama-3-8B-cars/checkpoint-14500)... Done. 1.8s
# wandb: Adding directory to artifact (./evgmaslov/Code-Llama-3-8B-cars/checkpoint-14500)... Done. 1.4s
#   0%|          | 0/2 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# wandb: Adding directory to artifact (./evgmaslov/Code-Llama-3-8B-cars/checkpoint-15000)... Done. 1.4s
# wandb: Adding directory to artifact (./evgmaslov/Code-Llama-3-8B-cars/checkpoint-15000)... Done. 1.3s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 4
#       1 wandb.init("leap71")
#       2 if resume_from_checkpoint:
#       3   #trainer.train(resume_from_checkpoint=text2code_tuned_model_name + "/last-checkpoint")
# ----> 4   trainer.train(resume_from_checkpoint=text2code_tuned_model_name + "/checkpoint-10000")
#       5 else:
#       6   trainer.train()
#
# File ~/.mlspace/envs/leap71/lib/python3.10/site-packages/trl/trainer/sft_trainer.py:434, in SFTTrainer.train(self, *args, **kwargs)
#     431 if self.neftune_noise_alpha is not None and not self._trainer_supports_neftune:
#     432     self.model = self._trl_activate_neftune(self.model)
# --> 434 output = super().train(*args, **kwargs)
#     436 # After training we make sure to retrieve back the original forward pass method
#     437 # for the embedding layer by removing the forward post hook.
#     438 if self.neftune_noise_alpha is not None and not self._trainer_supports_neftune:
#
# File ~/.mlspace/envs/leap71/lib/python3.10/site-packages/transformers/trainer.py:2043, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2040 try:
#    2041     # Disable progress bars when uploading models during checkpoints to avoid polluting stdout
#    2042     hf_hub_utils.disable_progress_bars()
# -> 2043     return inner_training_loop(
#    2044         args=args,
#    2045         resume_from_checkpoint=resume_from_checkpoint,
#    2046         trial=trial,
#    2047         ignore_keys_for_eval=ignore_keys_for_eval,
#    2048     )
#    2049 finally:
#    2050     hf_hub_utils.enable_progress_bars()
#
# File ~/.mlspace/envs/leap71/lib/python3.10/site-packages/transformers/trainer.py:2388, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2385     self.control = self.callback_handler.on_step_begin(args, self.state, self.control)
#    2387 with self.accelerator.accumulate(model):
# -> 2388     tr_loss_step = self.training_step(model, inputs)
#    2390 if (
#    2391     args.logging_nan_inf_filter
#    2392     and not is_torch_xla_available()
#    2393     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2394 ):
#    2395     # if loss is nan or inf simply add the average of previous logged losses
#    2396     tr_loss += tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/.mlspace/envs/leap71/lib/python3.10/site-packages/transformers/trainer.py:3518, in Trainer.training_step(***failed resolving arguments***)
#    3516         scaled_loss.backward()
#    3517 else:
# -> 3518     self.accelerator.backward(loss, **kwargs)
#    3520 return loss.detach() / self.args.gradient_accumulation_steps
#
# File ~/.mlspace/envs/leap71/lib/python3.10/site-packages/accelerate/accelerator.py:2196, in Accelerator.backward(self, loss, **kwargs)
#    2194     self.lomo_backward(loss, learning_rate)
#    2195 else:
# -> 2196     loss.backward(**kwargs)
#
# File ~/.mlspace/envs/leap71/lib/python3.10/site-packages/torch/_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File ~/.mlspace/envs/leap71/lib/python3.10/site-packages/torch/autograd/__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File ~/.mlspace/envs/leap71/lib/python3.10/site-packages/torch/autograd/graph.py:768, in _engine_run_backward(t_outputs, *args, **kwargs)
#     766     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     767 try:
# --> 768     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     769         t_outputs, *args, **kwargs
#     770     )  # Calls into the C++ engine to run the backward pass
#     771 finally:
#     772     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# # Inference

# %%
tokenizer = AutoTokenizer.from_pretrained(text2code_model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
tokenizer.chat_template = """{%- if messages[0][\"role\"] == \"system\" %}\n    {%- set system_message = messages[0][\"content\"] %}\n    {%- set loop_messages = messages[1:] %}\n{%- else %}\n    {%- set loop_messages = messages %}\n{%- endif %}\n{%- if not tools is defined %}\n    {%- set tools = none %}\n{%- endif %}\n{%- set user_messages = loop_messages | selectattr(\"role\", \"equalto\", \"user\") | list %}\n\n{#- This block checks for alternating user/assistant messages, skipping tool calling messages #}\n{%- set ns = namespace() %}\n{%- set ns.index = 0 %}\n{%- for message in loop_messages %}\n    {%- if not (message.role == \"tool\" or message.role == \"tool_results\" or (message.tool_calls is defined and message.tool_calls is not none)) %}\n        {%- if (message[\"role\"] == \"user\") != (ns.index % 2 == 0) %}\n            {{- raise_exception(\"After the optional system message, conversation roles must alternate user/assistant/user/assistant/...\") }}\n        {%- endif %}\n        {%- set ns.index = ns.index + 1 %}\n    {%- endif %}\n{%- endfor %}\n\n{{- bos_token }}\n{%- for message in loop_messages %}\n    {%- if message[\"role\"] == \"user\" %}\n        {%- if tools is not none and (message == user_messages[-1]) %}\n            {{- \"[AVAILABLE_TOOLS][\" }}\n            {%- for tool in tools %}\n                {%- set tool = tool.function %}\n                {{- '{\"type\": \"function\", \"function\": {' }}\n                {%- for key, val in tool.items() if key != \"return\" %}\n                    {%- if val is string %}\n                        {{- '\"' + key + '\": \"' + val + '\"' }}\n                    {%- else %}\n                        {{- '\"' + key + '\": ' + val|tojson }}\n                    {%- endif %}\n                    {%- if not loop.last %}\n                        {{- \", \" }}\n                    {%- endif %}\n                {%- endfor %}\n                {{- \"}}\" }}\n                {%- if not loop.last %}\n                    {{- \", \" }}\n                {%- else %}\n                    {{- \"]\" }}\n                {%- endif %}\n            {%- endfor %}\n            {{- \"[/AVAILABLE_TOOLS]\" }}\n            {%- endif %}\n        {%- if system_message is defined %}\n            {{- \"[INST]\" + system_message + \"\\n\\n\" + message[\"content\"] + \"[/INST]\" }}\n        {%- else %}\n            {{- \"[INST]\" + message[\"content\"] + \"[/INST]\" }}\n        {%- endif %}\n    {%- elif (message.tool_calls is defined and message.tool_calls is not none) %}\n        {{- \"[TOOL_CALLS][\" }}\n        {%- for tool_call in message.tool_calls %}\n            {%- set out = tool_call.function|tojson %}\n            {{- out[:-1] }}\n            {%- if not tool_call.id is defined or tool_call.id|length != 9 %}\n                {{- raise_exception(\"Tool call IDs should be alphanumeric strings with length 9!\") }}\n            {%- endif %}\n            {{- ', \"id\": \"' + tool_call.id + '\"}' }}\n            {%- if not loop.last %}\n                {{- \", \" }}\n            {%- else %}\n                {{- \"]\" + eos_token }}\n            {%- endif %}\n        {%- endfor %}\n    {%- elif message[\"role\"] == \"assistant\" %}\n        {{- message[\"content\"] + eos_token}}\n    {%- elif message[\"role\"] == \"tool_results\" or message[\"role\"] == \"tool\" %}\n        {%- if message.content is defined and message.content.content is defined %}\n            {%- set content = message.content.content %}\n        {%- else %}\n            {%- set content = message.content %}\n        {%- endif %}\n        {{- '[TOOL_RESULTS]{\"content\": ' + content|string + \", \" }}\n        {%- if not message.tool_call_id is defined or message.tool_call_id|length != 9 %}\n            {{- raise_exception(\"Tool call IDs should be alphanumeric strings with length 9!\") }}\n        {%- endif %}\n        {{- '\"call_id\": \"' + message.tool_call_id + '\"}[/TOOL_RESULTS]' }}\n    {%- else %}\n        {{- raise_exception(\"Only user and assistant roles are supported, with the exception of an initial optional system message!\") }}\n    {%- endif %}\n{%- endfor %}\n"""

# %%
quant_config = BitsAndBytesConfig(load_in_4bit=True,
                                  bnb_4bit_compute_dtype=torch.float16,
                                  bnb_4bit_quant_type="nf4",
                                  bnb_4bit_use_double_quant=True)
peft_params = LoraConfig(
    lora_alpha=16, lora_dropout=0.1, r=64, bias="none", task_type="CAUSAL_LM")

# %%
model = AutoModelForCausalLM.from_pretrained(text2code_model_name,
                                             quantization_config=quant_config,
                                             device_map='auto',
                                  low_cpu_mem_usage=True, offload_state_dict=True)
# Out:
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
model = PeftModel.from_pretrained(model, "evgmaslov/exp7-Mistral-Nemo-Instruct-2407-cars")

# %%
model.push_to_hub(text2code_tuned_model_name)
# Out:
# CommitInfo(commit_url='https://huggingface.co/evgmaslov/Mistral-Nemo-Instruct-2407-cars/commit/bc542a155f0691ec8330875bfe649cbbac8b2af7', commit_message='Upload model', commit_description='', oid='bc542a155f0691ec8330875bfe649cbbac8b2af7', pr_url=None, repo_url=RepoUrl('https://huggingface.co/evgmaslov/Mistral-Nemo-Instruct-2407-cars', endpoint='https://huggingface.co', repo_type='model', repo_id='evgmaslov/Mistral-Nemo-Instruct-2407-cars'), pr_revision=None, pr_num=None)

# %%
user_prompt = "Craft a hatchback with the length of 3.5 metres and the door at the rear."
gen_config = GenerationConfig.from_pretrained(text2code_model_name)
gen_config.max_length = 4096
output = generate(model, tokenizer, gen_config, get_inference_text(prompt, user_prompt, tokenizer))
print(output[0])
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Here's a C# class representing a hatchback car with the specified dimensions and characteristics. I've justified each parameter choice below the class.
#
# ```csharp
# using System.Collections.Generic;
# using System;
# using System.Collections;
#
# namespace GenerativeDesign.Cars
# {
#     public class Hatchback : CarBase
#     {
#         public Hatchback()
#         {
#             Length = 350f;
#             Width = 167f;
#             Height = 165f;
#
#             WheelWidth = 20f;
#             WheelRadius = 30f;
#             WheelRelativeBiasAlongWidth = 0.1f;
#             WheelRelativeBiasesAlongLength = new List<float>() { 0f, 0.6f, 1f };
#
#             WheelBaseSegmentsSpans = new List<List<float>>()
#             {
#                 new List<float>() { 0f, 0.2f },
#                 new List<float>() { 0.2f, 0.8f },
#                 new List<float>() { 0.8f, 1f }
#             };
#             WheelBaseSegmentsBottomSurfaces = new List<Line>()
#             {
#                 new Constant(height: 15f),
#                 new Constant(height: 20f),
#                 new Constant(height: 15f)
#             };
#             WheelBaseTopSurface = new Constant(height: 80f);
#             GapBetweenWheelAndBase = 5f;
#
#             BodySegmentsSpans = new List<List<float>>()
#             {
#                 new List<float>() { 0f, 0.1f },
#                 new List<float>() { 0.1f, 0.7f },
#                 new List<float>() { 0.7f, 0.9f },
#                 new List<float>() { 0.9f, 1f }
#             };
#             BodySegmentsTopSurfaces = new List<Line>()
#             {
#                 new CornerRounded(minHeight: 80f, maxHeight: 100f, cornerRelativeLength: 0.1f, surfaceAbsoluteLength: 33.4f, leftCornerRounded: true, rightCornerRounded: true),
#                 new Constant(height: 120f),
#                 new CornerRounded(minHeight: 120f, maxHeight: 165f, cornerRelativeLength: 0.1f, surfaceAbsoluteLength: 67f, leftCornerRounded: true, rightCornerRounded: true),
#                 new TotalRounded(minHeight: 120f, maxHeight: 140f, leftRounded: false)
#             };
#         }
#     }
# }
# ```
#
# Justifications:
#
# 1. **Length (350 cm)**: The user requested a length of 3.5 meters, which is 350 cm.
# 2. **Width (167 cm) and Height (165 cm)**: Standard width and height for a regular car. The height is increased by 10 cm to account for the hatchback door.
# 3. **WheelWidth (20 cm) and WheelRadius (30 cm)**: Standard wheel width and radius. The radius is increased to ensure sufficient ground clearance for the hatchback floor.
# 4. **WheelRelativeBiasAlongWidth (0.1f)**: The wheel is shifted inward by 10% of its width.
# 5. **WheelRelativeBiasesAlongLength (new List<float>() { 0f, 0.6f, 1f })**: The car has two wheel pairs, one at the front (0% offset) and one at the rear (60% offset) to accommodate the hatchback door.
# 6. **WheelBaseSegmentsSpans and WheelBaseSegmentsBottomSurfaces**: The floor of the car consists of three parts: the front part (20% of the length), the raised part (60% of the length) for the passenger compartment, and the rear part (20% of the length) that includes the hatchback floor. The raised part has a higher bottom surface (20 cm) to accommodate the engine and transmission components.
# 7. **WheelBaseTopSurface (Constant(height: 80f)) and GapBetweenWheelAndBase (5f)**: The top of the wheel base is a plain surface with a height of 80 cm and a gap of 5 cm between the wheel and the floor.
# 8. **BodySegmentsSpans and BodySegmentsTopSurfaces**: The car body consists of four components: the hood, the windshield and roof, the door and side panels, and the trunk/lid. The trunk/lid component has a rounded top surface to accommodate the hatchback door.

# %% [markdown]
# ## Inference on the test set

# %%
dataset = load_dataset(dataset_name)

with open("train_nl.json", "r") as f:
    data = json.load(f)
small_dataset = {"input":[], "natural_input":[], "output":[], "text": []}
keys = [int(k) for k in data.keys()]
sorted_keys = sorted(keys)
for ind in tqdm(sorted_keys):
    natural_input = ""
    try:
        natural_input = json.loads(data[str(ind)])["rewritten request"]
    except:
        continue
    if natural_input != "":
        row = dataset["train"][ind]
        small_dataset["input"].append(row["input"])
        small_dataset["output"].append(row["output"])
        small_dataset["text"].append("")
        small_dataset["natural_input"].append(natural_input)
small_dataset = Dataset.from_dict(small_dataset)
print(f"Dataset length: {len(small_dataset)}")
small_dataset = small_dataset.train_test_split(test_size=0.05, seed=42)
# Out:
#   0%|          | 0/13462 [00:00<?, ?it/s]
# Dataset length: 13442

# %%
small_dataset["test"]["natural_input"][232]
# Out:
# 'Craft a compact, two-wheeled vehicle. It should measure 1.67 meters in width and 1.35 meters in height, with small-radius wheels.'

# %%
gen_config = GenerationConfig.from_pretrained(text2code_model_name)
gen_config.max_length = 4096

# %%
def inference_on_test(dataset, batch_size, text2text_model, tokenizer, gen_config, prompt, path):
  natural_inputs = {}
  if os.path.exists(path):
      with open(path, "r") as f:
        current = json.load(f)
        for key in current.keys():
            natural_inputs[key] = current[key]
  n_batches = int(len(dataset)/batch_size)
  if n_batches * batch_size < len(dataset):
      n_batches += 1
  for i in range(n_batches):
      rest_inds = [ind for ind in range(len(dataset)) if str(ind) not in natural_inputs]
      if len(rest_inds) == 0:
          continue
      if len(rest_inds) < batch_size:
          inds = rest_inds
      else:
          inds = random.sample(rest_inds, batch_size)
      batch = dataset.select(inds)
      prompts = [get_inference_text(prompt, inp, tokenizer) for inp in batch["input"]]
      generations = generate(text2text_model, tokenizer, gen_config, prompts)
      
      for ind, pos in enumerate(inds):
          natural_inputs[pos] = generations[ind]
      with open(path, "w+") as f:
        json.dump(natural_inputs, f)
      print(f"Batch {i} is processed")
  return natural_inputs

# %%
generations = inference_on_test(small_dataset["test"], 24, model, tokenizer, gen_config, prompt, "generations.json")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 generations = inference_on_test(small_dataset["test"], 24, model, tokenizer, gen_config, prompt, "generations.json")
#
# Cell In[20], line 21, in inference_on_test(dataset, batch_size, text2text_model, tokenizer, gen_config, prompt, path)
#      19 batch = dataset.select(inds)
#      20 prompts = [get_inference_text(prompt, inp, tokenizer) for inp in batch["input"]]
# ---> 21 generations = generate(text2text_model, tokenizer, gen_config, prompts)
#      23 for i, text in enumerate(generations):
#      24     natural_inputs[ind * dataloader.batch_size + i] = text
#
# Cell In[4], line 6, in generate(model, tokenizer, generation_config, inp)
#       4 tokenized_prompt_mask = tokenized_prompt["attention_mask"].cuda()
#       5 with torch.inference_mode():
# ----> 6     output = model.generate(**{"input_ids":tokenized_prompt_ids, "attention_mask":tokenized_prompt_mask, "generation_config":generation_config}).detach().cpu()
#       7 decoded = []
#       8 for i in range(output.shape[0]):
#
# File ~/.mlspace/envs/leap71/lib/python3.10/site-packages/peft/peft_model.py:1704, in PeftModelForCausalLM.generate(self, *args, **kwargs)
#    1702     with self._enable_peft_forward_hooks(*args, **kwargs):
#    1703         kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 1704         outputs = self.base_model.generate(*args, **kwargs)
#    1705 else:
#    1706     outputs = self.base_model.generate(**kwargs)
#
# File ~/.mlspace/envs/leap71/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/.mlspace/envs/leap71/lib/python3.10/site-packages/transformers/generation/utils.py:2048, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2040     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2041         input_ids=input_ids,
#    2042         expand_size=generation_config.num_return_sequences,
#    2043         is_encoder_decoder=self.config.is_encoder_decoder,
#    2044         **model_kwargs,
#    2045     )
#    2047     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2048     result = self._sample(
#    2049         input_ids,
#    2050         logits_processor=prepared_logits_processor,
#    2051         stopping_criteria=prepared_stopping_criteria,
#    2052         generation_config=generation_config,
#    2053         synced_gpus=synced_gpus,
#    2054         streamer=streamer,
#    2055         **model_kwargs,
#    2056     )
#    2058 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2059     # 11. prepare beam search scorer
#    2060     beam_scorer = BeamSearchScorer(
#    2061         batch_size=batch_size,
#    2062         num_beams=generation_config.num_beams,
#    (...)
#    2067         max_length=generation_config.max_length,
#    2068     )
#
# File ~/.mlspace/envs/leap71/lib/python3.10/site-packages/transformers/generation/utils.py:2997, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2994 unfinished_sequences = torch.ones(batch_size, dtype=torch.long, device=input_ids.device)
#    2995 model_kwargs = self._get_initial_cache_position(input_ids, model_kwargs)
# -> 2997 while self._has_unfinished_sequences(
#    2998     this_peer_finished, synced_gpus, device=input_ids.device, cur_len=cur_len, max_length=max_length
#    2999 ):
#    3000     # prepare model inputs
#    3001     model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    3003     # prepare variable output controls (note: some models won't accept all output controls)
#
# File ~/.mlspace/envs/leap71/lib/python3.10/site-packages/transformers/generation/utils.py:2246, in GenerationMixin._has_unfinished_sequences(self, this_peer_finished, synced_gpus, device, cur_len, max_length)
#    2244     if this_peer_finished_flag.item() == 0.0:
#    2245         return False
# -> 2246 elif this_peer_finished:
#    2247     return False
#    2248 return True
#
# KeyboardInterrupt:

# %%
ind = 120
print(small_dataset["train"]["natural_input"][ind])
print(small_dataset["train"]["output"][ind])
# Out:
# Design a colossal truck with seven sets of wheels, featuring a roof fairing and a sleeper cab. This behemoth should measure 20 meters in length, 2.6 meters in width, and tower at 3.2 meters in height, with each wheel boasting a radius of 45 centimeters.
# using System.Collections.Generic;
# using System;
# using System.Collections;
# namespace GenerativeDesign.Cars
# {
#     public class Car : CarBase
#     {
#         public Car()
#         {
#             Length = 2000f;
#             Width = 260f;
#             Height = 320f;
#
#             WheelWidth = 20f;
#             WheelRadius = 45f;
#             WheelRelativeBiasAlongWidth = 0.1f;
#             WheelRelativeBiasesAlongLength = new List<float>() { 0.05f, 0.36f, 0.41f, 0.65f, 0.7f, 0.82f, 0.95f };
#
#             WheelBaseSegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 0.46f }, new List<float>(){ 0.55f, 1f } };
#             WheelBaseSegmentsBottomSurfaces = new List<Line>() { new Constant(height: 30f), new Constant(height: 70f) };
#             WheelBaseTopSurface = new Constant(height: 100f);
#             GapBetweenWheelAndBase = 3f;
#
#             BodySegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 0.13f }, new List<float>(){ 0.13f, 0.2f }, new List<float>(){ 0.2f, 0.3f }, new List<float>(){ 0.32f, 0.75f }, new List<float>(){ 0.77f, 1f } };
#             BodySegmentsTopSurfaces = new List<Line>() { new TotalRounded(minHeight: 144f, maxHeight: 160f, leftRounded: true), new CornerRounded(minHeight: 160f, maxHeight: 224f, cornerRelativeLength: 0.2f, surfaceAbsoluteLength: 0.07000001f, leftCornerRounded: true, rightCornerRounded: false), new TotalRounded(minHeight: 224f, maxHeight: 320f, leftRounded: true), new Constant(height: 320f), new Constant(height: 320f) };
#         }
#     }
#
# }

# %%
print(small_dataset["train"]["input"][ind])
# Out:
# Generate a car with the following characteristics: 7 wheelsets;roof fairing with sleeper cab; length: 2000 cm; width: 260 cm; height: 320 cm; wheel radius: 45 cm

# %%
inp = small_dataset["train"]["input"][ind]

# %%
row = dataset["train"].filter(lambda sample: sample["input"] == inp)[0]
# Out:
# Filter:   0%|          | 0/53280 [00:00<?, ? examples/s]

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Backend functions

# %%
pattern = "(?<=WheelBaseSegmentsSpans)\s*?=\s*?new\s*?List\s*?<\s*?List\s*?<\s*?float\s*?>\s*?>\s*?\(\s*?\)\s*?\{(.*?)\}\s*?;"
text = "WheelBaseSegmentsSpans = new List<List<float>>() { new List<float>() { 0f, 1f }, new List<float>() { 0f, 1f } };"
re.findall(pattern, text)
# Out:
# [' new List<float>() { 0f, 1f }, new List<float>() { 0f, 1f } ']

# %%
def code_to_json(code):
    code = re.sub("//(?:.|\s)+?(?=\n)", "", code)
    float_parameters = ["Length", "Width", "Height", "WheelWidth", "WheelRadius", "WheelRelativeBiasAlongWidth", "GapBetweenWheelAndBase"]
    serialized = {}
    for param in float_parameters:
        float_pattern = "(?<=" + param + ")\s*?=\s*?[\d\.]+?(?=f)"
        value = re.findall(float_pattern, code)[0]
        serialized[param] = float(value.replace("=", "").strip())

    param = "WheelRelativeBiasesAlongLength"
    pattern = "(?<=" + param + ")(?:.|\n)+?(?=;)"
    value_list = re.findall(pattern, code)[0]
    value_list = re.findall("(?<=\{)(?:.|\n)+?(?=\})", value_list)[0].split(",")
    values = []
    for value in value_list:
        value = re.findall(".+?(?=f)", value)[0].strip()
        values.append(float(value))
    serialized[param] = values

    params = ["WheelBaseSegmentsSpans", "BodySegmentsSpans"]
    for param in params:
        pattern = "(?<=" + param + ")\s*?=\s*?new\s+?List\s*?<\s*?List\s*?<\s*?float\s*?>\s*?>\s*?\(\s*?\)\s*?\{((?:.|\n)+?)\}\s*?;"
        list_of_lists = re.findall(pattern, code)[0]
        pattern = "(?<=\{)(?:.|\n)+?(?=\})"
        float_lists = re.findall(pattern, list_of_lists)
        total_lists = []
        for l in float_lists:
            floats = l.split(",")
            float_values = []
            for f in floats:
                value = re.findall(".+?(?=f)", f)[0].strip()
                float_values.append(float(value))
            total_lists.append(float_values)
        serialized[param] = total_lists

    params = ["WheelBaseSegmentsBottomSurfaces", "BodySegmentsTopSurfaces"]
    for param in params:
        pattern = "(?<=" + param + ")(?:.|\n)+?(?=;)"
        classes = re.findall(pattern, code)[0]
        classes = re.findall("(?<=\{)(?:.|\n)+?(?=\})", classes)[0]
        classes = re.findall("new\s+?\w+?\s*?\((?:.|\n)+?\)", classes)
        class_jsons = []
        for c in classes:
            class_json = []
            pattern = "(?<=new).+?(?=\()"
            class_name = re.findall(pattern, c)[0].strip()
            class_json.append(class_name)
            pattern = "(?<=\()(?:.|\n)+?(?=\))"
            parameters = re.findall(pattern, c)[0].split(",")
            parameters_json = {}
            for par in parameters:
                par = par.split(":")
                param_name = par[0].strip()
                param_value = re.findall("(?:\d|\.)+?(?=f)|\w+", par[1])[0].strip()
                try:
                    parameters_json[param_name] = float(param_value)
                except:
                    parameters_json[param_name] = param_value
            class_json.append(parameters_json)
            class_jsons.append(class_json)
        serialized[param] = class_jsons

    param = "WheelBaseTopSurface"
    class_json = []
    pattern = "(?<=" + param + ").+?(?=;)"
    class_value = re.findall(pattern, code)[0]
    pattern = "(?<=new).+?(?=\()"
    class_name = re.findall(pattern, class_value)[0].strip()
    class_json.append(class_name)
    pattern = "(?<=\().+?(?=\))"
    parameters = re.findall(pattern, class_value)[0].split(",")
    parameters_json = {}
    for par in parameters:
        par = par.split(":")
        param_name = par[0].strip()
        param_value = re.findall(".+?(?=f)|\s*?\w+?\s*?", par[1])[0].strip()
        try:
            parameters_json[param_name] = float(param_value)
        except:
            parameters_json[param_name] = param_value
    class_json.append(parameters_json)
    serialized[param] = class_json
    return serialized

# %%
with open("Code_0.cs", "r") as f:
    code = f.read()
test_json = code_to_json(code)

# %%
test_json
# Out:
# {'Length': '250',
#  'Width': '167',
#  'Height': '135',
#  'WheelWidth': '20',
#  'WheelRadius': '25',
#  'WheelRelativeBiasAlongWidth': '0.1',
#  'GapBetweenWheelAndBase': '3',
#  'WheelRelativeBiasesAlongLength': ['0.2', '0.8'],
#  'WheelBaseSegmentsSpans': [['0', '1']],
#  'BodySegmentsSpans': [['0', '1']],
#  'WheelBaseSegmentsBottomSurfaces': [['Constant', {'height': '13'}]],
#  'BodySegmentsTopSurfaces': [['Constant', {'height': '81'}],
#   ['Constant', {'height': '135'}],
#   ['TotalRounded',
#    {'minHeight': '67.5', 'maxHeight': '81', 'leftRounded': ''}]],
#  'WheelBaseTopSurface': ['Constant', {'height': '67.5'}]}

# %%
def extract_codes(generations):
    codes = []
    pattern = "(?<=```csharp)(?:.|\s)+?(?=```)"
    for gen in tqdm(generations):
        code = re.findall(pattern, gen)
        if len(code) != 0:
            code = code[0]
            codes.append(code)
    return codes

# %%
def transform_codes_to_jsons(codes):
    inds = []
    jsons = []
    for ind, code in tqdm(enumerate(codes), total=len(codes)):
        try:
            code_json = code_to_json(code)
            jsons.append(code_json)
            inds.append(ind)
        except:
            continue
    return inds, jsons

# %% [markdown]
# ### Backend functions for reconstruction score

# %%
def get_nearest_value(value, values_to_search):
    distance = 1e9
    nearest_value = 0
    for v in values_to_search:
        local_distance = abs(v - value)
        if local_distance < distance:
            distance = local_distance
            nearest_value = v
    return nearest_value

# %%
def get_parameter_value_part(code_json, indexes):
    value = code_json
    for ind in indexes:
        if type(value) == list:
            value = value[int(ind)]
        else:
            value = value[ind]
    return value

# %%
def get_indexes(value):
    indexes = []
    if type(value) == list:
        for i in range(len(value)):
            new_index = [i]
            local_value = value[i]
            local_indexes = get_indexes(local_value)
            if len(local_indexes) > 0:
                for local_index in local_indexes:
                    extended_index = new_index + local_index
                    indexes.append(extended_index)
            else:
                indexes.append(new_index)
    elif type(value) == dict:
        for k in value.keys():
            new_index = [k]
            local_value = value[k]
            local_indexes = get_indexes(local_value)
            if len(local_indexes) > 0:
                for local_index in local_indexes:
                    extended_index = new_index + local_index
                    indexes.append(extended_index)
            else:
                indexes.append(new_index)
    else:
        indexes.append([])
    return indexes

# %%
def drop_index_invalid(samples, indexes):
    valid_filtered_cars = []
    for car in samples:
        car_value = car
        is_valid = True
        for ind in indexes:
            try:
                value_part = get_parameter_value_part(car_value, ind)
            except:
                is_valid = False
                break
        if is_valid:
            valid_filtered_cars.append(car)
    return valid_filtered_cars

# %%
def index_to_key(index):
    key = "|".join([str(ind) for ind in index])
    return key
def key_to_index(key):
    ind = key.split("|")
    ind = [k for k in ind if len(str(k)) > 0]
    return ind

# %%
def is_equal_jsons(json1, json2):
    is_equal = True
    indexes1 = get_indexes(json1)
    indexes2 = get_indexes(json2)
    
    if len(indexes1) != len(indexes2):
        is_equal - False
    else:
        indexes2_keys = [index_to_key(ind) for ind in indexes2]
        for i in range(len(indexes1)):
            if index_to_key(indexes1[i]) not in indexes2_keys:
                is_equal = False
                break

    if is_equal:
        for ind in indexes1:
            value1 = get_parameter_value_part(json1, ind)
            value2 = get_parameter_value_part(json2, ind)
            if value1 != value2:
                is_equal = False
                break
    return is_equal

# %%
def get_valid_values(param, code_json, type_cars):
    parameters = ["Length", "Width", "Height", "WheelWidth", "WheelRadius", "WheelRelativeBiasAlongWidth", "WheelRelativeBiasesAlongLength", "WheelBaseSegmentsSpans", "WheelBaseSegmentsBottomSurfaces", "GapBetweenWheelAndBase", "WheelBaseTopSurface", "BodySegmentsSpans", "BodySegmentsTopSurfaces"]
    filtered_cars = type_cars
    global_indexes = get_indexes(code_json)
    for i, par in enumerate(parameters):
        if i < parameters.index(param):
            sample_value = code_json[par]
            rel_par_indexes = [[ind for ind in index] for index in global_indexes if index[0] == par]
            [index.pop(0) for index in rel_par_indexes]
            full_par_indexes = [[par] + index for index in rel_par_indexes]
            float_rel_par_indexes = [ind for ind in rel_par_indexes if type(get_parameter_value_part(sample_value, ind)) == float]
            str_rel_par_indexes = [ind for ind in rel_par_indexes if type(get_parameter_value_part(sample_value, ind)) == str]
            indexes = get_indexes(sample_value)
            valid_filtered_cars = drop_index_invalid(filtered_cars, full_par_indexes)
            new_filtered_cars = []
            nearest_values = {}
            for ind in float_rel_par_indexes:
                key = index_to_key(ind)
                value = get_parameter_value_part(sample_value, ind)
                values_to_search = [get_parameter_value_part(car[par], ind) for car in valid_filtered_cars]
                nearest_value = get_nearest_value(value, values_to_search)
                nearest_values[key] = nearest_value
            for car in valid_filtered_cars:
                is_car_valid = True
                car_value = car[par]
                for ind in float_rel_par_indexes:
                    sample_value_part = get_parameter_value_part(sample_value, ind)
                    car_value_part = get_parameter_value_part(car_value, ind)
                    if sample_value_part != car_value_part:
                        nearest_value = nearest_values[index_to_key(ind)]
                        if car_value_part != nearest_value:
                            is_car_valid = False
                            break
                for ind in str_rel_par_indexes:
                    sample_value_part = get_parameter_value_part(sample_value, ind)
                    car_value_part = get_parameter_value_part(car_value, ind)
                    if sample_value_part != car_value_part:
                        is_car_valid = False
                        break
                if is_car_valid:
                    new_filtered_cars.append(car)
            filtered_cars = new_filtered_cars 
        else:
            break
    valid_values = [car[param] for car in filtered_cars]
    unique_valid_values = []
    for v in valid_values:
        exists = False
        for u in unique_valid_values:
            if is_equal_jsons(v, u):
                exists = True
                break
        if not exists:
            unique_valid_values.append(v)
    return unique_valid_values

# %%
def is_from_distribution(value, valid_values):
    indexes = get_indexes(value)
    ind_valid_values = drop_index_invalid(valid_values, indexes)
    distributions = {}
    for ind in indexes:
        key = index_to_key(ind)
        if key not in distributions:
            distributions[key] = []
        for v in ind_valid_values:
            valid_value_part = get_parameter_value_part(v, ind)
            if value not in distributions[key]:
                distributions[key].append(valid_value_part)
    is_value_valid = True
    for key in distributions.keys():
        ind = key_to_index(key)
        dist = distributions[key]
        value_part = get_parameter_value_part(value, ind)
        if len(dist) == 0:
            is_value_valid = False
            break
        if type(value_part) == float:
            valid_min = min(dist)
            valid_max = max(dist)
            if value_part < valid_min or value_part > valid_max:
                is_value_valid = False
                break
        elif type(value_part) == str:
            if value_part not in dist:
                is_value_valid = False
                break
        else:
            is_value_valid = False
            break
    return is_value_valid

# %%
def define_car_type(code_json, codes_by_types):
    valid_types = []
    parameters = ["Length", "Width", "Height", "WheelWidth", "WheelRadius", "WheelRelativeBiasAlongWidth", "WheelRelativeBiasesAlongLength", "WheelBaseSegmentsSpans", "WheelBaseSegmentsBottomSurfaces", "GapBetweenWheelAndBase", "WheelBaseTopSurface", "BodySegmentsSpans", "BodySegmentsTopSurfaces"]
    types = ["sedan", "hatchback", "station wagon", "coupe", "limousine", "SUV", "pickup", "minivan", "van", "truck"]
    for car_type in types:
        type_cars = codes_by_types[car_type]
        passed = True
        for param in parameters:
            valid_values = get_valid_values(param, code_json, type_cars)
            if len(valid_values) == 0:
                passed = False
                break
            from_distribution = is_from_distribution(code_json[param], valid_values)
            if not from_distribution:
                passed = False
                break
        if passed:
            valid_types.append(car_type)
    return valid_types

# %%
def get_parameter(class_json, param):
    class_name = class_json[0]
    param_mapping = {
        "MaxHeight":"maxHeight",
        "MinHeight":"minHeight",
        "LeftRounded":"leftRounded",
        "CornerLength":"cornerRelativeLength",
        "TotalLength":"surfaceAbsoluteLength",
        "LeftCorner":"leftRoundedCorner",
        "RightCorner":"rightRoundedCorner"
    }
    if class_name == "Constant":
        param_mapping["MaxHeight"] = "height"
        param_mapping["MinHeight"] = "height"
    return class_json[1][param_mapping[param]]

# %%
def sample_with_drop(samples):
    results = [samples]
    if len(samples) > 1:
        for i in range(len(samples)):
            toDrop = [s for s in samples]
            toDrop.pop(i)
            droppedResults = sample_with_drop(toDrop)
            results.extend(droppedResults)
    return results

# %%
def num_to_str(num):
    string = ""
    if int(num) - num == 0:
        string = str(int(num))
    else:
        string = str(num)
    return string

# %%
def get_prompts_for_code(car, codes_by_types):
    car_types = define_car_type(car, codes_by_types)
    if len(car_types) == 0:
        return []
    allCars = []
    for key in codes_by_types.keys():
        allCars.extend(codes_by_types[key])

    for carType in car_types:
        numParameters = ["Length", "Width", "Height", "WheelRadius"]
        numParameterNames = ["length", "width", "height", "wheel radius"]
        classNumParameterBoundaries = {}
        totalNumParameterBoundaries = {}
        for param in numParameters:
            classNumParameterBoundaries[param] = [1e9, -1e9]
            totalNumParameterBoundaries[param] = [1e9, -1e9]
        for param in numParameters:
            for typeCar in codes_by_types[carType]:
                value = float(typeCar[param])
                if value < classNumParameterBoundaries[param][0]:
                    classNumParameterBoundaries[param][0] = value
                if value > classNumParameterBoundaries[param][1]:
                    classNumParameterBoundaries[param][1] = value
            for typeCar in allCars:
                value = float(typeCar[param])
                if value < totalNumParameterBoundaries[param][0]:
                    totalNumParameterBoundaries[param][0] = value
                if value > totalNumParameterBoundaries[param][1]:
                    totalNumParameterBoundaries[param][1] = value
        basePrompt = "Generate a car with the following characteristics: "
        
        prompts = []
    
        localTexts = []
        prompt = basePrompt
        textVariants = []
        carTypeTextVariants = []
        carTypeTextVariants.append(prompt)
        carTypeTextVariants.append(prompt + f"body type: {carType};")
        typeParameterDescriptions = []
        description = f"{len(car['WheelRelativeBiasesAlongLength'])} wheelsets"
        typeParameterDescriptions.append(description)
        if carType == "sedan" or carType == "coupe":
            typeParameterDescriptions.append("normal size bonnet")
            if car["BodySegmentsSpans"][2][0] == 0.8:
                typeParameterDescriptions.append("normal size boot")
            elif car["BodySegmentsSpans"][2][0] == 0.9:
                typeParameterDescriptions.append("small boot")
        elif carType == "hatchback" or carType == "SUV":
            typeParameterDescriptions.append("normal size bonnet")
            typeParameterDescriptions.append("normal size boot")
            typeParameterDescriptions.append("door at the rear")
        elif carType == "station wagon":
            typeParameterDescriptions.append("normal size bonnet")
            typeParameterDescriptions.append("large body")
            typeParameterDescriptions.append("large boot")
            typeParameterDescriptions.append("door at the rear")
        elif carType == "limousine":
            typeParameterDescriptions.append("normal size bonnet")
            if car["BodySegmentsSpans"][2][0] == 0.8:
                typeParameterDescriptions.append("normal size boot")
            elif car["BodySegmentsSpans"][2][0] == 0.9:
                typeParameterDescriptions.append("small boot")
            typeParameterDescriptions.append("very long body")
        elif carType == "pickup":
            typeParameterDescriptions.append("normal size bonnet")
            typeParameterDescriptions.append("large boot")
        elif carType == "minivan":
            typeParameterDescriptions.append("small bonnet")
            typeParameterDescriptions.append("large body")
            typeParameterDescriptions.append("no boot")
        elif carType == "van":
            typeParameterDescriptions.append("normal size bonnet")
            if float(get_parameter(car["BodySegmentsTopSurfaces"][2][1], "MaxHeight")) > float(get_parameter(car["BodySegmentsTopSurfaces"][1][1], "MaxHeight")):
                typeParameterDescriptions.append("1 cargo container")
            else:
                typeParameterDescriptions.append("1 flatbed")
        elif carType == "truck":
            if float(get_parameter(car["BodySegmentsTopSurfaces"][0][1], "MaxHeight")) > float(car["Height"]) * 0.6:
                typeParameterDescriptions.append("no bonnet")
            elif float(get_parameter(car["BodySegmentsTopSurfaces"][0][1], "MaxHeight")) > float(car["Height"]) * 0.6:
                typeParameterDescriptions.append("large bonnet")
            fairing = False
            for surf in car["BodySegmentsTopSurfaces"]:
                if surf[0] == "TotalRounded" and get_parameter(surf[1], "MaxHeight") == car["Height"]:
                    fairing = True
                    break
            if fairing:
                typeParameterDescriptions.append("roof fairing with sleeper cab")
            cargoCount = 0
            for i in range(len(car["BodySegmentsSpans"])):
                span = car["BodySegmentsSpans"][i]
                if span[1] - span[0] > 0.17:
                    cargoCount = len(car["BodySegmentsTopSurfaces"]) - i
                    break
            if cargoCount == 1:
                typeParameterDescriptions.append("1 cargo container")
            elif cargoCount > 1:
                typeParameterDescriptions.append(f"{cargoCount} cargo containers")
        descriptionSamples = sample_with_drop(typeParameterDescriptions)
        for sample in descriptionSamples:
            carTypeTextVariants.append(prompt + ";".join(sample))
        for carTypePrompt in carTypeTextVariants:
            textVariants.append(carTypePrompt)
            masks = []
            for j in range(2 ** len(numParameters)):
                mask = [None] * len(numParameters)
                div = j
                ind = len(numParameters) - 1
                while div > 0:
                    mask[ind] = div % 2
                    ind -= 1
                    div = int(div/2)
                for k in range(ind + 1):
                    mask[k] = 0
                masks.append(mask)
            for mask in masks:
                numParameterDescriptions = []
                for k in range(len(numParameters)):
                    info = numParameters[k]
                    value = float(car[info])
                    if mask[k] == 0:
                        numParameterDescriptions.append(f"{numParameterNames[k]}: {num_to_str(value)} cm")
                    else:
                        desc = ""
                        minv = 0
                        maxv = 0
                        if "body type:" in carTypePrompt:
                            minv = classNumParameterBoundaries[info][0]
                            maxv = classNumParameterBoundaries[info][1]
                        else:
                            minv = totalNumParameterBoundaries[info][0]
                            maxv = totalNumParameterBoundaries[info][1]
                        leftMedium = minv + (maxv - minv) / 3
                        rightMedium = minv + (maxv - minv) * 2 / 3
                        if value <= leftMedium:
                            desc = "small"
                        elif value >= rightMedium:
                            desc = "big"
                        else:
                            desc = "medium"
                        numParameterDescriptions.append(f"{numParameterNames[k]} is {desc}")
                numParameterDescriptionSamples = sample_with_drop(numParameterDescriptions)
                for sample in numParameterDescriptionSamples:
                    textVariants.append(f"{carTypePrompt}; {'; '.join(sample)}")
        corrected_prompts = []
        pattern = "(?<=;|:)\s*?;"
        for text in textVariants:
            cor = re.sub(pattern, "", text)
            corrected_prompts.append(cor)
        finalPrompts = []
        for text in corrected_prompts:
            if text not in finalPrompts:
                finalPrompts.append(text)
        prompts.extend(finalPrompts)
    return prompts

# %%
text = "Generate a car with the following characteristics: body type: sedan;; length: 250.0 cm; width: 167.0 cm; height: 150.0 cm; wheel radius: 25.0 cm"
pattern = "(?<=;|:)\s*?;"
re.sub(pattern, "", text)
# Out:
# 'Generate a car with the following characteristics: body type: sedan; length: 250.0 cm; width: 167.0 cm; height: 150.0 cm; wheel radius: 25.0 cm'

# %% [markdown]
# ## Scores

# %%
#measures the part of generations wich code can be extracted from
def extraction_score(generations):
    score = 0
    pattern = "(?<=```csharp)(?:.|\s)+?(?=```)"
    for gen in tqdm(generations):
        code = re.findall(pattern, gen)
        if len(code) != 0:
            code = code[0]
            score += 1
    score = score / len(generations)
    return score

# %%
#measures the part of generations wich code can be transformed to json. Generations should pass the extraction score before.
def compilation_score(codes):
    score = 0
    for code in tqdm(codes):
        try:
            code_json = code_to_json(code)
            score += 1
        except:
            continue
    score = score / len(codes)
    return score

# %%
#measures the part of generations wich compilled jsons can be transformed to templated text inputs correctly
def reconstruction_score(jsons, descriptions, codes_by_types):
    score = 0
    total_samples = 0
    for ind, code_json in tqdm(enumerate(jsons), total = len(jsons), desc="Computing score"):
        desc = descriptions[ind]
        pattern = "(?<=;|:)\s*?;"
        desc = re.sub(pattern, "", desc)
        total_samples += 1
        prompts = get_prompts_for_code(code_json, codes_by_types)
        if desc in prompts:
            score += 1
    score = score / total_samples
    return score

# %% [markdown]
# ## Evaluation

# %%
print("""{\"rewritten request\":\"Craft a lengthy vehicle, approximately 7 meters in length, with a medium width and a compact hood. It should have two sets of wheels, each with a small radius.\",\n\"explanation\":\"I started with 'Craft a lengthy vehicle' to emphasize the 'very long body'. I mentioned the length here: 'approximately 7 meters in length'. 'Medium width' is mentioned here: 'with a medium width'. 'Compact hood' refers to 'normal size bonnet'. I wrote about the wheel sets here: 'It should have two sets of wheels', and about the wheel radius here: 'each with a small radius'.\"}""")
# Out:
# {"rewritten request":"Craft a lengthy vehicle, approximately 7 meters in length, with a medium width and a compact hood. It should have two sets of wheels, each with a small radius.",
# "explanation":"I started with 'Craft a lengthy vehicle' to emphasize the 'very long body'. I mentioned the length here: 'approximately 7 meters in length'. 'Medium width' is mentioned here: 'with a medium width'. 'Compact hood' refers to 'normal size bonnet'. I wrote about the wheel sets here: 'It should have two sets of wheels', and about the wheel radius here: 'each with a small radius'."}

# %%
# !unzip code_by_types.zip
# Out:
# Archive:  code_by_types.zip
#    creating: code_by_types/
#    creating: code_by_types/Coupe/
#   inflating: code_by_types/Coupe/Code_0.cs
#   inflating: code_by_types/Coupe/Code_1.cs
#   inflating: code_by_types/Coupe/Code_10.cs
#   inflating: code_by_types/Coupe/Code_100.cs
#   inflating: code_by_types/Coupe/Code_101.cs
#   inflating: code_by_types/Coupe/Code_102.cs
#   inflating: code_by_types/Coupe/Code_103.cs
#   inflating: code_by_types/Coupe/Code_104.cs
#   inflating: code_by_types/Coupe/Code_105.cs
#   inflating: code_by_types/Coupe/Code_106.cs
#   inflating: code_by_types/Coupe/Code_107.cs
#   inflating: code_by_types/Coupe/Code_108.cs
#   inflating: code_by_types/Coupe/Code_109.cs
#   inflating: code_by_types/Coupe/Code_11.cs
#   inflating: code_by_types/Coupe/Code_110.cs
#   inflating: code_by_types/Coupe/Code_111.cs
#   inflating: code_by_types/Coupe/Code_112.cs
#   inflating: code_by_types/Coupe/Code_113.cs
#   inflating: code_by_types/Coupe/Code_114.cs
#   inflating: code_by_types/Coupe/Code_115.cs
#   inflating: code_by_types/Coupe/Code_116.cs
#   inflating: code_by_types/Coupe/Code_117.cs
#   inflating: code_by_types/Coupe/Code_118.cs
#   inflating: code_by_types/Coupe/Code_119.cs
#   inflating: code_by_types/Coupe/Code_12.cs
#   inflating: code_by_types/Coupe/Code_120.cs
#   inflating: code_by_types/Coupe/Code_121.cs
#   inflating: code_by_types/Coupe/Code_122.cs
#   inflating: code_by_types/Coupe/Code_123.cs
#   inflating: code_by_types/Coupe/Code_124.cs
#   inflating: code_by_types/Coupe/Code_125.cs
#   inflating: code_by_types/Coupe/Code_126.cs
#   inflating: code_by_types/Coupe/Code_127.cs
#   inflating: code_by_types/Coupe/Code_128.cs
#   inflating: code_by_types/Coupe/Code_129.cs
#   inflating: code_by_types/Coupe/Code_13.cs
#   inflating: code_by_types/Coupe/Code_130.cs
#   inflating: code_by_types/Coupe/Code_131.cs
#   inflating: code_by_types/Coupe/Code_132.cs
#   inflating: code_by_types/Coupe/Code_133.cs
#   inflating: code_by_types/Coupe/Code_134.cs
#   inflating: code_by_types/Coupe/Code_135.cs
#   inflating: code_by_types/Coupe/Code_136.cs
#   inflating: code_by_types/Coupe/Code_137.cs
#   inflating: code_by_types/Coupe/Code_138.cs
#   inflating: code_by_types/Coupe/Code_139.cs
#   inflating: code_by_types/Coupe/Code_14.cs
#   inflating: code_by_types/Coupe/Code_140.cs
#   inflating: code_by_types/Coupe/Code_141.cs
#   inflating: code_by_types/Coupe/Code_142.cs
#   inflating: code_by_types/Coupe/Code_143.cs
#   inflating: code_by_types/Coupe/Code_144.cs
#   inflating: code_by_types/Coupe/Code_145.cs
#   inflating: code_by_types/Coupe/Code_146.cs
#   inflating: code_by_types/Coupe/Code_147.cs
#   inflating: code_by_types/Coupe/Code_148.cs
#   inflating: code_by_types/Coupe/Code_149.cs
#   inflating: code_by_types/Coupe/Code_15.cs
#   inflating: code_by_types/Coupe/Code_150.cs
#   inflating: code_by_types/Coupe/Code_151.cs
#   inflating: code_by_types/Coupe/Code_152.cs
#   inflating: code_by_types/Coupe/Code_153.cs
#   inflating: code_by_types/Coupe/Code_154.cs
#   inflating: code_by_types/Coupe/Code_155.cs
#   inflating: code_by_types/Coupe/Code_156.cs
#   inflating: code_by_types/Coupe/Code_157.cs
#   inflating: code_by_types/Coupe/Code_158.cs
#   inflating: code_by_types/Coupe/Code_159.cs
#   inflating: code_by_types/Coupe/Code_16.cs
#   inflating: code_by_types/Coupe/Code_160.cs
#   inflating: code_by_types/Coupe/Code_161.cs
#   inflating: code_by_types/Coupe/Code_162.cs
#   inflating: code_by_types/Coupe/Code_163.cs
#   inflating: code_by_types/Coupe/Code_164.cs
#   inflating: code_by_types/Coupe/Code_165.cs
#   inflating: code_by_types/Coupe/Code_166.cs
#   inflating: code_by_types/Coupe/Code_167.cs
#   inflating: code_by_types/Coupe/Code_168.cs
#   inflating: code_by_types/Coupe/Code_169.cs
#   inflating: code_by_types/Coupe/Code_17.cs
#   inflating: code_by_types/Coupe/Code_170.cs
#   inflating: code_by_types/Coupe/Code_171.cs
#   inflating: code_by_types/Coupe/Code_172.cs
#   inflating: code_by_types/Coupe/Code_173.cs
#   inflating: code_by_types/Coupe/Code_174.cs
#   inflating: code_by_types/Coupe/Code_175.cs
#   inflating: code_by_types/Coupe/Code_176.cs
#   inflating: code_by_types/Coupe/Code_177.cs
#   inflating: code_by_types/Coupe/Code_178.cs
#   inflating: code_by_types/Coupe/Code_179.cs
#   inflating: code_by_types/Coupe/Code_18.cs
#   inflating: code_by_types/Coupe/Code_180.cs
#   inflating: code_by_types/Coupe/Code_181.cs
#   inflating: code_by_types/Coupe/Code_182.cs
#   inflating: code_by_types/Coupe/Code_183.cs
#   inflating: code_by_types/Coupe/Code_184.cs
#   inflating: code_by_types/Coupe/Code_185.cs
#   inflating: code_by_types/Coupe/Code_186.cs
#   inflating: code_by_types/Coupe/Code_187.cs
#   inflating: code_by_types/Coupe/Code_188.cs
#   inflating: code_by_types/Coupe/Code_189.cs
#   inflating: code_by_types/Coupe/Code_19.cs
#   inflating: code_by_types/Coupe/Code_190.cs
#   inflating: code_by_types/Coupe/Code_191.cs
#   inflating: code_by_types/Coupe/Code_192.cs
#   inflating: code_by_types/Coupe/Code_193.cs
#   inflating: code_by_types/Coupe/Code_194.cs
#   inflating: code_by_types/Coupe/Code_195.cs
#   inflating: code_by_types/Coupe/Code_196.cs
#   inflating: code_by_types/Coupe/Code_197.cs
#   inflating: code_by_types/Coupe/Code_198.cs
#   inflating: code_by_types/Coupe/Code_199.cs
#   inflating: code_by_types/Coupe/Code_2.cs
#   inflating: code_by_types/Coupe/Code_20.cs
#   inflating: code_by_types/Coupe/Code_200.cs
#   inflating: code_by_types/Coupe/Code_201.cs
#   inflating: code_by_types/Coupe/Code_202.cs
#   inflating: code_by_types/Coupe/Code_203.cs
#   inflating: code_by_types/Coupe/Code_204.cs
#   inflating: code_by_types/Coupe/Code_205.cs
#   inflating: code_by_types/Coupe/Code_206.cs
#   inflating: code_by_types/Coupe/Code_207.cs
#   inflating: code_by_types/Coupe/Code_208.cs
#   inflating: code_by_types/Coupe/Code_209.cs
#   inflating: code_by_types/Coupe/Code_21.cs
#   inflating: code_by_types/Coupe/Code_210.cs
#   inflating: code_by_types/Coupe/Code_211.cs
#   inflating: code_by_types/Coupe/Code_212.cs
#   inflating: code_by_types/Coupe/Code_213.cs
#   inflating: code_by_types/Coupe/Code_214.cs
#   inflating: code_by_types/Coupe/Code_215.cs
#   inflating: code_by_types/Coupe/Code_216.cs
#   inflating: code_by_types/Coupe/Code_217.cs
#   inflating: code_by_types/Coupe/Code_218.cs
#   inflating: code_by_types/Coupe/Code_219.cs
#   inflating: code_by_types/Coupe/Code_22.cs
#   inflating: code_by_types/Coupe/Code_220.cs
#   inflating: code_by_types/Coupe/Code_221.cs
#   inflating: code_by_types/Coupe/Code_222.cs
#   inflating: code_by_types/Coupe/Code_223.cs
#   inflating: code_by_types/Coupe/Code_224.cs
#   inflating: code_by_types/Coupe/Code_225.cs
#   inflating: code_by_types/Coupe/Code_226.cs
#   inflating: code_by_types/Coupe/Code_227.cs
#   inflating: code_by_types/Coupe/Code_228.cs
#   inflating: code_by_types/Coupe/Code_229.cs
#   inflating: code_by_types/Coupe/Code_23.cs
#   inflating: code_by_types/Coupe/Code_230.cs
#   inflating: code_by_types/Coupe/Code_231.cs
#   inflating: code_by_types/Coupe/Code_232.cs
#   inflating: code_by_types/Coupe/Code_233.cs
#   inflating: code_by_types/Coupe/Code_234.cs
#   inflating: code_by_types/Coupe/Code_235.cs
#   inflating: code_by_types/Coupe/Code_236.cs
#   inflating: code_by_types/Coupe/Code_237.cs
#   inflating: code_by_types/Coupe/Code_238.cs
#   inflating: code_by_types/Coupe/Code_239.cs
#   inflating: code_by_types/Coupe/Code_24.cs
#   inflating: code_by_types/Coupe/Code_25.cs
#   inflating: code_by_types/Coupe/Code_26.cs
#   inflating: code_by_types/Coupe/Code_27.cs
#   inflating: code_by_types/Coupe/Code_28.cs
#   inflating: code_by_types/Coupe/Code_29.cs
#   inflating: code_by_types/Coupe/Code_3.cs
#   inflating: code_by_types/Coupe/Code_30.cs
#   inflating: code_by_types/Coupe/Code_31.cs
#   inflating: code_by_types/Coupe/Code_32.cs
#   inflating: code_by_types/Coupe/Code_33.cs
#   inflating: code_by_types/Coupe/Code_34.cs
#   inflating: code_by_types/Coupe/Code_35.cs
#   inflating: code_by_types/Coupe/Code_36.cs
#   inflating: code_by_types/Coupe/Code_37.cs
#   inflating: code_by_types/Coupe/Code_38.cs
#   inflating: code_by_types/Coupe/Code_39.cs
#   inflating: code_by_types/Coupe/Code_4.cs
#   inflating: code_by_types/Coupe/Code_40.cs
#   inflating: code_by_types/Coupe/Code_41.cs
#   inflating: code_by_types/Coupe/Code_42.cs
#   inflating: code_by_types/Coupe/Code_43.cs
#   inflating: code_by_types/Coupe/Code_44.cs
#   inflating: code_by_types/Coupe/Code_45.cs
#   inflating: code_by_types/Coupe/Code_46.cs
#   inflating: code_by_types/Coupe/Code_47.cs
#   inflating: code_by_types/Coupe/Code_48.cs
#   inflating: code_by_types/Coupe/Code_49.cs
#   inflating: code_by_types/Coupe/Code_5.cs
#   inflating: code_by_types/Coupe/Code_50.cs
#   inflating: code_by_types/Coupe/Code_51.cs
#   inflating: code_by_types/Coupe/Code_52.cs
#   inflating: code_by_types/Coupe/Code_53.cs
#   inflating: code_by_types/Coupe/Code_54.cs
#   inflating: code_by_types/Coupe/Code_55.cs
#   inflating: code_by_types/Coupe/Code_56.cs
#   inflating: code_by_types/Coupe/Code_57.cs
#   inflating: code_by_types/Coupe/Code_58.cs
#   inflating: code_by_types/Coupe/Code_59.cs
#   inflating: code_by_types/Coupe/Code_6.cs
#   inflating: code_by_types/Coupe/Code_60.cs
#   inflating: code_by_types/Coupe/Code_61.cs
#   inflating: code_by_types/Coupe/Code_62.cs
#   inflating: code_by_types/Coupe/Code_63.cs
#   inflating: code_by_types/Coupe/Code_64.cs
#   inflating: code_by_types/Coupe/Code_65.cs
#   inflating: code_by_types/Coupe/Code_66.cs
#   inflating: code_by_types/Coupe/Code_67.cs
#   inflating: code_by_types/Coupe/Code_68.cs
#   inflating: code_by_types/Coupe/Code_69.cs
#   inflating: code_by_types/Coupe/Code_7.cs
#   inflating: code_by_types/Coupe/Code_70.cs
#   inflating: code_by_types/Coupe/Code_71.cs
#   inflating: code_by_types/Coupe/Code_72.cs
#   inflating: code_by_types/Coupe/Code_73.cs
#   inflating: code_by_types/Coupe/Code_74.cs
#   inflating: code_by_types/Coupe/Code_75.cs
#   inflating: code_by_types/Coupe/Code_76.cs
#   inflating: code_by_types/Coupe/Code_77.cs
#   inflating: code_by_types/Coupe/Code_78.cs
#   inflating: code_by_types/Coupe/Code_79.cs
#   inflating: code_by_types/Coupe/Code_8.cs
#   inflating: code_by_types/Coupe/Code_80.cs
#   inflating: code_by_types/Coupe/Code_81.cs
#   inflating: code_by_types/Coupe/Code_82.cs
#   inflating: code_by_types/Coupe/Code_83.cs
#   inflating: code_by_types/Coupe/Code_84.cs
#   inflating: code_by_types/Coupe/Code_85.cs
#   inflating: code_by_types/Coupe/Code_86.cs
#   inflating: code_by_types/Coupe/Code_87.cs
#   inflating: code_by_types/Coupe/Code_88.cs
#   inflating: code_by_types/Coupe/Code_89.cs
#   inflating: code_by_types/Coupe/Code_9.cs
#   inflating: code_by_types/Coupe/Code_90.cs
#   inflating: code_by_types/Coupe/Code_91.cs
#   inflating: code_by_types/Coupe/Code_92.cs
#   inflating: code_by_types/Coupe/Code_93.cs
#   inflating: code_by_types/Coupe/Code_94.cs
#   inflating: code_by_types/Coupe/Code_95.cs
#   inflating: code_by_types/Coupe/Code_96.cs
#   inflating: code_by_types/Coupe/Code_97.cs
#   inflating: code_by_types/Coupe/Code_98.cs
#   inflating: code_by_types/Coupe/Code_99.cs
#    creating: code_by_types/Hatchback/
#   inflating: code_by_types/Hatchback/Code_0.cs
#   inflating: code_by_types/Hatchback/Code_1.cs
#   inflating: code_by_types/Hatchback/Code_10.cs
#   inflating: code_by_types/Hatchback/Code_100.cs
#   inflating: code_by_types/Hatchback/Code_1000.cs
#   inflating: code_by_types/Hatchback/Code_1001.cs
#   inflating: code_by_types/Hatchback/Code_1002.cs
#   inflating: code_by_types/Hatchback/Code_1003.cs
#   inflating: code_by_types/Hatchback/Code_1004.cs
#   inflating: code_by_types/Hatchback/Code_1005.cs
#   inflating: code_by_types/Hatchback/Code_1006.cs
#   inflating: code_by_types/Hatchback/Code_1007.cs
#   inflating: code_by_types/Hatchback/Code_1008.cs
#   inflating: code_by_types/Hatchback/Code_1009.cs
#   inflating: code_by_types/Hatchback/Code_101.cs
#   inflating: code_by_types/Hatchback/Code_1010.cs
#   inflating: code_by_types/Hatchback/Code_1011.cs
#   inflating: code_by_types/Hatchback/Code_1012.cs
#   inflating: code_by_types/Hatchback/Code_1013.cs
#   inflating: code_by_types/Hatchback/Code_1014.cs
#   inflating: code_by_types/Hatchback/Code_1015.cs
#   inflating: code_by_types/Hatchback/Code_1016.cs
#   inflating: code_by_types/Hatchback/Code_1017.cs
#   inflating: code_by_types/Hatchback/Code_1018.cs
#   inflating: code_by_types/Hatchback/Code_1019.cs
#   inflating: code_by_types/Hatchback/Code_102.cs
#   inflating: code_by_types/Hatchback/Code_1020.cs
#   inflating: code_by_types/Hatchback/Code_1021.cs
#   inflating: code_by_types/Hatchback/Code_1022.cs
#   inflating: code_by_types/Hatchback/Code_1023.cs
#   inflating: code_by_types/Hatchback/Code_1024.cs
#   inflating: code_by_types/Hatchback/Code_1025.cs
#   inflating: code_by_types/Hatchback/Code_1026.cs
#   inflating: code_by_types/Hatchback/Code_1027.cs
#   inflating: code_by_types/Hatchback/Code_1028.cs
#   inflating: code_by_types/Hatchback/Code_1029.cs
#   inflating: code_by_types/Hatchback/Code_103.cs
#   inflating: code_by_types/Hatchback/Code_1030.cs
#   inflating: code_by_types/Hatchback/Code_1031.cs
#   inflating: code_by_types/Hatchback/Code_1032.cs
#   inflating: code_by_types/Hatchback/Code_1033.cs
#   inflating: code_by_types/Hatchback/Code_1034.cs
#   inflating: code_by_types/Hatchback/Code_1035.cs
#   inflating: code_by_types/Hatchback/Code_1036.cs
#   inflating: code_by_types/Hatchback/Code_1037.cs
#   inflating: code_by_types/Hatchback/Code_1038.cs
#   inflating: code_by_types/Hatchback/Code_1039.cs
#   inflating: code_by_types/Hatchback/Code_104.cs
#   inflating: code_by_types/Hatchback/Code_1040.cs
#   inflating: code_by_types/Hatchback/Code_1041.cs
#   inflating: code_by_types/Hatchback/Code_1042.cs
#   inflating: code_by_types/Hatchback/Code_1043.cs
#   inflating: code_by_types/Hatchback/Code_1044.cs
#   inflating: code_by_types/Hatchback/Code_1045.cs
#   inflating: code_by_types/Hatchback/Code_1046.cs
#   inflating: code_by_types/Hatchback/Code_1047.cs
#   inflating: code_by_types/Hatchback/Code_1048.cs
#   inflating: code_by_types/Hatchback/Code_1049.cs
#   inflating: code_by_types/Hatchback/Code_105.cs
#   inflating: code_by_types/Hatchback/Code_1050.cs
#   inflating: code_by_types/Hatchback/Code_1051.cs
#   inflating: code_by_types/Hatchback/Code_1052.cs
#   inflating: code_by_types/Hatchback/Code_1053.cs
#   inflating: code_by_types/Hatchback/Code_1054.cs
#   inflating: code_by_types/Hatchback/Code_1055.cs
#   inflating: code_by_types/Hatchback/Code_1056.cs
#   inflating: code_by_types/Hatchback/Code_1057.cs
#   inflating: code_by_types/Hatchback/Code_1058.cs
#   inflating: code_by_types/Hatchback/Code_1059.cs
#   inflating: code_by_types/Hatchback/Code_106.cs
#   inflating: code_by_types/Hatchback/Code_1060.cs
#   inflating: code_by_types/Hatchback/Code_1061.cs
#   inflating: code_by_types/Hatchback/Code_1062.cs
#   inflating: code_by_types/Hatchback/Code_1063.cs
#   inflating: code_by_types/Hatchback/Code_1064.cs
#   inflating: code_by_types/Hatchback/Code_1065.cs
#   inflating: code_by_types/Hatchback/Code_1066.cs
#   inflating: code_by_types/Hatchback/Code_1067.cs
#   inflating: code_by_types/Hatchback/Code_1068.cs
#   inflating: code_by_types/Hatchback/Code_1069.cs
#   inflating: code_by_types/Hatchback/Code_107.cs
#   inflating: code_by_types/Hatchback/Code_1070.cs
#   inflating: code_by_types/Hatchback/Code_1071.cs
#   inflating: code_by_types/Hatchback/Code_1072.cs
#   inflating: code_by_types/Hatchback/Code_1073.cs
#   inflating: code_by_types/Hatchback/Code_1074.cs
#   inflating: code_by_types/Hatchback/Code_1075.cs
#   inflating: code_by_types/Hatchback/Code_1076.cs
#   inflating: code_by_types/Hatchback/Code_1077.cs
#   inflating: code_by_types/Hatchback/Code_1078.cs
#   inflating: code_by_types/Hatchback/Code_1079.cs
#   inflating: code_by_types/Hatchback/Code_108.cs
#   inflating: code_by_types/Hatchback/Code_1080.cs
#   inflating: code_by_types/Hatchback/Code_1081.cs
#   inflating: code_by_types/Hatchback/Code_1082.cs
#   inflating: code_by_types/Hatchback/Code_1083.cs
#   inflating: code_by_types/Hatchback/Code_1084.cs
#   inflating: code_by_types/Hatchback/Code_1085.cs
#   inflating: code_by_types/Hatchback/Code_1086.cs
#   inflating: code_by_types/Hatchback/Code_1087.cs
#   inflating: code_by_types/Hatchback/Code_1088.cs
#   inflating: code_by_types/Hatchback/Code_1089.cs
#   inflating: code_by_types/Hatchback/Code_109.cs
#   inflating: code_by_types/Hatchback/Code_1090.cs
#   inflating: code_by_types/Hatchback/Code_1091.cs
#   inflating: code_by_types/Hatchback/Code_1092.cs
#   inflating: code_by_types/Hatchback/Code_1093.cs
#   inflating: code_by_types/Hatchback/Code_1094.cs
#   inflating: code_by_types/Hatchback/Code_1095.cs
#   inflating: code_by_types/Hatchback/Code_1096.cs
#   inflating: code_by_types/Hatchback/Code_1097.cs
#   inflating: code_by_types/Hatchback/Code_1098.cs
#   inflating: code_by_types/Hatchback/Code_1099.cs
#   inflating: code_by_types/Hatchback/Code_11.cs
#   inflating: code_by_types/Hatchback/Code_110.cs
#   inflating: code_by_types/Hatchback/Code_1100.cs
#   inflating: code_by_types/Hatchback/Code_1101.cs
#   inflating: code_by_types/Hatchback/Code_1102.cs
#   inflating: code_by_types/Hatchback/Code_1103.cs
#   inflating: code_by_types/Hatchback/Code_1104.cs
#   inflating: code_by_types/Hatchback/Code_1105.cs
#   inflating: code_by_types/Hatchback/Code_1106.cs
#   inflating: code_by_types/Hatchback/Code_1107.cs
#   inflating: code_by_types/Hatchback/Code_1108.cs
#   inflating: code_by_types/Hatchback/Code_1109.cs
#   inflating: code_by_types/Hatchback/Code_111.cs
#   inflating: code_by_types/Hatchback/Code_1110.cs
#   inflating: code_by_types/Hatchback/Code_1111.cs
#   inflating: code_by_types/Hatchback/Code_1112.cs
#   inflating: code_by_types/Hatchback/Code_1113.cs
#   inflating: code_by_types/Hatchback/Code_1114.cs
#   inflating: code_by_types/Hatchback/Code_1115.cs
#   inflating: code_by_types/Hatchback/Code_1116.cs
#   inflating: code_by_types/Hatchback/Code_1117.cs
#   inflating: code_by_types/Hatchback/Code_1118.cs
#   inflating: code_by_types/Hatchback/Code_1119.cs
#   inflating: code_by_types/Hatchback/Code_112.cs
#   inflating: code_by_types/Hatchback/Code_1120.cs
#   inflating: code_by_types/Hatchback/Code_1121.cs
#   inflating: code_by_types/Hatchback/Code_1122.cs
#   inflating: code_by_types/Hatchback/Code_1123.cs
#   inflating: code_by_types/Hatchback/Code_1124.cs
#   inflating: code_by_types/Hatchback/Code_1125.cs
#   inflating: code_by_types/Hatchback/Code_1126.cs
#   inflating: code_by_types/Hatchback/Code_1127.cs
#   inflating: code_by_types/Hatchback/Code_1128.cs
#   inflating: code_by_types/Hatchback/Code_1129.cs
#   inflating: code_by_types/Hatchback/Code_113.cs
#   inflating: code_by_types/Hatchback/Code_1130.cs
#   inflating: code_by_types/Hatchback/Code_1131.cs
#   inflating: code_by_types/Hatchback/Code_1132.cs
#   inflating: code_by_types/Hatchback/Code_1133.cs
#   inflating: code_by_types/Hatchback/Code_1134.cs
#   inflating: code_by_types/Hatchback/Code_1135.cs
#   inflating: code_by_types/Hatchback/Code_1136.cs
#   inflating: code_by_types/Hatchback/Code_1137.cs
#   inflating: code_by_types/Hatchback/Code_1138.cs
#   inflating: code_by_types/Hatchback/Code_1139.cs
#   inflating: code_by_types/Hatchback/Code_114.cs
#   inflating: code_by_types/Hatchback/Code_1140.cs
#   inflating: code_by_types/Hatchback/Code_1141.cs
#   inflating: code_by_types/Hatchback/Code_1142.cs
#   inflating: code_by_types/Hatchback/Code_1143.cs
#   inflating: code_by_types/Hatchback/Code_1144.cs
#   inflating: code_by_types/Hatchback/Code_1145.cs
#   inflating: code_by_types/Hatchback/Code_1146.cs
#   inflating: code_by_types/Hatchback/Code_1147.cs
#   inflating: code_by_types/Hatchback/Code_1148.cs
#   inflating: code_by_types/Hatchback/Code_1149.cs
#   inflating: code_by_types/Hatchback/Code_115.cs
#   inflating: code_by_types/Hatchback/Code_1150.cs
#   inflating: code_by_types/Hatchback/Code_1151.cs
#   inflating: code_by_types/Hatchback/Code_1152.cs
#   inflating: code_by_types/Hatchback/Code_1153.cs
#   inflating: code_by_types/Hatchback/Code_1154.cs
#   inflating: code_by_types/Hatchback/Code_1155.cs
#   inflating: code_by_types/Hatchback/Code_1156.cs
#   inflating: code_by_types/Hatchback/Code_1157.cs
#   inflating: code_by_types/Hatchback/Code_1158.cs
#   inflating: code_by_types/Hatchback/Code_1159.cs
#   inflating: code_by_types/Hatchback/Code_116.cs
#   inflating: code_by_types/Hatchback/Code_1160.cs
#   inflating: code_by_types/Hatchback/Code_1161.cs
#   inflating: code_by_types/Hatchback/Code_1162.cs
#   inflating: code_by_types/Hatchback/Code_1163.cs
#   inflating: code_by_types/Hatchback/Code_1164.cs
#   inflating: code_by_types/Hatchback/Code_1165.cs
#   inflating: code_by_types/Hatchback/Code_1166.cs
#   inflating: code_by_types/Hatchback/Code_1167.cs
#   inflating: code_by_types/Hatchback/Code_1168.cs
#   inflating: code_by_types/Hatchback/Code_1169.cs
#   inflating: code_by_types/Hatchback/Code_117.cs
#   inflating: code_by_types/Hatchback/Code_1170.cs
#   inflating: code_by_types/Hatchback/Code_1171.cs
#   inflating: code_by_types/Hatchback/Code_1172.cs
#   inflating: code_by_types/Hatchback/Code_1173.cs
#   inflating: code_by_types/Hatchback/Code_1174.cs
#   inflating: code_by_types/Hatchback/Code_1175.cs
#   inflating: code_by_types/Hatchback/Code_1176.cs
#   inflating: code_by_types/Hatchback/Code_1177.cs
#   inflating: code_by_types/Hatchback/Code_1178.cs
#   inflating: code_by_types/Hatchback/Code_1179.cs
#   inflating: code_by_types/Hatchback/Code_118.cs
#   inflating: code_by_types/Hatchback/Code_1180.cs
#   inflating: code_by_types/Hatchback/Code_1181.cs
#   inflating: code_by_types/Hatchback/Code_1182.cs
#   inflating: code_by_types/Hatchback/Code_1183.cs
#   inflating: code_by_types/Hatchback/Code_1184.cs
#   inflating: code_by_types/Hatchback/Code_1185.cs
#   inflating: code_by_types/Hatchback/Code_1186.cs
#   inflating: code_by_types/Hatchback/Code_1187.cs
#   inflating: code_by_types/Hatchback/Code_1188.cs
#   inflating: code_by_types/Hatchback/Code_1189.cs
#   inflating: code_by_types/Hatchback/Code_119.cs
#   inflating: code_by_types/Hatchback/Code_1190.cs
#   inflating: code_by_types/Hatchback/Code_1191.cs
#   inflating: code_by_types/Hatchback/Code_1192.cs
#   inflating: code_by_types/Hatchback/Code_1193.cs
#   inflating: code_by_types/Hatchback/Code_1194.cs
#   inflating: code_by_types/Hatchback/Code_1195.cs
#   inflating: code_by_types/Hatchback/Code_1196.cs
#   inflating: code_by_types/Hatchback/Code_1197.cs
#   inflating: code_by_types/Hatchback/Code_1198.cs
#   inflating: code_by_types/Hatchback/Code_1199.cs
#   inflating: code_by_types/Hatchback/Code_12.cs
#   inflating: code_by_types/Hatchback/Code_120.cs
#   inflating: code_by_types/Hatchback/Code_1200.cs
#   inflating: code_by_types/Hatchback/Code_1201.cs
#   inflating: code_by_types/Hatchback/Code_1202.cs
#   inflating: code_by_types/Hatchback/Code_1203.cs
#   inflating: code_by_types/Hatchback/Code_1204.cs
#   inflating: code_by_types/Hatchback/Code_1205.cs
#   inflating: code_by_types/Hatchback/Code_1206.cs
#   inflating: code_by_types/Hatchback/Code_1207.cs
#   inflating: code_by_types/Hatchback/Code_1208.cs
#   inflating: code_by_types/Hatchback/Code_1209.cs
#   inflating: code_by_types/Hatchback/Code_121.cs
#   inflating: code_by_types/Hatchback/Code_1210.cs
#   inflating: code_by_types/Hatchback/Code_1211.cs
#   inflating: code_by_types/Hatchback/Code_1212.cs
#   inflating: code_by_types/Hatchback/Code_1213.cs
#   inflating: code_by_types/Hatchback/Code_1214.cs
#   inflating: code_by_types/Hatchback/Code_1215.cs
#   inflating: code_by_types/Hatchback/Code_1216.cs
#   inflating: code_by_types/Hatchback/Code_1217.cs
#   inflating: code_by_types/Hatchback/Code_1218.cs
#   inflating: code_by_types/Hatchback/Code_1219.cs
#   inflating: code_by_types/Hatchback/Code_122.cs
#   inflating: code_by_types/Hatchback/Code_1220.cs
#   inflating: code_by_types/Hatchback/Code_1221.cs
#   inflating: code_by_types/Hatchback/Code_1222.cs
#   inflating: code_by_types/Hatchback/Code_1223.cs
#   inflating: code_by_types/Hatchback/Code_1224.cs
#   inflating: code_by_types/Hatchback/Code_1225.cs
#   inflating: code_by_types/Hatchback/Code_1226.cs
#   inflating: code_by_types/Hatchback/Code_1227.cs
#   inflating: code_by_types/Hatchback/Code_1228.cs
#   inflating: code_by_types/Hatchback/Code_1229.cs
#   inflating: code_by_types/Hatchback/Code_123.cs
#   inflating: code_by_types/Hatchback/Code_1230.cs
#   inflating: code_by_types/Hatchback/Code_1231.cs
#   inflating: code_by_types/Hatchback/Code_1232.cs
#   inflating: code_by_types/Hatchback/Code_1233.cs
#   inflating: code_by_types/Hatchback/Code_1234.cs
#   inflating: code_by_types/Hatchback/Code_1235.cs
#   inflating: code_by_types/Hatchback/Code_1236.cs
#   inflating: code_by_types/Hatchback/Code_1237.cs
#   inflating: code_by_types/Hatchback/Code_1238.cs
#   inflating: code_by_types/Hatchback/Code_1239.cs
#   inflating: code_by_types/Hatchback/Code_124.cs
#   inflating: code_by_types/Hatchback/Code_1240.cs
#   inflating: code_by_types/Hatchback/Code_1241.cs
#   inflating: code_by_types/Hatchback/Code_1242.cs
#   inflating: code_by_types/Hatchback/Code_1243.cs
#   inflating: code_by_types/Hatchback/Code_1244.cs
#   inflating: code_by_types/Hatchback/Code_1245.cs
#   inflating: code_by_types/Hatchback/Code_1246.cs
#   inflating: code_by_types/Hatchback/Code_1247.cs
#   inflating: code_by_types/Hatchback/Code_1248.cs
#   inflating: code_by_types/Hatchback/Code_1249.cs
#   inflating: code_by_types/Hatchback/Code_125.cs
#   inflating: code_by_types/Hatchback/Code_1250.cs
#   inflating: code_by_types/Hatchback/Code_1251.cs
#   inflating: code_by_types/Hatchback/Code_1252.cs
#   inflating: code_by_types/Hatchback/Code_1253.cs
#   inflating: code_by_types/Hatchback/Code_1254.cs
#   inflating: code_by_types/Hatchback/Code_1255.cs
#   inflating: code_by_types/Hatchback/Code_1256.cs
#   inflating: code_by_types/Hatchback/Code_1257.cs
#   inflating: code_by_types/Hatchback/Code_1258.cs
#   inflating: code_by_types/Hatchback/Code_1259.cs
#   inflating: code_by_types/Hatchback/Code_126.cs
#   inflating: code_by_types/Hatchback/Code_1260.cs
#   inflating: code_by_types/Hatchback/Code_1261.cs
#   inflating: code_by_types/Hatchback/Code_1262.cs
#   inflating: code_by_types/Hatchback/Code_1263.cs
#   inflating: code_by_types/Hatchback/Code_1264.cs
#   inflating: code_by_types/Hatchback/Code_1265.cs
#   inflating: code_by_types/Hatchback/Code_1266.cs
#   inflating: code_by_types/Hatchback/Code_1267.cs
#   inflating: code_by_types/Hatchback/Code_1268.cs
#   inflating: code_by_types/Hatchback/Code_1269.cs
#   inflating: code_by_types/Hatchback/Code_127.cs
#   inflating: code_by_types/Hatchback/Code_1270.cs
#   inflating: code_by_types/Hatchback/Code_1271.cs
#   inflating: code_by_types/Hatchback/Code_1272.cs
#   inflating: code_by_types/Hatchback/Code_1273.cs
#   inflating: code_by_types/Hatchback/Code_1274.cs
#   inflating: code_by_types/Hatchback/Code_1275.cs
#   inflating: code_by_types/Hatchback/Code_1276.cs
#   inflating: code_by_types/Hatchback/Code_1277.cs
#   inflating: code_by_types/Hatchback/Code_1278.cs
#   inflating: code_by_types/Hatchback/Code_1279.cs
#   inflating: code_by_types/Hatchback/Code_128.cs
#   inflating: code_by_types/Hatchback/Code_1280.cs
#   inflating: code_by_types/Hatchback/Code_1281.cs
#   inflating: code_by_types/Hatchback/Code_1282.cs
#   inflating: code_by_types/Hatchback/Code_1283.cs
#   inflating: code_by_types/Hatchback/Code_1284.cs
#   inflating: code_by_types/Hatchback/Code_1285.cs
#   inflating: code_by_types/Hatchback/Code_1286.cs
#   inflating: code_by_types/Hatchback/Code_1287.cs
#   inflating: code_by_types/Hatchback/Code_1288.cs
#   inflating: code_by_types/Hatchback/Code_1289.cs
#   inflating: code_by_types/Hatchback/Code_129.cs
#   inflating: code_by_types/Hatchback/Code_1290.cs
#   inflating: code_by_types/Hatchback/Code_1291.cs
#   inflating: code_by_types/Hatchback/Code_1292.cs
#   inflating: code_by_types/Hatchback/Code_1293.cs
#   inflating: code_by_types/Hatchback/Code_1294.cs
#   inflating: code_by_types/Hatchback/Code_1295.cs
#   inflating: code_by_types/Hatchback/Code_1296.cs
#   inflating: code_by_types/Hatchback/Code_1297.cs
#   inflating: code_by_types/Hatchback/Code_1298.cs
#   inflating: code_by_types/Hatchback/Code_1299.cs
#   inflating: code_by_types/Hatchback/Code_13.cs
#   inflating: code_by_types/Hatchback/Code_130.cs
#   inflating: code_by_types/Hatchback/Code_1300.cs
#   inflating: code_by_types/Hatchback/Code_1301.cs
#   inflating: code_by_types/Hatchback/Code_1302.cs
#   inflating: code_by_types/Hatchback/Code_1303.cs
#   inflating: code_by_types/Hatchback/Code_1304.cs
#   inflating: code_by_types/Hatchback/Code_1305.cs
#   inflating: code_by_types/Hatchback/Code_1306.cs
#   inflating: code_by_types/Hatchback/Code_1307.cs
#   inflating: code_by_types/Hatchback/Code_1308.cs
#   inflating: code_by_types/Hatchback/Code_1309.cs
#   inflating: code_by_types/Hatchback/Code_131.cs
#   inflating: code_by_types/Hatchback/Code_1310.cs
#   inflating: code_by_types/Hatchback/Code_1311.cs
#   inflating: code_by_types/Hatchback/Code_1312.cs
#   inflating: code_by_types/Hatchback/Code_1313.cs
#   inflating: code_by_types/Hatchback/Code_1314.cs
#   inflating: code_by_types/Hatchback/Code_1315.cs
#   inflating: code_by_types/Hatchback/Code_1316.cs
#   inflating: code_by_types/Hatchback/Code_1317.cs
#   inflating: code_by_types/Hatchback/Code_1318.cs
#   inflating: code_by_types/Hatchback/Code_1319.cs
#   inflating: code_by_types/Hatchback/Code_132.cs
#   inflating: code_by_types/Hatchback/Code_1320.cs
#   inflating: code_by_types/Hatchback/Code_1321.cs
#   inflating: code_by_types/Hatchback/Code_1322.cs
#   inflating: code_by_types/Hatchback/Code_1323.cs
#   inflating: code_by_types/Hatchback/Code_1324.cs
#   inflating: code_by_types/Hatchback/Code_1325.cs
#   inflating: code_by_types/Hatchback/Code_1326.cs
#   inflating: code_by_types/Hatchback/Code_1327.cs
#   inflating: code_by_types/Hatchback/Code_1328.cs
#   inflating: code_by_types/Hatchback/Code_1329.cs
#   inflating: code_by_types/Hatchback/Code_133.cs
#   inflating: code_by_types/Hatchback/Code_1330.cs
#   inflating: code_by_types/Hatchback/Code_1331.cs
#   inflating: code_by_types/Hatchback/Code_1332.cs
#   inflating: code_by_types/Hatchback/Code_1333.cs
#   inflating: code_by_types/Hatchback/Code_1334.cs
#   inflating: code_by_types/Hatchback/Code_1335.cs
#   inflating: code_by_types/Hatchback/Code_1336.cs
#   inflating: code_by_types/Hatchback/Code_1337.cs
#   inflating: code_by_types/Hatchback/Code_1338.cs
#   inflating: code_by_types/Hatchback/Code_1339.cs
#   inflating: code_by_types/Hatchback/Code_134.cs
#   inflating: code_by_types/Hatchback/Code_1340.cs
#   inflating: code_by_types/Hatchback/Code_1341.cs
#   inflating: code_by_types/Hatchback/Code_1342.cs
#   inflating: code_by_types/Hatchback/Code_1343.cs
#   inflating: code_by_types/Hatchback/Code_1344.cs
#   inflating: code_by_types/Hatchback/Code_1345.cs
#   inflating: code_by_types/Hatchback/Code_1346.cs
#   inflating: code_by_types/Hatchback/Code_1347.cs
#   inflating: code_by_types/Hatchback/Code_1348.cs
#   inflating: code_by_types/Hatchback/Code_1349.cs
#   inflating: code_by_types/Hatchback/Code_135.cs
#   inflating: code_by_types/Hatchback/Code_1350.cs
#   inflating: code_by_types/Hatchback/Code_1351.cs
#   inflating: code_by_types/Hatchback/Code_1352.cs
#   inflating: code_by_types/Hatchback/Code_1353.cs
#   inflating: code_by_types/Hatchback/Code_1354.cs
#   inflating: code_by_types/Hatchback/Code_1355.cs
#   inflating: code_by_types/Hatchback/Code_1356.cs
#   inflating: code_by_types/Hatchback/Code_1357.cs
#   inflating: code_by_types/Hatchback/Code_1358.cs
#   inflating: code_by_types/Hatchback/Code_1359.cs
#   inflating: code_by_types/Hatchback/Code_136.cs
#   inflating: code_by_types/Hatchback/Code_1360.cs
#   inflating: code_by_types/Hatchback/Code_1361.cs
#   inflating: code_by_types/Hatchback/Code_1362.cs
#   inflating: code_by_types/Hatchback/Code_1363.cs
#   inflating: code_by_types/Hatchback/Code_1364.cs
#   inflating: code_by_types/Hatchback/Code_1365.cs
#   inflating: code_by_types/Hatchback/Code_1366.cs
#   inflating: code_by_types/Hatchback/Code_1367.cs
#   inflating: code_by_types/Hatchback/Code_1368.cs
#   inflating: code_by_types/Hatchback/Code_1369.cs
#   inflating: code_by_types/Hatchback/Code_137.cs
#   inflating: code_by_types/Hatchback/Code_1370.cs
#   inflating: code_by_types/Hatchback/Code_1371.cs
#   inflating: code_by_types/Hatchback/Code_1372.cs
#   inflating: code_by_types/Hatchback/Code_1373.cs
#   inflating: code_by_types/Hatchback/Code_1374.cs
#   inflating: code_by_types/Hatchback/Code_1375.cs
#   inflating: code_by_types/Hatchback/Code_1376.cs
#   inflating: code_by_types/Hatchback/Code_1377.cs
#   inflating: code_by_types/Hatchback/Code_1378.cs
#   inflating: code_by_types/Hatchback/Code_1379.cs
#   inflating: code_by_types/Hatchback/Code_138.cs
#   inflating: code_by_types/Hatchback/Code_1380.cs
#   inflating: code_by_types/Hatchback/Code_1381.cs
#   inflating: code_by_types/Hatchback/Code_1382.cs
#   inflating: code_by_types/Hatchback/Code_1383.cs
#   inflating: code_by_types/Hatchback/Code_1384.cs
#   inflating: code_by_types/Hatchback/Code_1385.cs
#   inflating: code_by_types/Hatchback/Code_1386.cs
#   inflating: code_by_types/Hatchback/Code_1387.cs
#   inflating: code_by_types/Hatchback/Code_1388.cs
#   inflating: code_by_types/Hatchback/Code_1389.cs
#   inflating: code_by_types/Hatchback/Code_139.cs
#   inflating: code_by_types/Hatchback/Code_1390.cs
#   inflating: code_by_types/Hatchback/Code_1391.cs
#   inflating: code_by_types/Hatchback/Code_1392.cs
#   inflating: code_by_types/Hatchback/Code_1393.cs
#   inflating: code_by_types/Hatchback/Code_1394.cs
#   inflating: code_by_types/Hatchback/Code_1395.cs
#   inflating: code_by_types/Hatchback/Code_1396.cs
#   inflating: code_by_types/Hatchback/Code_1397.cs
#   inflating: code_by_types/Hatchback/Code_1398.cs
#   inflating: code_by_types/Hatchback/Code_1399.cs
#   inflating: code_by_types/Hatchback/Code_14.cs
#   inflating: code_by_types/Hatchback/Code_140.cs
#   inflating: code_by_types/Hatchback/Code_1400.cs
#   inflating: code_by_types/Hatchback/Code_1401.cs
#   inflating: code_by_types/Hatchback/Code_1402.cs
#   inflating: code_by_types/Hatchback/Code_1403.cs
#   inflating: code_by_types/Hatchback/Code_1404.cs
#   inflating: code_by_types/Hatchback/Code_1405.cs
#   inflating: code_by_types/Hatchback/Code_1406.cs
#   inflating: code_by_types/Hatchback/Code_1407.cs
#   inflating: code_by_types/Hatchback/Code_1408.cs
#   inflating: code_by_types/Hatchback/Code_1409.cs
#   inflating: code_by_types/Hatchback/Code_141.cs
#   inflating: code_by_types/Hatchback/Code_1410.cs
#   inflating: code_by_types/Hatchback/Code_1411.cs
#   inflating: code_by_types/Hatchback/Code_1412.cs
#   inflating: code_by_types/Hatchback/Code_1413.cs
#   inflating: code_by_types/Hatchback/Code_1414.cs
#   inflating: code_by_types/Hatchback/Code_1415.cs
#   inflating: code_by_types/Hatchback/Code_1416.cs
#   inflating: code_by_types/Hatchback/Code_1417.cs
#   inflating: code_by_types/Hatchback/Code_1418.cs
#   inflating: code_by_types/Hatchback/Code_1419.cs
#   inflating: code_by_types/Hatchback/Code_142.cs
#   inflating: code_by_types/Hatchback/Code_1420.cs
#   inflating: code_by_types/Hatchback/Code_1421.cs
#   inflating: code_by_types/Hatchback/Code_1422.cs
#   inflating: code_by_types/Hatchback/Code_1423.cs
#   inflating: code_by_types/Hatchback/Code_1424.cs
#   inflating: code_by_types/Hatchback/Code_1425.cs
#   inflating: code_by_types/Hatchback/Code_1426.cs
#   inflating: code_by_types/Hatchback/Code_1427.cs
#   inflating: code_by_types/Hatchback/Code_1428.cs
#   inflating: code_by_types/Hatchback/Code_1429.cs
#   inflating: code_by_types/Hatchback/Code_143.cs
#   inflating: code_by_types/Hatchback/Code_1430.cs
#   inflating: code_by_types/Hatchback/Code_1431.cs
#   inflating: code_by_types/Hatchback/Code_1432.cs
#   inflating: code_by_types/Hatchback/Code_1433.cs
#   inflating: code_by_types/Hatchback/Code_1434.cs
#   inflating: code_by_types/Hatchback/Code_1435.cs
#   inflating: code_by_types/Hatchback/Code_1436.cs
#   inflating: code_by_types/Hatchback/Code_1437.cs
#   inflating: code_by_types/Hatchback/Code_1438.cs
#   inflating: code_by_types/Hatchback/Code_1439.cs
#   inflating: code_by_types/Hatchback/Code_144.cs
#   inflating: code_by_types/Hatchback/Code_1440.cs
#   inflating: code_by_types/Hatchback/Code_1441.cs
#   inflating: code_by_types/Hatchback/Code_1442.cs
#   inflating: code_by_types/Hatchback/Code_1443.cs
#   inflating: code_by_types/Hatchback/Code_1444.cs
#   inflating: code_by_types/Hatchback/Code_1445.cs
#   inflating: code_by_types/Hatchback/Code_1446.cs
#   inflating: code_by_types/Hatchback/Code_1447.cs
#   inflating: code_by_types/Hatchback/Code_1448.cs
#   inflating: code_by_types/Hatchback/Code_1449.cs
#   inflating: code_by_types/Hatchback/Code_145.cs
#   inflating: code_by_types/Hatchback/Code_1450.cs
#   inflating: code_by_types/Hatchback/Code_1451.cs
#   inflating: code_by_types/Hatchback/Code_1452.cs
#   inflating: code_by_types/Hatchback/Code_1453.cs
#   inflating: code_by_types/Hatchback/Code_1454.cs
#   inflating: code_by_types/Hatchback/Code_1455.cs
#   inflating: code_by_types/Hatchback/Code_1456.cs
#   inflating: code_by_types/Hatchback/Code_1457.cs
#   inflating: code_by_types/Hatchback/Code_1458.cs
#   inflating: code_by_types/Hatchback/Code_1459.cs
#   inflating: code_by_types/Hatchback/Code_146.cs
#   inflating: code_by_types/Hatchback/Code_1460.cs
#   inflating: code_by_types/Hatchback/Code_1461.cs
#   inflating: code_by_types/Hatchback/Code_1462.cs
#   inflating: code_by_types/Hatchback/Code_1463.cs
#   inflating: code_by_types/Hatchback/Code_1464.cs
#   inflating: code_by_types/Hatchback/Code_1465.cs
#   inflating: code_by_types/Hatchback/Code_1466.cs
#   inflating: code_by_types/Hatchback/Code_1467.cs
#   inflating: code_by_types/Hatchback/Code_1468.cs
#   inflating: code_by_types/Hatchback/Code_1469.cs
#   inflating: code_by_types/Hatchback/Code_147.cs
#   inflating: code_by_types/Hatchback/Code_1470.cs
#   inflating: code_by_types/Hatchback/Code_1471.cs
#   inflating: code_by_types/Hatchback/Code_1472.cs
#   inflating: code_by_types/Hatchback/Code_1473.cs
#   inflating: code_by_types/Hatchback/Code_1474.cs
#   inflating: code_by_types/Hatchback/Code_1475.cs
#   inflating: code_by_types/Hatchback/Code_1476.cs
#   inflating: code_by_types/Hatchback/Code_1477.cs
#   inflating: code_by_types/Hatchback/Code_1478.cs
#   inflating: code_by_types/Hatchback/Code_1479.cs
#   inflating: code_by_types/Hatchback/Code_148.cs
#   inflating: code_by_types/Hatchback/Code_1480.cs
#   inflating: code_by_types/Hatchback/Code_1481.cs
#   inflating: code_by_types/Hatchback/Code_1482.cs
#   inflating: code_by_types/Hatchback/Code_1483.cs
#   inflating: code_by_types/Hatchback/Code_1484.cs
#   inflating: code_by_types/Hatchback/Code_1485.cs
#   inflating: code_by_types/Hatchback/Code_1486.cs
#   inflating: code_by_types/Hatchback/Code_1487.cs
#   inflating: code_by_types/Hatchback/Code_1488.cs
#   inflating: code_by_types/Hatchback/Code_1489.cs
#   inflating: code_by_types/Hatchback/Code_149.cs
#   inflating: code_by_types/Hatchback/Code_1490.cs
#   inflating: code_by_types/Hatchback/Code_1491.cs
#   inflating: code_by_types/Hatchback/Code_1492.cs
#   inflating: code_by_types/Hatchback/Code_1493.cs
#   inflating: code_by_types/Hatchback/Code_1494.cs
#   inflating: code_by_types/Hatchback/Code_1495.cs
#   inflating: code_by_types/Hatchback/Code_1496.cs
#   inflating: code_by_types/Hatchback/Code_1497.cs
#   inflating: code_by_types/Hatchback/Code_1498.cs
#   inflating: code_by_types/Hatchback/Code_1499.cs
#   inflating: code_by_types/Hatchback/Code_15.cs
#   inflating: code_by_types/Hatchback/Code_150.cs
#   inflating: code_by_types/Hatchback/Code_1500.cs
#   inflating: code_by_types/Hatchback/Code_1501.cs
#   inflating: code_by_types/Hatchback/Code_1502.cs
#   inflating: code_by_types/Hatchback/Code_1503.cs
#   inflating: code_by_types/Hatchback/Code_1504.cs
#   inflating: code_by_types/Hatchback/Code_1505.cs
#   inflating: code_by_types/Hatchback/Code_1506.cs
#   inflating: code_by_types/Hatchback/Code_1507.cs
#   inflating: code_by_types/Hatchback/Code_1508.cs
#   inflating: code_by_types/Hatchback/Code_1509.cs
#   inflating: code_by_types/Hatchback/Code_151.cs
#   inflating: code_by_types/Hatchback/Code_1510.cs
#   inflating: code_by_types/Hatchback/Code_1511.cs
#   inflating: code_by_types/Hatchback/Code_1512.cs
#   inflating: code_by_types/Hatchback/Code_1513.cs
#   inflating: code_by_types/Hatchback/Code_1514.cs
#   inflating: code_by_types/Hatchback/Code_1515.cs
#   inflating: code_by_types/Hatchback/Code_1516.cs
#   inflating: code_by_types/Hatchback/Code_1517.cs
#   inflating: code_by_types/Hatchback/Code_1518.cs
#   inflating: code_by_types/Hatchback/Code_1519.cs
#   inflating: code_by_types/Hatchback/Code_152.cs
#   inflating: code_by_types/Hatchback/Code_1520.cs
#   inflating: code_by_types/Hatchback/Code_1521.cs
#   inflating: code_by_types/Hatchback/Code_1522.cs
#   inflating: code_by_types/Hatchback/Code_1523.cs
#   inflating: code_by_types/Hatchback/Code_1524.cs
#   inflating: code_by_types/Hatchback/Code_1525.cs
#   inflating: code_by_types/Hatchback/Code_1526.cs
#   inflating: code_by_types/Hatchback/Code_1527.cs
#   inflating: code_by_types/Hatchback/Code_1528.cs
#   inflating: code_by_types/Hatchback/Code_1529.cs
#   inflating: code_by_types/Hatchback/Code_153.cs
#   inflating: code_by_types/Hatchback/Code_1530.cs
#   inflating: code_by_types/Hatchback/Code_1531.cs
#   inflating: code_by_types/Hatchback/Code_1532.cs
#   inflating: code_by_types/Hatchback/Code_1533.cs
#   inflating: code_by_types/Hatchback/Code_1534.cs
#   inflating: code_by_types/Hatchback/Code_1535.cs
#   inflating: code_by_types/Hatchback/Code_1536.cs
#   inflating: code_by_types/Hatchback/Code_1537.cs
#   inflating: code_by_types/Hatchback/Code_1538.cs
#   inflating: code_by_types/Hatchback/Code_1539.cs
#   inflating: code_by_types/Hatchback/Code_154.cs
#   inflating: code_by_types/Hatchback/Code_1540.cs
#   inflating: code_by_types/Hatchback/Code_1541.cs
#   inflating: code_by_types/Hatchback/Code_1542.cs
#   inflating: code_by_types/Hatchback/Code_1543.cs
#   inflating: code_by_types/Hatchback/Code_1544.cs
#   inflating: code_by_types/Hatchback/Code_1545.cs
#   inflating: code_by_types/Hatchback/Code_1546.cs
#   inflating: code_by_types/Hatchback/Code_1547.cs
#   inflating: code_by_types/Hatchback/Code_1548.cs
#   inflating: code_by_types/Hatchback/Code_1549.cs
#   inflating: code_by_types/Hatchback/Code_155.cs
#   inflating: code_by_types/Hatchback/Code_1550.cs
#   inflating: code_by_types/Hatchback/Code_1551.cs
#   inflating: code_by_types/Hatchback/Code_1552.cs
#   inflating: code_by_types/Hatchback/Code_1553.cs
#   inflating: code_by_types/Hatchback/Code_1554.cs
#   inflating: code_by_types/Hatchback/Code_1555.cs
#   inflating: code_by_types/Hatchback/Code_1556.cs
#   inflating: code_by_types/Hatchback/Code_1557.cs
#   inflating: code_by_types/Hatchback/Code_1558.cs
#   inflating: code_by_types/Hatchback/Code_1559.cs
#   inflating: code_by_types/Hatchback/Code_156.cs
#   inflating: code_by_types/Hatchback/Code_1560.cs
#   inflating: code_by_types/Hatchback/Code_1561.cs
#   inflating: code_by_types/Hatchback/Code_1562.cs
#   inflating: code_by_types/Hatchback/Code_1563.cs
#   inflating: code_by_types/Hatchback/Code_1564.cs
#   inflating: code_by_types/Hatchback/Code_1565.cs
#   inflating: code_by_types/Hatchback/Code_1566.cs
#   inflating: code_by_types/Hatchback/Code_1567.cs
#   inflating: code_by_types/Hatchback/Code_1568.cs
#   inflating: code_by_types/Hatchback/Code_1569.cs
#   inflating: code_by_types/Hatchback/Code_157.cs
#   inflating: code_by_types/Hatchback/Code_1570.cs
#   inflating: code_by_types/Hatchback/Code_1571.cs
#   inflating: code_by_types/Hatchback/Code_1572.cs
#   inflating: code_by_types/Hatchback/Code_1573.cs
#   inflating: code_by_types/Hatchback/Code_1574.cs
#   inflating: code_by_types/Hatchback/Code_1575.cs
#   inflating: code_by_types/Hatchback/Code_1576.cs
#   inflating: code_by_types/Hatchback/Code_1577.cs
#   inflating: code_by_types/Hatchback/Code_1578.cs
#   inflating: code_by_types/Hatchback/Code_1579.cs
#   inflating: code_by_types/Hatchback/Code_158.cs
#   inflating: code_by_types/Hatchback/Code_1580.cs
#   inflating: code_by_types/Hatchback/Code_1581.cs
#   inflating: code_by_types/Hatchback/Code_1582.cs
#   inflating: code_by_types/Hatchback/Code_1583.cs
#   inflating: code_by_types/Hatchback/Code_1584.cs
#   inflating: code_by_types/Hatchback/Code_1585.cs
#   inflating: code_by_types/Hatchback/Code_1586.cs
#   inflating: code_by_types/Hatchback/Code_1587.cs
#   inflating: code_by_types/Hatchback/Code_1588.cs
#   inflating: code_by_types/Hatchback/Code_1589.cs
#   inflating: code_by_types/Hatchback/Code_159.cs
#   inflating: code_by_types/Hatchback/Code_1590.cs
#   inflating: code_by_types/Hatchback/Code_1591.cs
#   inflating: code_by_types/Hatchback/Code_1592.cs
#   inflating: code_by_types/Hatchback/Code_1593.cs
#   inflating: code_by_types/Hatchback/Code_1594.cs
#   inflating: code_by_types/Hatchback/Code_1595.cs
#   inflating: code_by_types/Hatchback/Code_1596.cs
#   inflating: code_by_types/Hatchback/Code_1597.cs
#   inflating: code_by_types/Hatchback/Code_1598.cs
#   inflating: code_by_types/Hatchback/Code_1599.cs
#   inflating: code_by_types/Hatchback/Code_16.cs
#   inflating: code_by_types/Hatchback/Code_160.cs
#   inflating: code_by_types/Hatchback/Code_1600.cs
#   inflating: code_by_types/Hatchback/Code_1601.cs
#   inflating: code_by_types/Hatchback/Code_1602.cs
#   inflating: code_by_types/Hatchback/Code_1603.cs
#   inflating: code_by_types/Hatchback/Code_1604.cs
#   inflating: code_by_types/Hatchback/Code_1605.cs
#   inflating: code_by_types/Hatchback/Code_1606.cs
#   inflating: code_by_types/Hatchback/Code_1607.cs
#   inflating: code_by_types/Hatchback/Code_1608.cs
#   inflating: code_by_types/Hatchback/Code_1609.cs
#   inflating: code_by_types/Hatchback/Code_161.cs
#   inflating: code_by_types/Hatchback/Code_1610.cs
#   inflating: code_by_types/Hatchback/Code_1611.cs
#   inflating: code_by_types/Hatchback/Code_1612.cs
#   inflating: code_by_types/Hatchback/Code_1613.cs
#   inflating: code_by_types/Hatchback/Code_1614.cs
#   inflating: code_by_types/Hatchback/Code_1615.cs
#   inflating: code_by_types/Hatchback/Code_1616.cs
#   inflating: code_by_types/Hatchback/Code_1617.cs
#   inflating: code_by_types/Hatchback/Code_1618.cs
#   inflating: code_by_types/Hatchback/Code_1619.cs
#   inflating: code_by_types/Hatchback/Code_162.cs
#   inflating: code_by_types/Hatchback/Code_1620.cs
#   inflating: code_by_types/Hatchback/Code_1621.cs
#   inflating: code_by_types/Hatchback/Code_1622.cs
#   inflating: code_by_types/Hatchback/Code_1623.cs
#   inflating: code_by_types/Hatchback/Code_1624.cs
#   inflating: code_by_types/Hatchback/Code_1625.cs
#   inflating: code_by_types/Hatchback/Code_1626.cs
#   inflating: code_by_types/Hatchback/Code_1627.cs
#   inflating: code_by_types/Hatchback/Code_1628.cs
#   inflating: code_by_types/Hatchback/Code_1629.cs
#   inflating: code_by_types/Hatchback/Code_163.cs
#   inflating: code_by_types/Hatchback/Code_1630.cs
#   inflating: code_by_types/Hatchback/Code_1631.cs
#   inflating: code_by_types/Hatchback/Code_1632.cs
#   inflating: code_by_types/Hatchback/Code_1633.cs
# ...
#   inflating: code_by_types/Van/Code_679.cs
#   inflating: code_by_types/Van/Code_68.cs
#   inflating: code_by_types/Van/Code_680.cs
#   inflating: code_by_types/Van/Code_681.cs
#   inflating: code_by_types/Van/Code_682.cs
#   inflating: code_by_types/Van/Code_683.cs
#   inflating: code_by_types/Van/Code_684.cs
#   inflating: code_by_types/Van/Code_685.cs
#   inflating: code_by_types/Van/Code_686.cs
#   inflating: code_by_types/Van/Code_687.cs
#   inflating: code_by_types/Van/Code_688.cs
#   inflating: code_by_types/Van/Code_689.cs
#   inflating: code_by_types/Van/Code_69.cs
#   inflating: code_by_types/Van/Code_690.cs
#   inflating: code_by_types/Van/Code_691.cs
#   inflating: code_by_types/Van/Code_692.cs
#   inflating: code_by_types/Van/Code_693.cs
#   inflating: code_by_types/Van/Code_694.cs
#   inflating: code_by_types/Van/Code_695.cs
#   inflating: code_by_types/Van/Code_696.cs
#   inflating: code_by_types/Van/Code_697.cs
#   inflating: code_by_types/Van/Code_698.cs
#   inflating: code_by_types/Van/Code_699.cs
#   inflating: code_by_types/Van/Code_7.cs
#   inflating: code_by_types/Van/Code_70.cs
#   inflating: code_by_types/Van/Code_700.cs
#   inflating: code_by_types/Van/Code_701.cs
#   inflating: code_by_types/Van/Code_702.cs
#   inflating: code_by_types/Van/Code_703.cs
#   inflating: code_by_types/Van/Code_704.cs
#   inflating: code_by_types/Van/Code_705.cs
#   inflating: code_by_types/Van/Code_706.cs
#   inflating: code_by_types/Van/Code_707.cs
#   inflating: code_by_types/Van/Code_708.cs
#   inflating: code_by_types/Van/Code_709.cs
#   inflating: code_by_types/Van/Code_71.cs
#   inflating: code_by_types/Van/Code_710.cs
#   inflating: code_by_types/Van/Code_711.cs
#   inflating: code_by_types/Van/Code_712.cs
#   inflating: code_by_types/Van/Code_713.cs
#   inflating: code_by_types/Van/Code_714.cs
#   inflating: code_by_types/Van/Code_715.cs
#   inflating: code_by_types/Van/Code_716.cs
#   inflating: code_by_types/Van/Code_717.cs
#   inflating: code_by_types/Van/Code_718.cs
#   inflating: code_by_types/Van/Code_719.cs
#   inflating: code_by_types/Van/Code_72.cs
#   inflating: code_by_types/Van/Code_720.cs
#   inflating: code_by_types/Van/Code_721.cs
#   inflating: code_by_types/Van/Code_722.cs
#   inflating: code_by_types/Van/Code_723.cs
#   inflating: code_by_types/Van/Code_724.cs
#   inflating: code_by_types/Van/Code_725.cs
#   inflating: code_by_types/Van/Code_726.cs
#   inflating: code_by_types/Van/Code_727.cs
#   inflating: code_by_types/Van/Code_728.cs
#   inflating: code_by_types/Van/Code_729.cs
#   inflating: code_by_types/Van/Code_73.cs
#   inflating: code_by_types/Van/Code_730.cs
#   inflating: code_by_types/Van/Code_731.cs
#   inflating: code_by_types/Van/Code_732.cs
#   inflating: code_by_types/Van/Code_733.cs
#   inflating: code_by_types/Van/Code_734.cs
#   inflating: code_by_types/Van/Code_735.cs
#   inflating: code_by_types/Van/Code_736.cs
#   inflating: code_by_types/Van/Code_737.cs
#   inflating: code_by_types/Van/Code_738.cs
#   inflating: code_by_types/Van/Code_739.cs
#   inflating: code_by_types/Van/Code_74.cs
#   inflating: code_by_types/Van/Code_740.cs
#   inflating: code_by_types/Van/Code_741.cs
#   inflating: code_by_types/Van/Code_742.cs
#   inflating: code_by_types/Van/Code_743.cs
#   inflating: code_by_types/Van/Code_744.cs
#   inflating: code_by_types/Van/Code_745.cs
#   inflating: code_by_types/Van/Code_746.cs
#   inflating: code_by_types/Van/Code_747.cs
#   inflating: code_by_types/Van/Code_748.cs
#   inflating: code_by_types/Van/Code_749.cs
#   inflating: code_by_types/Van/Code_75.cs
#   inflating: code_by_types/Van/Code_750.cs
#   inflating: code_by_types/Van/Code_751.cs
#   inflating: code_by_types/Van/Code_752.cs
#   inflating: code_by_types/Van/Code_753.cs
#   inflating: code_by_types/Van/Code_754.cs
#   inflating: code_by_types/Van/Code_755.cs
#   inflating: code_by_types/Van/Code_756.cs
#   inflating: code_by_types/Van/Code_757.cs
#   inflating: code_by_types/Van/Code_758.cs
#   inflating: code_by_types/Van/Code_759.cs
#   inflating: code_by_types/Van/Code_76.cs
#   inflating: code_by_types/Van/Code_760.cs
#   inflating: code_by_types/Van/Code_761.cs
#   inflating: code_by_types/Van/Code_762.cs
#   inflating: code_by_types/Van/Code_763.cs
#   inflating: code_by_types/Van/Code_764.cs
#   inflating: code_by_types/Van/Code_765.cs
#   inflating: code_by_types/Van/Code_766.cs
#   inflating: code_by_types/Van/Code_767.cs
#   inflating: code_by_types/Van/Code_768.cs
#   inflating: code_by_types/Van/Code_769.cs
#   inflating: code_by_types/Van/Code_77.cs
#   inflating: code_by_types/Van/Code_770.cs
#   inflating: code_by_types/Van/Code_771.cs
#   inflating: code_by_types/Van/Code_772.cs
#   inflating: code_by_types/Van/Code_773.cs
#   inflating: code_by_types/Van/Code_774.cs
#   inflating: code_by_types/Van/Code_775.cs
#   inflating: code_by_types/Van/Code_776.cs
#   inflating: code_by_types/Van/Code_777.cs
#   inflating: code_by_types/Van/Code_778.cs
#   inflating: code_by_types/Van/Code_779.cs
#   inflating: code_by_types/Van/Code_78.cs
#   inflating: code_by_types/Van/Code_780.cs
#   inflating: code_by_types/Van/Code_781.cs
#   inflating: code_by_types/Van/Code_782.cs
#   inflating: code_by_types/Van/Code_783.cs
#   inflating: code_by_types/Van/Code_784.cs
#   inflating: code_by_types/Van/Code_785.cs
#   inflating: code_by_types/Van/Code_786.cs
#   inflating: code_by_types/Van/Code_787.cs
#   inflating: code_by_types/Van/Code_788.cs
#   inflating: code_by_types/Van/Code_789.cs
#   inflating: code_by_types/Van/Code_79.cs
#   inflating: code_by_types/Van/Code_790.cs
#   inflating: code_by_types/Van/Code_791.cs
#   inflating: code_by_types/Van/Code_792.cs
#   inflating: code_by_types/Van/Code_793.cs
#   inflating: code_by_types/Van/Code_794.cs
#   inflating: code_by_types/Van/Code_795.cs
#   inflating: code_by_types/Van/Code_796.cs
#   inflating: code_by_types/Van/Code_797.cs
#   inflating: code_by_types/Van/Code_798.cs
#   inflating: code_by_types/Van/Code_799.cs
#   inflating: code_by_types/Van/Code_8.cs
#   inflating: code_by_types/Van/Code_80.cs
#   inflating: code_by_types/Van/Code_800.cs
#   inflating: code_by_types/Van/Code_801.cs
#   inflating: code_by_types/Van/Code_802.cs
#   inflating: code_by_types/Van/Code_803.cs
#   inflating: code_by_types/Van/Code_804.cs
#   inflating: code_by_types/Van/Code_805.cs
#   inflating: code_by_types/Van/Code_806.cs
#   inflating: code_by_types/Van/Code_807.cs
#   inflating: code_by_types/Van/Code_808.cs
#   inflating: code_by_types/Van/Code_809.cs
#   inflating: code_by_types/Van/Code_81.cs
#   inflating: code_by_types/Van/Code_810.cs
#   inflating: code_by_types/Van/Code_811.cs
#   inflating: code_by_types/Van/Code_812.cs
#   inflating: code_by_types/Van/Code_813.cs
#   inflating: code_by_types/Van/Code_814.cs
#   inflating: code_by_types/Van/Code_815.cs
#   inflating: code_by_types/Van/Code_816.cs
#   inflating: code_by_types/Van/Code_817.cs
#   inflating: code_by_types/Van/Code_818.cs
#   inflating: code_by_types/Van/Code_819.cs
#   inflating: code_by_types/Van/Code_82.cs
#   inflating: code_by_types/Van/Code_820.cs
#   inflating: code_by_types/Van/Code_821.cs
#   inflating: code_by_types/Van/Code_822.cs
#   inflating: code_by_types/Van/Code_823.cs
#   inflating: code_by_types/Van/Code_824.cs
#   inflating: code_by_types/Van/Code_825.cs
#   inflating: code_by_types/Van/Code_826.cs
#   inflating: code_by_types/Van/Code_827.cs
#   inflating: code_by_types/Van/Code_828.cs
#   inflating: code_by_types/Van/Code_829.cs
#   inflating: code_by_types/Van/Code_83.cs
#   inflating: code_by_types/Van/Code_830.cs
#   inflating: code_by_types/Van/Code_831.cs
#   inflating: code_by_types/Van/Code_832.cs
#   inflating: code_by_types/Van/Code_833.cs
#   inflating: code_by_types/Van/Code_834.cs
#   inflating: code_by_types/Van/Code_835.cs
#   inflating: code_by_types/Van/Code_836.cs
#   inflating: code_by_types/Van/Code_837.cs
#   inflating: code_by_types/Van/Code_838.cs
#   inflating: code_by_types/Van/Code_839.cs
#   inflating: code_by_types/Van/Code_84.cs
#   inflating: code_by_types/Van/Code_840.cs
#   inflating: code_by_types/Van/Code_841.cs
#   inflating: code_by_types/Van/Code_842.cs
#   inflating: code_by_types/Van/Code_843.cs
#   inflating: code_by_types/Van/Code_844.cs
#   inflating: code_by_types/Van/Code_845.cs
#   inflating: code_by_types/Van/Code_846.cs
#   inflating: code_by_types/Van/Code_847.cs
#   inflating: code_by_types/Van/Code_848.cs
#   inflating: code_by_types/Van/Code_849.cs
#   inflating: code_by_types/Van/Code_85.cs
#   inflating: code_by_types/Van/Code_850.cs
#   inflating: code_by_types/Van/Code_851.cs
#   inflating: code_by_types/Van/Code_852.cs
#   inflating: code_by_types/Van/Code_853.cs
#   inflating: code_by_types/Van/Code_854.cs
#   inflating: code_by_types/Van/Code_855.cs
#   inflating: code_by_types/Van/Code_856.cs
#   inflating: code_by_types/Van/Code_857.cs
#   inflating: code_by_types/Van/Code_858.cs
#   inflating: code_by_types/Van/Code_859.cs
#   inflating: code_by_types/Van/Code_86.cs
#   inflating: code_by_types/Van/Code_860.cs
#   inflating: code_by_types/Van/Code_861.cs
#   inflating: code_by_types/Van/Code_862.cs
#   inflating: code_by_types/Van/Code_863.cs
#   inflating: code_by_types/Van/Code_864.cs
#   inflating: code_by_types/Van/Code_865.cs
#   inflating: code_by_types/Van/Code_866.cs
#   inflating: code_by_types/Van/Code_867.cs
#   inflating: code_by_types/Van/Code_868.cs
#   inflating: code_by_types/Van/Code_869.cs
#   inflating: code_by_types/Van/Code_87.cs
#   inflating: code_by_types/Van/Code_870.cs
#   inflating: code_by_types/Van/Code_871.cs
#   inflating: code_by_types/Van/Code_872.cs
#   inflating: code_by_types/Van/Code_873.cs
#   inflating: code_by_types/Van/Code_874.cs
#   inflating: code_by_types/Van/Code_875.cs
#   inflating: code_by_types/Van/Code_876.cs
#   inflating: code_by_types/Van/Code_877.cs
#   inflating: code_by_types/Van/Code_878.cs
#   inflating: code_by_types/Van/Code_879.cs
#   inflating: code_by_types/Van/Code_88.cs
#   inflating: code_by_types/Van/Code_880.cs
#   inflating: code_by_types/Van/Code_881.cs
#   inflating: code_by_types/Van/Code_882.cs
#   inflating: code_by_types/Van/Code_883.cs
#   inflating: code_by_types/Van/Code_884.cs
#   inflating: code_by_types/Van/Code_885.cs
#   inflating: code_by_types/Van/Code_886.cs
#   inflating: code_by_types/Van/Code_887.cs
#   inflating: code_by_types/Van/Code_888.cs
#   inflating: code_by_types/Van/Code_889.cs
#   inflating: code_by_types/Van/Code_89.cs
#   inflating: code_by_types/Van/Code_890.cs
#   inflating: code_by_types/Van/Code_891.cs
#   inflating: code_by_types/Van/Code_892.cs
#   inflating: code_by_types/Van/Code_893.cs
#   inflating: code_by_types/Van/Code_894.cs
#   inflating: code_by_types/Van/Code_895.cs
#   inflating: code_by_types/Van/Code_896.cs
#   inflating: code_by_types/Van/Code_897.cs
#   inflating: code_by_types/Van/Code_898.cs
#   inflating: code_by_types/Van/Code_899.cs
#   inflating: code_by_types/Van/Code_9.cs
#   inflating: code_by_types/Van/Code_90.cs
#   inflating: code_by_types/Van/Code_900.cs
#   inflating: code_by_types/Van/Code_901.cs
#   inflating: code_by_types/Van/Code_902.cs
#   inflating: code_by_types/Van/Code_903.cs
#   inflating: code_by_types/Van/Code_904.cs
#   inflating: code_by_types/Van/Code_905.cs
#   inflating: code_by_types/Van/Code_906.cs
#   inflating: code_by_types/Van/Code_907.cs
#   inflating: code_by_types/Van/Code_908.cs
#   inflating: code_by_types/Van/Code_909.cs
#   inflating: code_by_types/Van/Code_91.cs
#   inflating: code_by_types/Van/Code_910.cs
#   inflating: code_by_types/Van/Code_911.cs
#   inflating: code_by_types/Van/Code_912.cs
#   inflating: code_by_types/Van/Code_913.cs
#   inflating: code_by_types/Van/Code_914.cs
#   inflating: code_by_types/Van/Code_915.cs
#   inflating: code_by_types/Van/Code_916.cs
#   inflating: code_by_types/Van/Code_917.cs
#   inflating: code_by_types/Van/Code_918.cs
#   inflating: code_by_types/Van/Code_919.cs
#   inflating: code_by_types/Van/Code_92.cs
#   inflating: code_by_types/Van/Code_920.cs
#   inflating: code_by_types/Van/Code_921.cs
#   inflating: code_by_types/Van/Code_922.cs
#   inflating: code_by_types/Van/Code_923.cs
#   inflating: code_by_types/Van/Code_924.cs
#   inflating: code_by_types/Van/Code_925.cs
#   inflating: code_by_types/Van/Code_926.cs
#   inflating: code_by_types/Van/Code_927.cs
#   inflating: code_by_types/Van/Code_928.cs
#   inflating: code_by_types/Van/Code_929.cs
#   inflating: code_by_types/Van/Code_93.cs
#   inflating: code_by_types/Van/Code_930.cs
#   inflating: code_by_types/Van/Code_931.cs
#   inflating: code_by_types/Van/Code_932.cs
#   inflating: code_by_types/Van/Code_933.cs
#   inflating: code_by_types/Van/Code_934.cs
#   inflating: code_by_types/Van/Code_935.cs
#   inflating: code_by_types/Van/Code_936.cs
#   inflating: code_by_types/Van/Code_937.cs
#   inflating: code_by_types/Van/Code_938.cs
#   inflating: code_by_types/Van/Code_939.cs
#   inflating: code_by_types/Van/Code_94.cs
#   inflating: code_by_types/Van/Code_940.cs
#   inflating: code_by_types/Van/Code_941.cs
#   inflating: code_by_types/Van/Code_942.cs
#   inflating: code_by_types/Van/Code_943.cs
#   inflating: code_by_types/Van/Code_944.cs
#   inflating: code_by_types/Van/Code_945.cs
#   inflating: code_by_types/Van/Code_946.cs
#   inflating: code_by_types/Van/Code_947.cs
#   inflating: code_by_types/Van/Code_948.cs
#   inflating: code_by_types/Van/Code_949.cs
#   inflating: code_by_types/Van/Code_95.cs
#   inflating: code_by_types/Van/Code_950.cs
#   inflating: code_by_types/Van/Code_951.cs
#   inflating: code_by_types/Van/Code_952.cs
#   inflating: code_by_types/Van/Code_953.cs
#   inflating: code_by_types/Van/Code_954.cs
#   inflating: code_by_types/Van/Code_955.cs
#   inflating: code_by_types/Van/Code_956.cs
#   inflating: code_by_types/Van/Code_957.cs
#   inflating: code_by_types/Van/Code_958.cs
#   inflating: code_by_types/Van/Code_959.cs
#   inflating: code_by_types/Van/Code_96.cs
#   inflating: code_by_types/Van/Code_960.cs
#   inflating: code_by_types/Van/Code_961.cs
#   inflating: code_by_types/Van/Code_962.cs
#   inflating: code_by_types/Van/Code_963.cs
#   inflating: code_by_types/Van/Code_964.cs
#   inflating: code_by_types/Van/Code_965.cs
#   inflating: code_by_types/Van/Code_966.cs
#   inflating: code_by_types/Van/Code_967.cs
#   inflating: code_by_types/Van/Code_968.cs
#   inflating: code_by_types/Van/Code_969.cs
#   inflating: code_by_types/Van/Code_97.cs
#   inflating: code_by_types/Van/Code_970.cs
#   inflating: code_by_types/Van/Code_971.cs
#   inflating: code_by_types/Van/Code_972.cs
#   inflating: code_by_types/Van/Code_973.cs
#   inflating: code_by_types/Van/Code_974.cs
#   inflating: code_by_types/Van/Code_975.cs
#   inflating: code_by_types/Van/Code_976.cs
#   inflating: code_by_types/Van/Code_977.cs
#   inflating: code_by_types/Van/Code_978.cs
#   inflating: code_by_types/Van/Code_979.cs
#   inflating: code_by_types/Van/Code_98.cs
#   inflating: code_by_types/Van/Code_980.cs
#   inflating: code_by_types/Van/Code_981.cs
#   inflating: code_by_types/Van/Code_982.cs
#   inflating: code_by_types/Van/Code_983.cs
#   inflating: code_by_types/Van/Code_984.cs
#   inflating: code_by_types/Van/Code_985.cs
#   inflating: code_by_types/Van/Code_986.cs
#   inflating: code_by_types/Van/Code_987.cs
#   inflating: code_by_types/Van/Code_988.cs
#   inflating: code_by_types/Van/Code_989.cs
#   inflating: code_by_types/Van/Code_99.cs
#   inflating: code_by_types/Van/Code_990.cs
#   inflating: code_by_types/Van/Code_991.cs
#   inflating: code_by_types/Van/Code_992.cs
#   inflating: code_by_types/Van/Code_993.cs
#   inflating: code_by_types/Van/Code_994.cs
#   inflating: code_by_types/Van/Code_995.cs
#   inflating: code_by_types/Van/Code_996.cs
#   inflating: code_by_types/Van/Code_997.cs
#   inflating: code_by_types/Van/Code_998.cs
#   inflating: code_by_types/Van/Code_999.cs

# %%
dataset = load_dataset(dataset_name)

with open("train_nl.json", "r") as f:
    data = json.load(f)
small_dataset = {"input":[], "natural_input":[], "output":[], "text": []}
keys = [int(k) for k in data.keys()]
sorted_keys = sorted(keys)
for ind in tqdm(sorted_keys):
    natural_input = ""
    try:
        natural_input = json.loads(data[str(ind)])["rewritten request"]
    except:
        continue
    if natural_input != "":
        row = dataset["train"][ind]
        small_dataset["input"].append(row["input"])
        small_dataset["output"].append(row["output"])
        small_dataset["text"].append("")
        small_dataset["natural_input"].append(natural_input)
small_dataset = Dataset.from_dict(small_dataset)
print(f"Dataset length: {len(small_dataset)}")
small_dataset = small_dataset.train_test_split(test_size=0.05, seed=42)
# Out:
#   0%|          | 0/13462 [00:00<?, ?it/s]
# Dataset length: 13442

# %%
small_dataset["test"]["natural_input"][232]
# Out:
# 'Craft a compact, two-wheeled vehicle. It should measure 1.67 meters in width and 1.35 meters in height, with small-radius wheels.'

# %%
with open("generations.json", "r") as f:
    generations = json.load(f)
eval_dataset = {"input":[], "output":[], "natural_input":[], "generation":[]}
for key in generations.keys():
    ind = int(key)
    row = small_dataset["test"][ind]
    gen = generations[key]
    eval_dataset["generation"].append(gen)
    eval_dataset["input"].append(row["input"])
    eval_dataset["output"].append(row["output"])
    eval_dataset["natural_input"].append(row["natural_input"])
eval_dataset = Dataset.from_dict(eval_dataset)

# %%
ind = 300
print(eval_dataset["natural_input"][ind])
print(eval_dataset["generation"][ind])
# Out:
# Craft a compact vehicle with a small hood and a spacious body, devoid of a boot. It should have two wheelsets, each with a radius of 40 cm, and a width of 1.67 meters.
# Here's the C# class for the car you described, with the parameters filled according to the user's request:
#
# ```csharp
# using System.Collections.Generic;
# using System;
# using System.Collections;
#
# namespace GenerativeDesign.Cars
# {
#     public class Car : CarBase
#     {
#         public Car()
#         {
#             Length = 250f;
#             Width = 167f;
#             Height = 150f;
#
#             WheelWidth = 20f;
#             WheelRadius = 40f;
#             WheelRelativeBiasAlongWidth = 0.1f;
#             WheelRelativeBiasesAlongLength = new List<float>() { 0.2f, 0.8f };
#
#             WheelBaseSegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 1f } };
#             WheelBaseSegmentsBottomSurfaces = new List<Line>() { new Constant(height: 20f) };
#             WheelBaseTopSurface = new Constant(height: 80f);
#             GapBetweenWheelAndBase = 3f;
#
#             BodySegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 0.2f }, new List<float>(){ 0.2f, 0.8f }, new List<float>(){ 0.8f, 1f } };
#             BodySegmentsTopSurfaces = new List<Line>() {
#                 new TotalRounded(minHeight: 80f, maxHeight: 100f, leftRounded: true),
#                 new CornerRounded(minHeight: 100f, maxHeight: 150f, cornerRelativeLength: 0.2f, surfaceAbsoluteLength: 150f, leftCornerRounded: true, rightCornerRounded: true),
#                 new TotalRounded(minHeight: 80f, maxHeight: 100f, leftRounded: false)
#             };
#         }
#     }
# }
# ```
#
# Explanation:
# - The car has a length of 250 cm, a width of 167 cm, and a height of 150 cm.
# - Each wheel has a width of 20 cm and a radius of 40 cm. The wheels are biased into the car by 10% of their width.
# - The wheel base consists of a single segment spanning the entire length of the car, with a constant height of 20 cm (wheel radius + gap).
# - The car body consists of three segments: a small bonnet, a large body, and no boot. The large body segment has rounded corners, and the bonnet and boot segments are rounded.

# %%
extraction = extraction_score(eval_dataset["generation"])
print(f"Extraction score: {extraction}")
# Out:
#   0%|          | 0/625 [00:00<?, ?it/s]
# Extraction score: 1.0

# %%
codes = extract_codes(eval_dataset["generation"])
# Out:
#   0%|          | 0/625 [00:00<?, ?it/s]

# %%
compilation = compilation_score(codes)
print(f"Compilation score: {compilation}")
# Out:
#   0%|          | 0/625 [00:00<?, ?it/s]
# Compilation score: 0.9952

# %%
inds, jsons = transform_codes_to_jsons(codes)
# Out:
#   0%|          | 0/625 [00:00<?, ?it/s]

# %%
descriptions = [eval_dataset[ind]["input"] for ind in inds]

# %%
path = "code_by_types"
codes_dict = {}
for d in tqdm(os.listdir(path), desc = "Preparing data"):
    codes_path = os.path.join(path, d)
    codes_dict[d] = []
    for name in os.listdir(codes_path):
        with open(os.path.join(codes_path, name), "r") as f:
            code = f.read()
        code_json = code_to_json(code)
        codes_dict[d].append(code_json)
type_mapping = {
    "Coupe": "coupe",
    "Hatchback":"hatchback",
    "Limousine":"limousine",
    "Minivan":"minivan",
    "Pickup":"pickup",
    "Sedan":"sedan",
    "StationWagon":"station wagon",
    "SUV":"SUV",
    "Truck":"truck",
    "Van":"van",
}
codes_by_types = {}
for key in codes_dict.keys():
    codes_by_types[type_mapping[key]] = codes_dict[key]
# Out:
# Preparing data:   0%|          | 0/10 [00:00<?, ?it/s]

# %%
reconstruction = reconstruction_score(jsons, descriptions, codes_by_types)
print(f"Reconstruction score: {reconstruction}")
# Out:
# Computing score:   0%|          | 0/622 [00:00<?, ?it/s]
# ['sedan']
# ['sedan']
# ['sedan']
# ['sedan']
# ['sedan']
# ['sedan']
# ['sedan']
# Reconstruction score: 0.006430868167202572

# %% [markdown]
# # Bot

# %%
def get_inference_text(prompt, text, tokenizer):
  messages = [
      {"role": "system", "content": prompt},
      {"role": "user", "content": text}
  ]
  input_text = tokenizer.apply_chat_template(
      messages,
      tokenize=False,
      add_generation_prompt=True
  )
  return input_text

# %%
def generate(model, tokenizer, generation_config, inp):
  tokenized_prompt = tokenizer(inp, return_tensors='pt', padding=True, truncation=True)
  tokenized_prompt_ids = tokenized_prompt["input_ids"].cuda()
  tokenized_prompt_mask = tokenized_prompt["attention_mask"].cuda()
  with torch.inference_mode():
      output = model.generate(**{"input_ids":tokenized_prompt_ids, "attention_mask":tokenized_prompt_mask, "generation_config":generation_config}).detach().cpu()
  decoded = []
  for i in range(output.shape[0]):
    ans = tokenizer.decode(output[i][len(tokenized_prompt[0]):], skip_special_tokens=True)
    decoded.append(ans)
  return decoded

# %%
import os
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, GenerationConfig
from peft import PeftModel
import torch
import re

# %%
text2code_model_name = "mistralai/Mistral-Nemo-Instruct-2407"
text2code_tuned_model_name = "evgmaslov/Mistral-Nemo-Instruct-2407-cars"

# %%
tokenizer = AutoTokenizer.from_pretrained(text2code_model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
tokenizer.chat_template = """{%- if messages[0][\"role\"] == \"system\" %}\n    {%- set system_message = messages[0][\"content\"] %}\n    {%- set loop_messages = messages[1:] %}\n{%- else %}\n    {%- set loop_messages = messages %}\n{%- endif %}\n{%- if not tools is defined %}\n    {%- set tools = none %}\n{%- endif %}\n{%- set user_messages = loop_messages | selectattr(\"role\", \"equalto\", \"user\") | list %}\n\n{#- This block checks for alternating user/assistant messages, skipping tool calling messages #}\n{%- set ns = namespace() %}\n{%- set ns.index = 0 %}\n{%- for message in loop_messages %}\n    {%- if not (message.role == \"tool\" or message.role == \"tool_results\" or (message.tool_calls is defined and message.tool_calls is not none)) %}\n        {%- if (message[\"role\"] == \"user\") != (ns.index % 2 == 0) %}\n            {{- raise_exception(\"After the optional system message, conversation roles must alternate user/assistant/user/assistant/...\") }}\n        {%- endif %}\n        {%- set ns.index = ns.index + 1 %}\n    {%- endif %}\n{%- endfor %}\n\n{{- bos_token }}\n{%- for message in loop_messages %}\n    {%- if message[\"role\"] == \"user\" %}\n        {%- if tools is not none and (message == user_messages[-1]) %}\n            {{- \"[AVAILABLE_TOOLS][\" }}\n            {%- for tool in tools %}\n                {%- set tool = tool.function %}\n                {{- '{\"type\": \"function\", \"function\": {' }}\n                {%- for key, val in tool.items() if key != \"return\" %}\n                    {%- if val is string %}\n                        {{- '\"' + key + '\": \"' + val + '\"' }}\n                    {%- else %}\n                        {{- '\"' + key + '\": ' + val|tojson }}\n                    {%- endif %}\n                    {%- if not loop.last %}\n                        {{- \", \" }}\n                    {%- endif %}\n                {%- endfor %}\n                {{- \"}}\" }}\n                {%- if not loop.last %}\n                    {{- \", \" }}\n                {%- else %}\n                    {{- \"]\" }}\n                {%- endif %}\n            {%- endfor %}\n            {{- \"[/AVAILABLE_TOOLS]\" }}\n            {%- endif %}\n        {%- if system_message is defined %}\n            {{- \"[INST]\" + system_message + \"\\n\\n\" + message[\"content\"] + \"[/INST]\" }}\n        {%- else %}\n            {{- \"[INST]\" + message[\"content\"] + \"[/INST]\" }}\n        {%- endif %}\n    {%- elif (message.tool_calls is defined and message.tool_calls is not none) %}\n        {{- \"[TOOL_CALLS][\" }}\n        {%- for tool_call in message.tool_calls %}\n            {%- set out = tool_call.function|tojson %}\n            {{- out[:-1] }}\n            {%- if not tool_call.id is defined or tool_call.id|length != 9 %}\n                {{- raise_exception(\"Tool call IDs should be alphanumeric strings with length 9!\") }}\n            {%- endif %}\n            {{- ', \"id\": \"' + tool_call.id + '\"}' }}\n            {%- if not loop.last %}\n                {{- \", \" }}\n            {%- else %}\n                {{- \"]\" + eos_token }}\n            {%- endif %}\n        {%- endfor %}\n    {%- elif message[\"role\"] == \"assistant\" %}\n        {{- message[\"content\"] + eos_token}}\n    {%- elif message[\"role\"] == \"tool_results\" or message[\"role\"] == \"tool\" %}\n        {%- if message.content is defined and message.content.content is defined %}\n            {%- set content = message.content.content %}\n        {%- else %}\n            {%- set content = message.content %}\n        {%- endif %}\n        {{- '[TOOL_RESULTS]{\"content\": ' + content|string + \", \" }}\n        {%- if not message.tool_call_id is defined or message.tool_call_id|length != 9 %}\n            {{- raise_exception(\"Tool call IDs should be alphanumeric strings with length 9!\") }}\n        {%- endif %}\n        {{- '\"call_id\": \"' + message.tool_call_id + '\"}[/TOOL_RESULTS]' }}\n    {%- else %}\n        {{- raise_exception(\"Only user and assistant roles are supported, with the exception of an initial optional system message!\") }}\n    {%- endif %}\n{%- endfor %}\n"""

# %%
quant_config = BitsAndBytesConfig(load_in_4bit=True,
                                  bnb_4bit_compute_dtype=torch.float16,
                                  bnb_4bit_quant_type="nf4",
                                  bnb_4bit_use_double_quant=True)

# %%
model = AutoModelForCausalLM.from_pretrained(text2code_model_name,
                                             quantization_config=quant_config,
                                             device_map='auto',
                                  low_cpu_mem_usage=True, offload_state_dict=True)
# Out:
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
model = PeftModel.from_pretrained(model, text2code_tuned_model_name)

# %%
prompt = """You are an experienced engineer who designs cars. You help people get their dream car. You receive a request to create a car, which describes its shape, size, and other characteristics. To create a car, you use a C# class of the following structure:
public Car()
{
    Length = ...;
    Width = ...;
    Height = ...;

    WheelWidth = ...;
    WheelRadius = ...;

    WheelRelativeBiasAlongWidth = ...;
    WheelRelativeBiasesAlongLength = ...;

    WheelBaseSegmentsSpans = ...;
    WheelBaseSegmentsBottomSurfaces = ...;
    WheelBaseTopSurface = ...;
    GapBetweenWheelAndBase = ...;

    BodySegmentsSpans = ...;
    BodySegmentsTopSurfaces = ...;
}.
Here is a description of its parameters. "Length" is the length of the car in centimeters, this is a float type parameter. "Width" is the length of the car in centimeters, this is a float type parameter. "Height" is the length of the car in centimeters, this is a float type parameter. "WheelWidth" is the width of each wheel in centimeters, this is a float type parameter. "WheelRadius" is the radius of each wheel in centimeters, this is a float type parameter. "WheelRelativeBiasAlongWidth" is a parameter that determines how far the wheel is shifted into the car body. For example, if WheelRelativeBiasAlongWidth = 0.1, then the wheel is shifted into the car by a distance equal to 10% of its width. This parameter is of float type. "WheelRelativeBiasesAlongLength" is a parameter that contains a list of numbers in floating point format. The number of values in the list is equal to the number of wheel pairs the car has. Each value is equal to the relative offset of a wheel pair relative to the front of the car. For example, if WheelRelativeBiasesAlongLength = new List<float>() { 0.2f, 0.8f }, then the car has two wheel pairs, one offset by 20% of the length, and the other by 80%. The "WheelBaseSegmentsSpans" parameter describes the arrangement of the parts of the car's floor. The floor of a car is the frame on which its wheels are mounted. Usually a car has one frame, but a truck can have 2 or more frames. This parameter contains a list where each element is a range of lengths in which the floor of the car is located. The range is described by a list where the first element is the start of the range and the second element is the end of the range. The WheelBaseSegmentsBottomSurfaces parameter describes the shape of the bottom of the car. If the bottom of the car consists of several planes, this parameter will contain several planes. This parameter contains as many planes as there are ranges specified in the "WheelBaseSegmentsSpans" parameter, because each plane has its own range. This parameter can be used to adjust the ground clearance of the car. The BodySegmentsSpans parameter contains a list of length ranges in which the vehicle body components are located. The "BodySegmentsTopSurfaces" parameter contains a list of the components of the car body. The number of components of the car is equal to the number of ranges in the "BodySegmentsSpans" parameter, because each component has its own range. Each component of the car is described by the shape of its surface. The shape can be specified by one of three classes: Constant (plain shape), CornerRounded (plain shape with rounded corners) and TotalRounded (rounded shape).
The user will ask you to generate a car and will provide you with a description of its shape and dimensions. You need to extract from his request the information needed to fill in the C# class parameters described above. Write C# class to generate a car, fill in its parameters according to the user's request. Here are some examples of what you need to do:
Example 1
user request: Design a car with a standard-sized hood and trunk. It should be 1.67 meters wide and have wheels with a radius of 40 cm.
car: using System.Collections.Generic;
using System;
using System.Collections;
namespace GenerativeDesign.Cars
{
    public class Car : CarBase
    {
        public Car()
        {
            Length = 250f;
            Width = 167f;
            Height = 150f;

            WheelWidth = 20f;
            WheelRadius = 40f;
            WheelRelativeBiasAlongWidth = 0.1f;
            WheelRelativeBiasesAlongLength = new List<float>() { 0.2f, 0.8f };

            WheelBaseSegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 1f } };
            WheelBaseSegmentsBottomSurfaces = new List<Line>() { new Constant(height: 13f) };
            WheelBaseTopSurface = new Constant(height: 90f);
            GapBetweenWheelAndBase = 3f;

            BodySegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 0.3f }, new List<float>(){ 0.3f, 0.8f }, new List<float>(){ 0.8f, 1f } };
            BodySegmentsTopSurfaces = new List<Line>() { new Constant(height: 105f), new Constant(height: 150f), new CornerRounded(minHeight: 90f, maxHeight: 105f, cornerRelativeLength: 0.2f, surfaceAbsoluteLength: 49.999996f, leftCornerRounded: false, rightCornerRounded: true) };
        }
    }

}
Example 2:
user request: Design a car with two wheelsets and a standard-sized hood. It should be 1.67 meters wide.
car: using System.Collections.Generic;
using System;
using System.Collections;
namespace GenerativeDesign.Cars
{
    public class Car : CarBase
    {
        public Car()
        {
            Length = 250f;
            Width = 167f;
            Height = 150f;

            WheelWidth = 20f;
            WheelRadius = 25f;
            WheelRelativeBiasAlongWidth = 0.1f;
            WheelRelativeBiasesAlongLength = new List<float>() { 0.2f, 0.8f };

            WheelBaseSegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 1f } };
            WheelBaseSegmentsBottomSurfaces = new List<Line>() { new Constant(height: 18f) };
            WheelBaseTopSurface = new Constant(height: 75f);
            GapBetweenWheelAndBase = 3f;

            BodySegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 0.3f }, new List<float>(){ 0.3f, 0.9f }, new List<float>(){ 0.9f, 1f } };
            BodySegmentsTopSurfaces = new List<Line>() { new TotalRounded(minHeight: 75f, maxHeight: 90f, leftRounded: true), new Constant(height: 150f), new CornerRounded(minHeight: 75f, maxHeight: 90f, cornerRelativeLength: 0.2f, surfaceAbsoluteLength: 25.000006f, leftCornerRounded: false, rightCornerRounded: true) };
        }
    }

}
Example 3: 
user request: Design a compact sedan. It should be short and narrow, with a small height.
car: using System.Collections.Generic;
using System;
using System.Collections;
namespace GenerativeDesign.Cars
{
    public class Car : CarBase
    {
        public Car()
        {
            Length = 250f;
            Width = 167f;
            Height = 135f;

            WheelWidth = 20f;
            WheelRadius = 25f;
            WheelRelativeBiasAlongWidth = 0.1f;
            WheelRelativeBiasesAlongLength = new List<float>() { 0.2f, 0.8f };

            WheelBaseSegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 1f } };
            WheelBaseSegmentsBottomSurfaces = new List<Line>() { new Constant(height: 13f) };
            WheelBaseTopSurface = new Constant(height: 67.5f);
            GapBetweenWheelAndBase = 3f;

            BodySegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 0.2f }, new List<float>(){ 0.2f, 0.8f }, new List<float>(){ 0.8f, 1f } };
            BodySegmentsTopSurfaces = new List<Line>() { new CornerRounded(minHeight: 67.5f, maxHeight: 94.5f, cornerRelativeLength: 0.2f, surfaceAbsoluteLength: 50f, leftCornerRounded: true, rightCornerRounded: false), new CornerRounded(minHeight: 94.5f, maxHeight: 135f, cornerRelativeLength: 0.2f, surfaceAbsoluteLength: 150f, leftCornerRounded: true, rightCornerRounded: true), new CornerRounded(minHeight: 67.5f, maxHeight: 94.5f, cornerRelativeLength: 0.2f, surfaceAbsoluteLength: 49.999996f, leftCornerRounded: false, rightCornerRounded: true) };
        }
    }

}
Example 4:
user request: Design a car with two wheelsets, a standard-sized hood, and a height of 1.35 meters. Ensure the wheel radius is large.
car: using System.Collections.Generic;
using System;
using System.Collections;
namespace GenerativeDesign.Cars
{
    public class Car : CarBase
    {
        public Car()
        {
            Length = 250f;
            Width = 167f;
            Height = 135f;

            WheelWidth = 20f;
            WheelRadius = 40f;
            WheelRelativeBiasAlongWidth = 0.1f;
            WheelRelativeBiasesAlongLength = new List<float>() { 0.2f, 0.8f };

            WheelBaseSegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 1f } };
            WheelBaseSegmentsBottomSurfaces = new List<Line>() { new Constant(height: 18f) };
            WheelBaseTopSurface = new Constant(height: 94.5f);
            GapBetweenWheelAndBase = 3f;

            BodySegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 0.2f }, new List<float>(){ 0.2f, 0.8f }, new List<float>(){ 0.8f, 1f } };
            BodySegmentsTopSurfaces = new List<Line>() { new TotalRounded(minHeight: 94.5f, maxHeight: 108f, leftRounded: true), new CornerRounded(minHeight: 108f, maxHeight: 135f, cornerRelativeLength: 0.2f, surfaceAbsoluteLength: 150f, leftCornerRounded: true, rightCornerRounded: true), new TotalRounded(minHeight: 94.5f, maxHeight: 108f, leftRounded: false) };
        }
    }

}"""

# %%
user_prompt = "Craft a car with the width of 165 cm and wheel radius of 30 cm."
gen_config = GenerationConfig.from_pretrained(text2code_model_name)
gen_config.max_length = 4096
output = generate(model, tokenizer, gen_config, get_inference_text(prompt, user_prompt, tokenizer))
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)

# %%
pattern = "(?<=```csharp)(?:.|\s)+?(?=```)"
code = re.findall(pattern, output[0])
if len(code) > 0:
    code = code[0]
else:
    code = ""

# %%
print(code)
# Out:
# using System.Collections.Generic;
# using System;
# using System.Collections;
#
# namespace GenerativeDesign.Cars
# {
#     public class Car : CarBase
#     {
#         public Car()
#         {
#             Length = 250f;
#             Width = 165f;
#             Height = 150f;
#
#             WheelWidth = 20f;
#             WheelRadius = 30f;
#             WheelRelativeBiasAlongWidth = 0.1f;
#             WheelRelativeBiasesAlongLength = new List<float>() { 0.2f, 0.8f };
#
#             WheelBaseSegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 1f } };
#             WheelBaseSegmentsBottomSurfaces = new List<Line>() { new Constant(height: 22f) };
#             WheelBaseTopSurface = new Constant(height: 85f);
#             GapBetweenWheelAndBase = 3f;
#
#             BodySegmentsSpans = new List<List<float>>() { new List<float>(){ 0f, 0.3f }, new List<float>(){ 0.3f, 0.9f }, new List<float>(){ 0.9f, 1f } };
#             BodySegmentsTopSurfaces = new List<Line>() { new TotalRounded(minHeight: 85f, maxHeight: 100f, leftRounded: true), new Constant(height: 150f), new CornerRounded(minHeight: 85f, maxHeight: 100f, cornerRelativeLength: 0.2f, surfaceAbsoluteLength: 33f, leftCornerRounded: false, rightCornerRounded: true) };
#         }
#     }
# }
